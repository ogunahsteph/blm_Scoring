# %%
# Import modules
import sys

# %%
# Import custom modules
sys.path.append('../')

from src.models.upload_data import *

# %%
# Set notebook attributes
pd.set_option('display.max_colwidth', 500)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 300)
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
# Set magic attributes
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
# Configuration
args = argparse.ArgumentParser()
args.add_argument("--config", default="../params.yaml")
parsed_args = vars(args.parse_args(""))
config_path = parsed_args['config']

# %% [markdown]
# ### LFTSV

# %%
# %%time
# Data ingestion, cleaning/wrangling
df_lftsv_raw = pull_data(config_path, lftsv_sql(), 'DWH', 'lftsv', False, 'raw')
# Out:
# Currently loading lftsv data set ...
# Time taken is 0 seconds ...
#         client_mifos_id client_mobile_number  loan_status  loan_mifos_id
# 261373            37756                 None          300          74352  \
# 177310            25330                 None          600          50270
#
#         term_frequency  principal_disbursed  principal_repaid
# 261373               7              6300.00              0.00  \
# 177310               7             18000.00          18000.00
#
#         interest_charged  interest_repaid  fee_charges_charged
# 261373            163.81             0.00                94.50  \
# 177310            360.00           360.00                 0.00
#
#         fee_charges_repaid  penalty_charges_charged  penalty_charges_repaid
# 261373                0.00                  1954.28                  151.24  \
# 177310                0.00                     0.00                    0.00
#
#         total_expected_repayment  total_repayment  total_outstanding
# 261373                   8512.59           151.24            8361.35  \
# 177310                  18360.00         18360.00               0.00
#
#         safaricom_loan_balance disbursed_on_date expected_matured_on_date
# 261373                     NaN        2022-04-22               2022-04-29  \
# 177310                     NaN        2019-01-01               2019-01-08
#
#        closed_on_date store_number bloom_version  src_crdt_score
# 261373           None      7237855             2             NaN  \
# 177310     2019-01-07       698026             1             NaN
#
#        due_date_fixed end_rollover_date_fixed expected_dpd90
# 261373     2022-04-29              2022-05-02     2022-07-31
# 177310     2019-01-08              2019-01-11     2019-04-11
# ---------------------------------------------------------------------------------------------------------------------------------------
# CPU times: user 532 ms, sys: 234 ms, total: 766 ms
# Wall time: 380 ms

# %%
# %%time
# Data ingestion, cleaning/wrangling
df_lftsv_clean = clean_dataset(config_path, 'lftsv')
# Out:
# Currently cleaning lftsv data set ...
# Analysis start date 2017-12-10 00:00:00
# Analysis latest date 2023-07-04 00:00:00
#        client_mifos_id client_mobile_number  loan_status loan_mifos_id
# 122137           21030                  nan          600          8339  \
# 271059           52036         254720390987          600        101573
#
#         term_frequency  principal_disbursed  principal_repaid
# 122137              30             25000.00          25000.00  \
# 271059               7             12000.00          12000.00
#
#         interest_charged  interest_repaid  fee_charges_charged
# 122137           1750.00          1750.00                 0.00  \
# 271059            312.01           312.01                 0.00
#
#         fee_charges_repaid  penalty_charges_charged  penalty_charges_repaid
# 122137                0.00                     0.00                    0.00  \
# 271059                0.00                     0.00                    0.00
#
#         total_expected_repayment  total_repayment  total_outstanding
# 122137                  26750.00         26750.00               0.00  \
# 271059                  12312.01         12312.01               0.00
#
#        disbursed_on_date expected_matured_on_date closed_on_date store_number
# 122137        2018-03-27               2018-04-26     2018-04-16       932020  \
# 271059        2022-05-20               2022-05-27     2022-05-27      7357594
#
#         bloom_version  src_crdt_score due_date_fixed end_rollover_date_fixed
# 122137           1.00             NaN     2018-04-26                     NaT  \
# 271059           2.00             NaN     2022-05-27              2022-05-30
#
#        expected_dpd90  safaricom_loan_balance
# 122137            NaT                     NaN
# 271059     2022-08-28                    0.00
# ---------------------------------------------------------------------------------------------------------------------------------------
# CPU times: user 4.5 s, sys: 536 ms, total: 5.04 s
# Wall time: 4.73 s

# %%
# %%time
# Feature engineering
df_lftsv_features = lftsv_feature_engineering(config_path, extract_end_date)
# Out:
# Any bloom 2 one day feature sample:
#        loan_id_product_concat  any_bloom2_1day
# 108105             308912-2.0            False
# ---------------------------------------------------------------------------------------------------------------------------------------
#
# Days past due feature sample:
#        loan_id_product_concat  loan_status due_date_fixed closed_on_date
# 108105             308912-2.0          600     2023-05-10     2023-05-10  \
#
#        max_transaction_date  days_past_due
# 108105           2023-05-10           0.00
# ---------------------------------------------------------------------------------------------------------------------------------------
#
# Days past end rollover feature sample:
#        loan_id_product_concat  loan_status end_rollover_date_fixed
# 108105             308912-2.0          600              2023-05-13  \
#
#        closed_on_date max_transaction_date  days_past_end_rollover
# 108105     2023-05-10           2023-05-10                   -3.00
# ---------------------------------------------------------------------------------------------------------------------------------------
#
# Loan repayment feature sample:
#        loan_id_product_concat  loan_status loan_repayment_status
# 108105             308912-2.0          600        closed_on_time
# ---------------------------------------------------------------------------------------------------------------------------------------
#
# Days to maturity feature sample:
#        loan_id_product_concat max_transaction_date due_date_fixed
# 108105             308912-2.0           2023-05-10     2023-05-10  \
#
#         days_diff_maturity_max_trans
# 108105                          0.00
# ---------------------------------------------------------------------------------------------------------------------------------------
#        client_mifos_id client_mobile_number  loan_status loan_mifos_id
# 77131            53224         254721134218          600        312504  \
# 131501          106886         254726677860          600        299796
#
#         term_frequency  principal_disbursed  principal_repaid
# 77131                7             20000.00          20000.00  \
# 131501              21              3500.00           3500.00
#
#         interest_charged  interest_repaid  fee_charges_charged
# 77131             624.00           624.00                 0.00  \
# 131501            319.20           319.20                 0.00
#
#         fee_charges_repaid  penalty_charges_charged  penalty_charges_repaid
# 77131                 0.00                     0.00                    0.00  \
# 131501                0.00                     0.00                    0.00
#
#         total_expected_repayment  total_repayment  total_outstanding
# 77131                   20624.00         20624.00               0.00  \
# 131501                   3819.20          3819.20               0.00
#
#        disbursed_on_date expected_matured_on_date closed_on_date store_number
# 77131         2023-06-09               2023-06-16     2023-06-15      7188183  \
# 131501        2023-01-29               2023-02-19     2023-02-19      7786293
#
#         bloom_version  src_crdt_score due_date_fixed end_rollover_date_fixed
# 77131            2.00          463.00     2023-06-16              2023-06-19  \
# 131501           2.00          475.00     2023-02-19              2023-02-24
#
#        expected_dpd90  safaricom_loan_balance loan_id_product_concat
# 77131      2023-09-17                    0.00             312504-2.0  \
# 131501     2023-05-25                    0.00             299796-2.0
#
#         loan_count  loan_rank  total_repayment_vs_principal_amount
# 77131           21      18.00                                 1.03  \
# 131501          17      11.00                                 1.09
#
#         any_bloom2_1day max_transaction_date  days_past_due
# 77131             False           2023-06-15          -1.00  \
# 131501            False           2023-02-19           0.00
#
#         days_past_end_rollover   loan_repayment_status
# 77131                    -4.00  closed_early_repayment  \
# 131501                   -5.00          closed_on_time
#
#         days_diff_maturity_max_trans
# 77131                          -1.00
# 131501                          0.00
# ---------------------------------------------------------------------------------------------------------------------------------------
# CPU times: user 6.22 s, sys: 571 ms, total: 6.79 s
# Wall time: 6.27 s

# %%
# %%time
# Data aggregation
df_lftsv_aggregate = lftsv_agg_summaries(config_path, extract_end_date)
# Out:
# All loans:
#       store_number  loan_rank  principal_disbursed disbursed_on_date
# 39344      7491730       5.50             12000.00        2022-10-16  \
# 39345      7491730       5.50             81000.00        2022-10-16
# 39346      7491730       4.00             12900.00        2022-08-13
# 39347      7491730       3.00             12900.00        2022-08-06
# 39348      7491730       2.00             12900.00        2022-07-30
# 39349      7491730       1.00             12000.00        2022-07-25
#
#        safaricom_loan_balance  total_outstanding
# 39344                    0.00               0.00
# 39345               115363.53          115254.37
# 39346                    0.00               0.00
# 39347                    0.00               0.00
# 39348                    0.00               0.00
# 39349                12312.00               0.00
# ---------------------------------------------------------------------------------------------------------------------------------------
#
# Loan snapshots:
#        index client_mifos_id client_mobile_number  loan_status loan_mifos_id
# 19570   3811           55813         254700165018          600        288999  \
#
#        term_frequency  principal_disbursed  principal_repaid
# 19570              21             10500.00          10500.00  \
#
#        interest_charged  interest_repaid  fee_charges_charged
# 19570            957.60           957.60                 0.00  \
#
#        fee_charges_repaid  penalty_charges_charged  penalty_charges_repaid
# 19570                0.00                     0.00                    0.00  \
#
#        total_expected_repayment  total_repayment  total_outstanding
# 19570                  11457.60         11457.60               0.00  \
#
#       disbursed_on_date expected_matured_on_date closed_on_date store_number
# 19570        2022-12-23               2023-01-13     2023-01-10      7105817  \
#
#        bloom_version  src_crdt_score due_date_fixed end_rollover_date_fixed
# 19570           2.00          450.00     2023-01-13              2023-01-18  \
#
#       expected_dpd90  safaricom_loan_balance loan_id_product_concat
# 19570     2023-04-18                    0.00             288999-2.0  \
#
#        loan_count  loan_rank  total_repayment_vs_principal_amount
# 19570          11      11.00                                 1.09  \
#
#        any_bloom2_1day max_transaction_date  days_past_due
# 19570            False           2023-01-10          -3.00  \
#
#        days_past_end_rollover   loan_repayment_status
# 19570                   -8.00  closed_early_repayment  \
#
#        days_diff_maturity_max_trans  latest_21_loan  latest_7_loan
# 19570                         -3.00        10500.00           0.00  \
#
#        latest_1_loan  snapshot_3m_21_loan  snapshot_3m_7_loan
# 19570           0.00             10500.00                0.00  \
#
#        snapshot_3m_1_loan
# 19570                0.00
# ---------------------------------------------------------------------------------------------------------------------------------------
#
# Latest loan:
#       store_number  loan_rank  principal_disbursed  safaricom_loan_balance
# 34331      7491730       5.50             81000.00               115363.53  \
#
#        total_outstanding
# 34331          115254.37
# ---------------------------------------------------------------------------------------------------------------------------------------
#       client_mobile_number store_number  loan_count  loan_status
# 54471                  nan       987640        8.00       600.00  \
# 24938                  nan       724493        4.00       600.00
#
#        term_frequency  principal_disbursed  principal_repaid
# 54471           30.00             10000.00          10000.00  \
# 24938           30.00              5000.00           5000.00
#
#       disbursed_on_date expected_matured_on_date closed_on_date
# 54471        2019-01-29               2019-02-28     2019-03-25  \
# 24938        2019-11-25               2019-12-25     2019-12-25
#
#       due_date_fixed end_rollover_date_fixed expected_dpd90  days_past_due
# 54471     2019-02-28                     NaT            NaT          25.00  \
# 24938     2019-12-25                     NaT            NaT           0.00
#
#        bloom_version loan_repayment_status  src_crdt_score
# 54471           1.00        closed_default             NaN  \
# 24938           1.00        closed_on_time             NaN
#
#        max_principal_amount max_loan_disbursement_date  count_good_loans
# 54471              70000.00                 2018-09-24              6.00  \
# 24938               5000.00                 2019-11-25              4.00
#
#        good_loans_repayment_ratio  num_days_since_last_disbursement
# 54471                        0.75                           1617.00  \
# 24938                        1.00                           1317.00
#
#           inference_col  weight_dpd  max_days_past_due
# 54471  No_rules_relaxed        0.00              25.00  \
# 24938       relax_rules        1.00               0.00
#
#        loan_count_past_3_months  count_7_day_loans  avg_loan_tenure
# 54471                      0.00               0.00              NaN  \
# 24938                      0.00               0.00              NaN
#
#        count_7_day_loans_paid_upto_rollover
# 54471                                  0.00  \
# 24938                                  0.00
#
#        good_loans_repayment_ratio(7_day_loans)
# 54471                                     0.00  \
# 24938                                     0.00
#
#        minimum_7_day_principal_disbursed  total_sum_7_day_principal_disbursed
# 54471                               0.00                                 0.00  \
# 24938                               0.00                                 0.00
#
#        total_sum_1_day_principal_disbursed  avg_7_day_principal_disbursed
# 54471                                 0.00                           0.00  \
# 24938                                 0.00                           0.00
#
#        days_past_end_rollover any_bloom2_1day  total_outstanding_sum
# 54471                     NaN           False                   0.00  \
# 24938                     NaN           False                   0.00
#
#        safaricom_loan_balance_sum  loan_balance  latest_21_loan
# 54471                        0.00          0.00            0.00  \
# 24938                        0.00          0.00            0.00
#
#        latest_7_loan  latest_1_loan  snapshot_3m_21_loan  snapshot_3m_7_loan
# 54471        5000.00           0.00                 0.00             5000.00  \
# 24938           0.00           0.00                 0.00                0.00
#
#        snapshot_3m_1_loan
# 54471                0.00
# 24938                0.00
# ---------------------------------------------------------------------------------------------------------------------------------------
# CPU times: user 17.8 s, sys: 670 ms, total: 18.5 s
# Wall time: 17.5 s

# %%
# Final dataset schema
df_lftsv_aggregate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54882 entries, 0 to 54881
# Data columns (total 45 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   client_mobile_number                     54860 non-null  object
#  1   store_number                             54882 non-null  object
#  2   loan_count                               54860 non-null  float64
#  3   loan_status                              54860 non-null  float64
#  4   term_frequency                           54860 non-null  float64
#  5   principal_disbursed                      54860 non-null  float64
#  6   principal_repaid                         54860 non-null  float64
#  7   disbursed_on_date                        54860 non-null  datetime64[ns]
#  8   expected_matured_on_date                 54860 non-null  datetime64[ns]
#  9   closed_on_date                           29020 non-null  datetime64[ns]
#  10  due_date_fixed                           54860 non-null  datetime64[ns]
#  11  end_rollover_date_fixed                  39937 non-null  datetime64[ns]
#  12  expected_dpd90                           39937 non-null  datetime64[ns]
#  13  days_past_due                            54649 non-null  float64
#  14  bloom_version                            54860 non-null  float64
#  15  loan_repayment_status                    54860 non-null  object
#  16  src_crdt_score                           32426 non-null  float64
#  17  max_principal_amount                     54860 non-null  float64
#  18  max_loan_disbursement_date               54860 non-null  datetime64[ns]
#  19  count_good_loans                         54882 non-null  float64
#  20  good_loans_repayment_ratio               54882 non-null  float64
#  21  num_days_since_last_disbursement         54860 non-null  float64
#  22  inference_col                            54882 non-null  object
#  23  weight_dpd                               54882 non-null  float64
#  24  max_days_past_due                        54850 non-null  float64
#  25  loan_count_past_3_months                 54882 non-null  float64
#  26  count_7_day_loans                        54882 non-null  float64
#  27  avg_loan_tenure                          2308 non-null   float64
#  28  count_7_day_loans_paid_upto_rollover     54882 non-null  float64
#  29  good_loans_repayment_ratio(7_day_loans)  54882 non-null  float64
#  30  minimum_7_day_principal_disbursed        54882 non-null  float64
#  31  total_sum_7_day_principal_disbursed      54882 non-null  float64
#  32  total_sum_1_day_principal_disbursed      54882 non-null  float64
#  33  avg_7_day_principal_disbursed            54882 non-null  float64
#  34  days_past_end_rollover                   39728 non-null  float64
#  35  any_bloom2_1day                          54860 non-null  object
#  36  total_outstanding_sum                    54882 non-null  float64
#  37  safaricom_loan_balance_sum               54882 non-null  float64
#  38  loan_balance                             54882 non-null  float64
#  39  latest_21_loan                           54860 non-null  float64
#  40  latest_7_loan                            54860 non-null  float64
#  41  latest_1_loan                            54860 non-null  float64
#  42  snapshot_3m_21_loan                      54860 non-null  float64
#  43  snapshot_3m_7_loan                       54860 non-null  float64
#  44  snapshot_3m_1_loan                       54860 non-null  float64
# dtypes: datetime64[ns](7), float64(33), object(5)
# memory usage: 18.8+ MB
