# %%
# Import modules
import sys

# %%
# Import custom modules
sys.path.append('../')

from src.models.upload_data import *

# %%
# Set notebook attributes
pd.set_option('display.max_colwidth', 500)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 300)
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
# Set magic attributes
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
# Configuration
args = argparse.ArgumentParser()
args.add_argument("--config", default="../params.yaml")
parsed_args = vars(args.parse_args(""))
config_path = parsed_args['config']

# %% [markdown]
# ### Approved Limits Upload To Safaricom Table

# %%
# %%time
# Approved limits upload
df_upload_saf = push_data(config_path, "AIRFLOW", "saf", execution_date, refresh_date, record_added_to_warehouse_on_timestamp, created_at)
# Out:
# Uploading limits from model version 2022-007[2022-10-21, 2022-11-29] to Safaricom table
# Update Safaricom table pipeline is NOT triggered because push_limits flag = False
#       mobile_number store_number most_recent_trx_date_past_30_days  \
# 5210   254710899960       188939                        2022-11-06
# 30679  254706030123      7249764                        2022-10-26
#
#       last_trx_date  actual_trx_days  approx_30_days_trx_val  \
# 5210     2022-11-22             5.00                15315.73
# 30679    2022-11-24            29.00                80383.79
#
#        expected_trx_days  page_active_days     inference_col  \
# 5210               17.00              0.29  No_rules_relaxed
# 30679              30.00              0.97       relax_rules
#
#        days_since_last_trx transacted_last_5_days  weight_till_recency  \
# 5210                  5.00                    Yes                 1.00
# 30679                 3.00                    Yes                 1.00
#
# ...

# %%
# Final dataset schema
df_upload_saf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147351 entries, 0 to 147350
# Columns: 124 entries, mobile_number to record_added_to_warehouse_on_timestamp
# dtypes: datetime64[ns](2), float64(94), int64(3), object(25)
# memory usage: 139.4+ MB

# %%
# Limits
df_upload_saf[['final_21_limit', 'final_7_limit', 'final_1_limit']].sum()
# Out:
# final_21_limit    117347600
# final_7_limit     314401000
# final_1_limit     150133800
# dtype: int64
