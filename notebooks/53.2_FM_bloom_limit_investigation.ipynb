# %%
# Import modules
import sys

# %%
# Import custom modules
sys.path.append('../')

from src.models.upload_data import *

# %%
# Set notebook attributes
pd.set_option('display.max_colwidth', 500)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 300)
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
# Set magic attributes
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
# Configuration
args = argparse.ArgumentParser()
args.add_argument("--config", default="../params.yaml")
parsed_args = vars(args.parse_args(""))
config_path = parsed_args['config']

# %%
# Load configurations
config = read_params(config_path)
project_dir = config["project_dir"]
scored_limits_risk_review_data_path_excel_parquet = config["processed_data_config"]["scored_limits_risk_review_data_excel_parquet"]
before_21d_graduation_limits_data_path = config["interim_data_config"]["before_21d_graduation_limits_data_parquet"]
after_rmdd_ge95_data_path = config["interim_data_config"]["after_rmdd_ge95_data_parquet"]
after_rmdd_ge96_data_path = config["interim_data_config"]["after_rmdd_ge96_data_parquet"]

# %% [markdown]
# ### Limit Investigation

# %% [markdown]
# #### Legacy

# %%
# Columns not in scope
df_columns_not_in_scope = ['sum_3_months_trx_val', 'approx_30_days_trx_val', 'model_version', 'created_at', 'record_added_to_warehouse_on_timestamp', 'old_src_crdt_score']
limit_cols = ['final_21_limit', 'final_7_limit', 'final_1_limit']

# %%
# Legacy system refresh run
# df = pd.read_excel('../data/external/07_JN_Limits_refresh_summary_20221006_multiple_products_rec_new_2.xlsx')
# df.to_parquet('../data/external/07_JN_Limits_refresh_summary_20221006_multiple_products_rec_new_2.parquet', index=False)
df_raw = pd.read_parquet('../data/external/07_JN_Limits_refresh_summary_20221006_multiple_products_rec_new_2.parquet')
df_raw['store_number'] = df_raw['store_number'].astype('str')
df = df_raw.drop(columns=df_columns_not_in_scope)
df.rename(columns={'avg_3_months_trx_val': 'approx_30_days_trx_val'}, inplace=True)
df.sample(2)
# Out:
#       mobile_number store_number  approx_30_days_trx_val  \
# 34780  254791390899       148371               162262.08
# 13593  254722595191      7054254               140128.85
#
#       most_recent_trx_date_past_30_days last_trx_date  expected_trx_days  \
# 34780                        2022-09-06    2022-10-05                 30
# 13593                        2022-09-06    2022-10-05                 30
#
#        actual_trx_days  page_active_days     inference_col  \
# 34780               26              0.87       relax_rules
# 13593               30              1.00  No_rules_relaxed
#
#        days_since_last_trx transacted_last_5_days  weight_till_recency  \
# 34780                 1.00                    Yes                 1.00
# 13593                 1.00                    Yes                 1.00
#
#        national_id idm_recommendation  idm_limit  is_iprs_validated  \
# 34780  28451681.00             Reject       0.00               True
# 13593  21669837.00             Reject       0.00               True
#
#        client_mobile_number  loan_count  loan_status  term_frequency  \
# 34780       254791390899.00          13       300.00            7.00
# 13593                   NaN           5       300.00            7.00
#
#        principal_disbursed  principal_repaid disbursed_on_date  \
# 34780             50400.00              0.00        2022-09-28
# 13593             28500.00              0.00        2022-03-30
#
#       expected_matured_on_date closed_on_date due_date_fixed  days_past_due  \
# 34780               2022-10-05            NaT     2022-10-05           0.00
# 13593               2022-04-06            NaT     2022-04-06         182.00
#
#        bloom_version loan_repayment_status  src_crdt_score  \
# 34780           2.00        current_active          423.00
# 13593           2.00        active_default             NaN
#
#        max_principal_amount max_loan_disbursement_date  count_good_loans  \
# 34780              50400.00                 2022-09-28             13.00
# 13593              51900.00                 2022-03-09              4.00
#
#        good_loans_repayment_ratio  num_days_since_last_disbursement  \
# 34780                        1.00                              7.00
# 13593                        0.80                            189.00
#
#        weight_dpd  adjusted_loan_count  limit_factor_21  limit_factor_7  \
# 34780           1                   13             0.35            0.12
# 13593           0                    0             0.35            0.12
#
#        limit_factor_1  idm_factor_21  idm_factor_7  idm_factor_1  \
# 34780            0.12           0.70          0.71          0.71
# 13593            0.12           0.70          0.71          0.71
#
#       trading_consistency_bands loan_count_bands  new_limit_factor_21  \
# 34780                    Band 6           Band 8                 0.50
# 13593                    Band 7           Band 4                 0.35
#
#        new_limit_factor_7  new_limit_factor_1  \
# 34780                0.28                0.28
# 13593                0.20                0.20
#
#        weight_good_loans_repayment_ratio  weight_consistency  weight_recency  \
# 34780                                  1                   1               1
# 13593                                  0                   1               1
#
#        risk_rules_factor  ultimate_factor_21  ultimate_factor_7  \
# 34780               1.00                0.35               0.19
# 13593               0.50                0.12               0.07
#
#        ultimate_factor_1  limit_21_day  limit_7_day  limit_1_day  \
# 34780               0.19      56791.73     31497.93     31497.93
# 13593               0.07      17165.78      9891.45      9891.45
#
#        adjusted_21_limit  adjusted_7_limit  adjusted_1_limit  final_21_limit  \
# 34780           56791.73          31497.93          31497.93           56600
# 13593               0.00           9891.45           9891.45               0
#
#        final_7_limit  final_1_limit  blacklist_flag  total_final_21_limit  \
# 34780          50400          50400               0                472000
# 13593              0              0               1                186800
#
#        previous_21_limit  previous_7_limit  previous_1_limit
# 34780              56600             50400             50400
# 13593                  0                 0                 0

# %%
# Data set dimension
df.shape
# Out:
# (60977, 69)

# %%
# Data set schema
df.dtypes.to_frame().T
# Out:
#   mobile_number store_number approx_30_days_trx_val  \
# 0        object       object                float64
#
#   most_recent_trx_date_past_30_days   last_trx_date expected_trx_days  \
# 0                    datetime64[ns]  datetime64[ns]             int64
#
#   actual_trx_days page_active_days inference_col days_since_last_trx  \
# 0           int64          float64        object             float64
#
#   transacted_last_5_days weight_till_recency national_id idm_recommendation  \
# 0                 object             float64     float64             object
#
#   idm_limit is_iprs_validated client_mobile_number loan_count loan_status  \
# 0   float64              bool              float64      int64     float64
#
#   term_frequency principal_disbursed principal_repaid disbursed_on_date  \
# 0        float64             float64          float64    datetime64[ns]
#
#   expected_matured_on_date  closed_on_date  due_date_fixed days_past_due  \
# 0           datetime64[ns]  datetime64[ns]  datetime64[ns]       float64
#
#   bloom_version loan_repayment_status src_crdt_score max_principal_amount  \
# 0       float64                object        float64              float64
#
#   max_loan_disbursement_date count_good_loans good_loans_repayment_ratio  \
# 0             datetime64[ns]          float64                    float64
#
#   num_days_since_last_disbursement weight_dpd adjusted_loan_count  \
# 0                          float64      int64               int64
#
#   limit_factor_21 limit_factor_7 limit_factor_1 idm_factor_21 idm_factor_7  \
# 0         float64        float64        float64       float64      float64
#
#   idm_factor_1 trading_consistency_bands loan_count_bands new_limit_factor_21  \
# 0      float64                    object           object             float64
#
#   new_limit_factor_7 new_limit_factor_1 weight_good_loans_repayment_ratio  \
# 0            float64            float64                             int64
#
#   weight_consistency weight_recency risk_rules_factor ultimate_factor_21  \
# 0              int64          int64           float64            float64
#
#   ultimate_factor_7 ultimate_factor_1 limit_21_day limit_7_day limit_1_day  \
# 0           float64           float64      float64     float64     float64
#
#   adjusted_21_limit adjusted_7_limit adjusted_1_limit final_21_limit  \
# 0           float64          float64          float64          int64
#
#   final_7_limit final_1_limit blacklist_flag total_final_21_limit  \
# 0         int64         int64          int64                int64
#
#   previous_21_limit previous_7_limit previous_1_limit
# 0             int64            int64            int64

# %% [markdown]
# #### Ubuntu 2.0

# %%
# Ubuntu 2.0 refresh run
df_scoring_stabilisation_raw = pd.read_parquet(project_dir + scored_limits_risk_review_data_path_excel_parquet.format(refresh_date.replace("-", "")))
df_scoring_stabilisation = df_scoring_stabilisation_raw[df.columns]
df_scoring_stabilisation.sample(2)
# Out:
#       mobile_number store_number  approx_30_days_trx_val  \
# 20888  254723459568       270710               165789.60
# 4306   254706419485       237572                  193.33
#
#       most_recent_trx_date_past_30_days last_trx_date  expected_trx_days  \
# 20888                        2022-09-20    2022-10-15                 26
# 4306                         2022-09-23    2022-10-08                 16
#
#        actual_trx_days  page_active_days     inference_col  \
# 20888               16              0.62  No_rules_relaxed
# 4306                 2              0.12  No_rules_relaxed
#
#        days_since_last_trx transacted_last_5_days  weight_till_recency  \
# 20888                32.00                     No                 0.00
# 4306                 39.00                     No                 0.00
#
#       national_id idm_recommendation  idm_limit is_iprs_validated  \
# 20888     7121798            Approve       0.00              True
# 4306     20021983             Reject       0.00              True
#
#       client_mobile_number  loan_count  loan_status  term_frequency  \
# 20888         254723459568          14       300.00            7.00
# 4306                   nan           3       300.00           30.00
#
#        principal_disbursed  principal_repaid disbursed_on_date  \
# 20888             32000.00          21543.86        2022-06-19
# 4306               5000.00              0.00        2019-11-22
#
#       expected_matured_on_date closed_on_date due_date_fixed  days_past_due  \
# 20888               2022-06-26            NaT     2022-06-26         143.00
# 4306                2019-12-22            NaT     2019-12-22        1060.00
#
#        bloom_version loan_repayment_status  src_crdt_score  \
# 20888           2.00        active_default          451.00
# 4306            1.00        active_default             NaN
#
#        max_principal_amount max_loan_disbursement_date  count_good_loans  \
# 20888              32000.00                 2022-06-19             11.00
# 4306                5000.00                 2019-11-22              2.00
#
#        good_loans_repayment_ratio  num_days_since_last_disbursement  \
# 20888                        0.79                            150.00
# 4306                         0.67                           1090.00
#
#        weight_dpd  adjusted_loan_count  limit_factor_21  limit_factor_7  \
# 20888           0                   14             0.50            0.17
# 4306            0                    0             0.35            0.12
#
#        limit_factor_1  idm_factor_21  idm_factor_7  idm_factor_1  \
# 20888            0.17           1.00          1.00          1.00
# 4306             0.12           0.70          0.71          0.71
#
#       trading_consistency_bands loan_count_bands  new_limit_factor_21  \
# 20888                    Band 4           Band 8                 0.35
# 4306                     Band 1           Band 3                 0.00
#
#        new_limit_factor_7  new_limit_factor_1  \
# 20888                0.23                0.23
# 4306                 0.00                0.00
#
#        weight_good_loans_repayment_ratio  weight_consistency  weight_recency  \
# 20888                               0.00                0.00               0
# 4306                                0.00                0.00               0
#
#        risk_rules_factor  ultimate_factor_21  ultimate_factor_7  \
# 20888               0.00                0.00               0.00
# 4306                0.00                0.00               0.00
#
#        ultimate_factor_1  limit_21_day  limit_7_day  limit_1_day  \
# 20888               0.00          0.00         0.00         0.00
# 4306                0.00          0.00         0.00         0.00
#
#        adjusted_21_limit  adjusted_7_limit  adjusted_1_limit  final_21_limit  \
# 20888               0.00              0.00              0.00               0
# 4306                0.00              0.00              0.00               0
#
#        final_7_limit  final_1_limit  blacklist_flag  total_final_21_limit  \
# 20888              0              0               1                801800
# 4306               0              0               1                     0
#
#        previous_21_limit  previous_7_limit  previous_1_limit
# 20888                  0                 0                 0
# 4306                   0                 0                 0

# %%
# Data set dimension
df_scoring_stabilisation.shape
# Out:
# (39261, 69)

# %%
# Data set schema
df_scoring_stabilisation.dtypes.to_frame().T
# Out:
#   mobile_number store_number approx_30_days_trx_val  \
# 0        object       object                float64
#
#   most_recent_trx_date_past_30_days   last_trx_date expected_trx_days  \
# 0                    datetime64[ns]  datetime64[ns]             int32
#
#   actual_trx_days page_active_days inference_col days_since_last_trx  \
# 0           int32          float64        object             float64
#
#   transacted_last_5_days weight_till_recency national_id idm_recommendation  \
# 0                 object             float64      object             object
#
#   idm_limit is_iprs_validated client_mobile_number loan_count loan_status  \
# 0   float64            object               object      int32     float64
#
#   term_frequency principal_disbursed principal_repaid disbursed_on_date  \
# 0        float64             float64          float64    datetime64[ns]
#
#   expected_matured_on_date  closed_on_date  due_date_fixed days_past_due  \
# 0           datetime64[ns]  datetime64[ns]  datetime64[ns]       float64
#
#   bloom_version loan_repayment_status src_crdt_score max_principal_amount  \
# 0       float64                object        float64              float64
#
#   max_loan_disbursement_date count_good_loans good_loans_repayment_ratio  \
# 0             datetime64[ns]          float64                    float64
#
#   num_days_since_last_disbursement weight_dpd adjusted_loan_count  \
# 0                          float64      int32               int32
#
#   limit_factor_21 limit_factor_7 limit_factor_1 idm_factor_21 idm_factor_7  \
# 0         float64        float64        float64       float64      float64
#
#   idm_factor_1 trading_consistency_bands loan_count_bands new_limit_factor_21  \
# 0      float64                    object           object             float64
#
#   new_limit_factor_7 new_limit_factor_1 weight_good_loans_repayment_ratio  \
# 0            float64            float64                           float64
#
#   weight_consistency weight_recency risk_rules_factor ultimate_factor_21  \
# 0            float64          int32           float64            float64
#
#   ultimate_factor_7 ultimate_factor_1 limit_21_day limit_7_day limit_1_day  \
# 0           float64           float64      float64     float64     float64
#
#   adjusted_21_limit adjusted_7_limit adjusted_1_limit final_21_limit  \
# 0           float64          float64          float64          int32
#
#   final_7_limit final_1_limit blacklist_flag total_final_21_limit  \
# 0         int32         int32          int32                int32
#
#   previous_21_limit previous_7_limit previous_1_limit
# 0             int32            int32            int32

# %% [markdown]
# #### Comparison

# %%
# In legacy and not in Ubuntu 2.0
df_diff_in_legacy = df[~(df['store_number'].isin(df_scoring_stabilisation['store_number']))]
df_diff_in_legacy.shape
# Out:
# (22348, 69)

# %%
# In Ubuntu 2.0 and not in legacy
df_diff_in_ubuntu = df_scoring_stabilisation[~(df_scoring_stabilisation['store_number'].isin(df['store_number']))]
df_diff_in_ubuntu.shape
# Out:
# (632, 69)

# %%
# In legacy and in Ubuntu 2.0
df_similar = df[(df['store_number'].isin(df_scoring_stabilisation['store_number']))]
df_similar.shape
# Out:
# (38629, 69)

# %% [markdown]
# #### Samples

# %%
# Sample similar in legacy
df_similar_l = df[df['store_number'].isin(df_similar['store_number'])]
df_similar_ls = df_similar_l.sample(2).sort_values(by=['store_number'])
df_similar_l[df_similar_l['store_number'].isin(['7361329', '943478', '7252207'])].sort_values(by=['store_number'])
# Out:
#       mobile_number store_number  approx_30_days_trx_val  \
# 35217  254722874310      7252207                24679.90
# 15416  254724915820      7361329                10268.91
# 7573   254722527886       943478                  130.00
#
#       most_recent_trx_date_past_30_days last_trx_date  expected_trx_days  \
# 35217                        2022-09-06    2022-10-05                 30
# 15416                        2022-09-06    2022-10-05                 30
# 7573                         2022-09-19    2022-09-29                 11
#
#        actual_trx_days  page_active_days     inference_col  \
# 35217               24              0.80       relax_rules
# 15416               29              0.97  No_rules_relaxed
# 7573                 2              0.18       relax_rules
#
#        days_since_last_trx transacted_last_5_days  weight_till_recency  \
# 35217                 1.00                    Yes                 1.00
# 15416                 1.00                    Yes                 1.00
# 7573                  7.00                    Yes                 0.70
#
#        national_id idm_recommendation  idm_limit  is_iprs_validated  \
# 35217  23681415.00             Reject       0.00               True
# 15416  23584522.00             Reject       0.00               True
# 7573    8485166.00             Reject       0.00               True
#
#        client_mobile_number  loan_count  loan_status  term_frequency  \
# 35217       254722874310.00           4       300.00            7.00
# 15416                   NaN          14       300.00            7.00
# 7573                    NaN          17       300.00           30.00
#
#        principal_disbursed  principal_repaid disbursed_on_date  \
# 35217              1100.00              0.00        2022-09-29
# 15416              2000.00              0.00        2022-04-23
# 7573              40000.00              0.00        2021-08-25
#
#       expected_matured_on_date closed_on_date due_date_fixed  days_past_due  \
# 35217               2022-10-06            NaT     2022-10-06          -1.00
# 15416               2022-04-30            NaT     2022-04-30         158.00
# 7573                2021-09-24            NaT     2021-09-24         376.00
#
#        bloom_version loan_repayment_status  src_crdt_score  \
# 35217           2.00        current_active          425.00
# 15416           2.00        active_default          415.00
# 7573            1.00        active_default             NaN
#
#        max_principal_amount max_loan_disbursement_date  count_good_loans  \
# 35217               1100.00                 2022-09-03              4.00
# 15416               2800.00                 2022-03-19             10.00
# 7573              150000.00                 2018-04-11             16.00
#
#        good_loans_repayment_ratio  num_days_since_last_disbursement  \
# 35217                        1.00                              6.00
# 15416                        0.71                            165.00
# 7573                         0.94                            406.00
#
#        weight_dpd  adjusted_loan_count  limit_factor_21  limit_factor_7  \
# 35217           1                    0             0.35            0.12
# 15416           0                   14             0.35            0.12
# 7573            0                    0             0.35            0.12
#
#        limit_factor_1  idm_factor_21  idm_factor_7  idm_factor_1  \
# 35217            0.12           0.70          0.71          0.71
# 15416            0.12           0.70          0.71          0.71
# 7573             0.12           0.70          0.71          0.71
#
#       trading_consistency_bands loan_count_bands  new_limit_factor_21  \
# 35217                    Band 6           Band 3                 0.25
# 15416                    Band 7           Band 8                 0.55
# 7573                     Band 1           Band 8                 0.20
#
#        new_limit_factor_7  new_limit_factor_1  \
# 35217                0.15                0.15
# 15416                0.30                0.30
# 7573                 0.15                0.15
#
#        weight_good_loans_repayment_ratio  weight_consistency  weight_recency  \
# 35217                                  1                   0               1
# 15416                                  0                   1               1
# 7573                                   0                   0               0
#
#        risk_rules_factor  ultimate_factor_21  ultimate_factor_7  \
# 35217               0.75                0.13               0.08
# 15416               0.50                0.19               0.11
# 7573                0.00                0.00               0.00
#
#        ultimate_factor_1  limit_21_day  limit_7_day  limit_1_day  \
# 35217               0.08       3239.24      1959.87      1959.87
# 15416               0.11       1976.77      1087.30      1087.30
# 7573                0.00          0.00         0.00         0.00
#
#        adjusted_21_limit  adjusted_7_limit  adjusted_1_limit  final_21_limit  \
# 35217               0.00           1959.87           1959.87               0
# 15416               0.00              0.00              0.00               0
# 7573                0.00              0.00              0.00               0
#
#        final_7_limit  final_1_limit  blacklist_flag  total_final_21_limit  \
# 35217           2000           1100               0                     0
# 15416              0              0               1                122700
# 7573               0              0               1                 11000
#
#        previous_21_limit  previous_7_limit  previous_1_limit
# 35217                  0                 0              1100
# 15416                  0                 0                 0
# 7573                   0                 0                 0

# %%
# Sample similar in Ubuntu 2.0
df_similar_u = df_scoring_stabilisation[df_scoring_stabilisation['store_number'].isin(df_similar_l['store_number'])]
df_similar_us = df_similar_u[df_similar_u['store_number'].isin(df_similar_ls['store_number'])]
df_similar_u[df_similar_u['store_number'].isin(['7361329', '943478', '7252207'])].sort_values(by=['store_number'])
# Out:
#       mobile_number store_number  approx_30_days_trx_val  \
# 37267  254722874310      7252207                29192.74
# 15563  254724915820      7361329                12800.68
# 7699   254722527886       943478                  175.00
#
#       most_recent_trx_date_past_30_days last_trx_date  expected_trx_days  \
# 37267                        2022-09-20    2022-10-20                 31
# 15563                        2022-09-20    2022-10-20                 31
# 7699                         2022-09-29    2022-10-16                 18
#
#        actual_trx_days  page_active_days     inference_col  \
# 37267               25              0.81  No_rules_relaxed
# 15563               29              0.94  No_rules_relaxed
# 7699                 3              0.17  No_rules_relaxed
#
#        days_since_last_trx transacted_last_5_days  weight_till_recency  \
# 37267                27.00                     No                 0.00
# 15563                27.00                     No                 0.00
# 7699                 31.00                     No                 0.00
#
#       national_id idm_recommendation  idm_limit is_iprs_validated  \
# 37267    23681415            Approve       0.00              True
# 15563    23584522             Reject       0.00              True
# 7699      8485166             Reject       0.00              True
#
#       client_mobile_number  loan_count  loan_status  term_frequency  \
# 37267         254722874310           6       300.00            7.00
# 15563                  nan          14       300.00            7.00
# 7699                   nan          17       300.00           30.00
#
#        principal_disbursed  principal_repaid disbursed_on_date  \
# 37267              2000.00              0.00        2022-10-17
# 15563              2000.00              0.00        2022-04-23
# 7699              40000.00              0.00        2021-08-25
#
#       expected_matured_on_date closed_on_date due_date_fixed  days_past_due  \
# 37267               2022-10-24            NaT     2022-10-24          23.00
# 15563               2022-04-30            NaT     2022-04-30         200.00
# 7699                2021-09-24            NaT     2021-09-24         418.00
#
#        bloom_version loan_repayment_status  src_crdt_score  \
# 37267           2.00        active_default          425.00
# 15563           2.00        active_default          415.00
# 7699            1.00        active_default             NaN
#
#        max_principal_amount max_loan_disbursement_date  count_good_loans  \
# 37267               2000.00                 2022-10-17              5.00
# 15563               2800.00                 2022-03-19             10.00
# 7699              150000.00                 2018-04-11             16.00
#
#        good_loans_repayment_ratio  num_days_since_last_disbursement  \
# 37267                        0.83                             30.00
# 15563                        0.71                            207.00
# 7699                         0.94                            448.00
#
#        weight_dpd  adjusted_loan_count  limit_factor_21  limit_factor_7  \
# 37267           0                    6             0.50            0.17
# 15563           0                    0             0.35            0.12
# 7699            0                    0             0.35            0.12
#
#        limit_factor_1  idm_factor_21  idm_factor_7  idm_factor_1  \
# 37267            0.17           1.00          1.00          1.00
# 15563            0.12           0.70          0.71          0.71
# 7699             0.12           0.70          0.71          0.71
#
#       trading_consistency_bands loan_count_bands  new_limit_factor_21  \
# 37267                    Band 6           Band 4                 0.30
# 15563                    Band 7           Band 8                 0.55
# 7699                     Band 1           Band 8                 0.20
#
#        new_limit_factor_7  new_limit_factor_1  \
# 37267                0.17                0.17
# 15563                0.30                0.30
# 7699                 0.15                0.15
#
#        weight_good_loans_repayment_ratio  weight_consistency  weight_recency  \
# 37267                               0.00                0.00               0
# 15563                               0.00                1.00               0
# 7699                                0.00                0.00               0
#
#        risk_rules_factor  ultimate_factor_21  ultimate_factor_7  \
# 37267               0.00                0.00               0.00
# 15563               0.25                0.10               0.05
# 7699                0.00                0.00               0.00
#
#        ultimate_factor_1  limit_21_day  limit_7_day  limit_1_day  \
# 37267               0.00          0.00         0.00         0.00
# 15563               0.05       1232.07       677.68       677.68
# 7699                0.00          0.00         0.00         0.00
#
#        adjusted_21_limit  adjusted_7_limit  adjusted_1_limit  final_21_limit  \
# 37267               0.00              0.00              0.00               0
# 15563               0.00              0.00              0.00               0
# 7699                0.00              0.00              0.00               0
#
#        final_7_limit  final_1_limit  blacklist_flag  total_final_21_limit  \
# 37267              0              0               0                     0
# 15563              0              0               1                122700
# 7699               0              0               1                 11000
#
#        previous_21_limit  previous_7_limit  previous_1_limit
# 37267                  0              2000              1100
# 15563                  0                 0                 0
# 7699                   0                 0                 0

# %% [markdown]
# #### Limits

# %%
# Legacy limits
df[limit_cols].sum()
# Out:
# final_21_limit    209283300
# final_7_limit     507871200
# final_1_limit     511063900
# dtype: int64

# %%
# Ubuntu 2.0 limits
df_scoring_stabilisation[limit_cols].sum()
# Out:
# final_21_limit    17065000
# final_7_limit     18091300
# final_1_limit     16272400
# dtype: int64

# %% [markdown]
# #### Diagnostics

# %% [markdown]
# ##### 01. approx_30_days_trx_val

# %% [raw]
# This feature is understated by 1 day in legacy.

# %% [markdown]
# ##### 02. most_recent_trx_date_past_30_days

# %%
# Legacy
df.last_trx_date.max() - df.last_trx_date.min()
# Out:
# Timedelta('29 days 00:00:00')

# %%
# Ubuntu 2.0
df_scoring_stabilisation.last_trx_date.max() - df_scoring_stabilisation.last_trx_date.min()
# Out:
# Timedelta('30 days 00:00:00')

# %% [raw]
# Legacy looks at a 29 day window.
# Ubuntu 2.0 looks at a 30 day window.
#
# This affects:
#
# * expected_trx_days = last_trx_date - most_recent_trx_date_past_30_days `Shorter window in scope`
# * actual_trx_days = COUNT UNIQUE transaction_time `Shorter window in scope`
# * page_active_days = actual_trx_days / expected_trx_days `Computational metrics are under respresented`
# * inference_col

# %% [markdown]
# ##### 03. days_since_last_trx

# %%
df.loc[(df.last_trx_date == (extract_end_date - dt.timedelta(days=5))), 'days_since_last_trx'].unique()
# Out:
# array([], dtype=float64)

# %%
df_scoring_stabilisation[df_scoring_stabilisation.days_since_last_trx == 5].head()
# Out:
# Empty DataFrame
# Columns: [mobile_number, store_number, approx_30_days_trx_val, most_recent_trx_date_past_30_days, last_trx_date, expected_trx_days, actual_trx_days, page_active_days, inference_col, days_since_last_trx, transacted_last_5_days, weight_till_recency, national_id, idm_recommendation, idm_limit, is_iprs_validated, client_mobile_number, loan_count, loan_status, term_frequency, principal_disbursed, principal_repaid, disbursed_on_date, expected_matured_on_date, closed_on_date, due_date_fixed, days_past_due, bloom_version, loan_repayment_status, src_crdt_score, max_principal_amount, max_loan_disbursement_date, count_good_loans, good_loans_repayment_ratio, num_days_since_last_disbursement, weight_dpd, adjusted_loan_count, limit_factor_21, limit_factor_7, limit_factor_1, idm_factor_21, idm_factor_7, idm_factor_1, trading_consistency_bands, loan_count_bands, new_limit_factor_21, new_limit_factor_7, new_limit_factor_1, weight_good_loans_repayment_ratio, weight_consistency, weight_recency, risk_rules_factor, ultimate_factor_21, ultimate_factor_7, ultimate_factor_1, limit_21_day, limit_7_day, limit_1_day, adjusted_21_limit, adjusted_7_limit, adjusted_1_limit, final_21_limit, final_7_limit, final_1_limit, blacklist_flag, total_final_21_limit, previous_21_limit, previous_7_limit, previous_1_limit]
# Index: []

# %% [raw]
# This feature is ovestated by 1 day in legacy.
# Refresh date is factored in computation logic.
#
# days_since_last_trx = extract_end_date - last_trx_date
#
# This affects:
#
# * transacted_last_5_days `Actual window not in scope`

# %% [markdown]
# ##### 04. good_loans_repayment_ratio

# %% [raw]
# Some values are null in Ubuntu 2.0.
# This is beacuse of a loan count of 0.
#
# This has been remediated by imputing missing values.
#
# This affects:
#
# * inference_col
# * transacted_last_5_days
# * weight_till_recency

# %% [markdown]
# ##### 05. max_loan_disbursement_date

# %% [raw]
# Ought to be sorted by both amount and disbured_on_date due to duplicate max principal amount.

# %% [markdown]
# ##### 06. loan_id_product_concat

# %% [raw]
# Bloom version for td data set ought to be coersed to float

# %% [markdown]
# ##### 07. weight_recency

# %% [raw]
# Threshold of 3
# Less than or equal to three return 1
# Else 0

# %% [markdown]
# ##### 08. old_src_credit_score

# %% [raw]
# Definition not available.
