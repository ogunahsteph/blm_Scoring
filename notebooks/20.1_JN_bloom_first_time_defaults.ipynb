# %%
#import data processing libraries
import os
import pandas as pd
import numpy as np
import math as math
import datetime as dt
from scipy import stats

#import visualization libraries
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
sns.set_style('darkgrid')
# %matplotlib inline

#db connection libraries
import psycopg2
from sqlalchemy import create_engine
import psycopg2.extras as extras

# %%
pd.set_option('display.max_colwidth', 500)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 300)

#suppress scientific notation to 2 decimal places
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
host = '157.245.248.249'
port = int(5432)
dbname = 'ubuntu'
user = 'jacklinengenia'
password = 'x3MX&8#!'


def get_query_results_postgres():
    with psycopg2.connect(host = host,
                          port = port,
                          database = dbname,
                          user = user,
                          password = password) as conn:
        sql = 'select loan_mifos_id, store_number, loan_status, term_frequency, principal_disbursed, principal_outstanding, interest_outstanding, fee_charges_charged, fee_charges_outstanding, penalty_charges_charged, penalty_charges_outstanding, total_expected_repayment, total_repayment, total_outstanding, safaricom_loan_balance, bloom_version, disbursed_on_date, expected_matured_on_date, end_rollvr_dt, dpd_30, dpd_d60, dpd_d90 from bloomlive.loans_fact_table_materialized_summary_view'
        df = pd.read_sql(sql, conn)
        
    return df

    conn.close()

# %%
df_loans = get_query_results_postgres()

df_loans.head(3)
# Out:
# /opt/tljh/user/lib/python3.9/site-packages/pandas/io/sql.py:758: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#    loan_mifos_id store_number  loan_status  term_frequency  \
# 0          60553       930988          600               1
# 1          60590      7049959          600               1
# 2          60828       210507          600               1
#
#    principal_disbursed  principal_outstanding  interest_outstanding  \
# 0             20000.00                   0.00                  0.00
# 1              2500.00                   0.00                  0.00
# 2              5000.00                   0.00                  0.00
#
#    fee_charges_charged  fee_charges_outstanding  penalty_charges_charged  \
# 0                 0.00                     0.00                     0.00
# 1                18.68                     0.00                    20.00
# 2                 0.00                     0.00                     0.00
#
#    penalty_charges_outstanding  total_expected_repayment  total_repayment  \
# 0                         0.00                  20080.00         20080.00
# 1                         0.00                   2548.68          2548.68
# 2                         0.00                   5020.00          5020.00
#
#    total_outstanding  safaricom_loan_balance  bloom_version disbursed_on_date  \
# 0               0.00                     NaN           2.00        2022-04-05
# 1               0.00                     NaN           2.00        2022-04-05
# 2               0.00                     NaN           2.00        2022-04-06
#
#   expected_matured_on_date end_rollvr_dt      dpd_30     dpd_d60     dpd_d90
# 0               2022-04-06    2022-04-07  2022-05-07  2022-06-06  2022-07-06
# 1               2022-04-06    2022-04-07  2022-05-07  2022-06-06  2022-07-06
# 2               2022-04-07    2022-04-08  2022-05-08  2022-06-07  2022-07-07

# %%
df_loans.shape
# Out:
# (469068, 22)

# %%
#create loan count column i.e adds a new column that captures the num of loans a customer has taken
df_loans["loan_count"] = df_loans.groupby("store_number")["store_number"].transform('size')

df_loans.head(3)
# Out:
#    loan_mifos_id store_number  loan_status  term_frequency  \
# 0          60553       930988          600               1
# 1          60590      7049959          600               1
# 2          60828       210507          600               1
#
#    principal_disbursed  principal_outstanding  interest_outstanding  \
# 0             20000.00                   0.00                  0.00
# 1              2500.00                   0.00                  0.00
# 2              5000.00                   0.00                  0.00
#
#    fee_charges_charged  fee_charges_outstanding  penalty_charges_charged  \
# 0                 0.00                     0.00                     0.00
# 1                18.68                     0.00                    20.00
# 2                 0.00                     0.00                     0.00
#
#    penalty_charges_outstanding  total_expected_repayment  total_repayment  \
# 0                         0.00                  20080.00         20080.00
# 1                         0.00                   2548.68          2548.68
# 2                         0.00                   5020.00          5020.00
#
#    total_outstanding  safaricom_loan_balance  bloom_version disbursed_on_date  \
# 0               0.00                     NaN           2.00        2022-04-05
# 1               0.00                     NaN           2.00        2022-04-05
# 2               0.00                     NaN           2.00        2022-04-06
#
#   expected_matured_on_date end_rollvr_dt      dpd_30     dpd_d60     dpd_d90  \
# 0               2022-04-06    2022-04-07  2022-05-07  2022-06-06  2022-07-06
# 1               2022-04-06    2022-04-07  2022-05-07  2022-06-06  2022-07-06
# 2               2022-04-07    2022-04-08  2022-05-08  2022-06-07  2022-07-07
#
#    loan_count
# 0       26.00
# 1        2.00
# 2       39.00

# %%
#converting the current time to datetime format
curr_time = pd.to_datetime('today')

df_loans['disbursed_on_date'] = pd.to_datetime(df_loans['disbursed_on_date'], errors='coerce')
df_loans['end_rollvr_dt'] = pd.to_datetime(df_loans['end_rollvr_dt'], errors='coerce')
df_loans['expected_matured_on_date'] = pd.to_datetime(df_loans['expected_matured_on_date'], errors='coerce')

# %%
def saf_loan_balance(df):
    
    total_outstanding = df['total_outstanding']
    safaricom_loan_balance = df['safaricom_loan_balance']
    
    if safaricom_loan_balance >= 0:
        return safaricom_loan_balance
    else:
        return total_outstanding

# %%
df_loans['safaricom_loan_balance'] = df_loans.apply(lambda x: saf_loan_balance(x), axis = 1)

df_loans.head(5)
# Out:
#    loan_mifos_id store_number  loan_status  term_frequency  \
# 0          60553       930988          600               1
# 1          60590      7049959          600               1
# 2          60828       210507          600               1
# 3          60977      7278566          600               7
# 4          61245      7569133          600               7
#
#    principal_disbursed  principal_outstanding  interest_outstanding  \
# 0             20000.00                   0.00                  0.00
# 1              2500.00                   0.00                  0.00
# 2              5000.00                   0.00                  0.00
# 3              1800.00                   0.00                  0.00
# 4             43000.00                   0.00                  0.00
#
#    fee_charges_charged  fee_charges_outstanding  penalty_charges_charged  \
# 0                 0.00                     0.00                     0.00
# 1                18.68                     0.00                    20.00
# 2                 0.00                     0.00                     0.00
# 3                 0.00                     0.00                     0.00
# 4                 0.00                     0.00                     0.00
#
#    penalty_charges_outstanding  total_expected_repayment  total_repayment  \
# 0                         0.00                  20080.00         20080.00
# 1                         0.00                   2548.68          2548.68
# 2                         0.00                   5020.00          5020.00
# 3                         0.00                   1846.81          1846.81
# 4                         0.00                  44118.01         44118.01
#
#    total_outstanding  safaricom_loan_balance  bloom_version disbursed_on_date  \
# 0               0.00                    0.00           2.00        2022-04-05
# 1               0.00                    0.00           2.00        2022-04-05
# 2               0.00                    0.00           2.00        2022-04-06
# 3               0.00                    0.00           2.00        2022-04-06
# 4               0.00                    0.00           2.00        2022-04-06
#
#   expected_matured_on_date end_rollvr_dt      dpd_30     dpd_d60     dpd_d90  \
# 0               2022-04-06    2022-04-07  2022-05-07  2022-06-06  2022-07-06
# 1               2022-04-06    2022-04-07  2022-05-07  2022-06-06  2022-07-06
# 2               2022-04-07    2022-04-08  2022-05-08  2022-06-07  2022-07-07
# 3               2022-04-13    2022-04-16  2022-05-16  2022-06-15  2022-07-15
# 4               2022-04-13    2022-04-16  2022-05-16  2022-06-15  2022-07-15
#
#    loan_count
# 0       26.00
# 1        2.00
# 2       39.00
# 3        5.00
# 4       17.00

# %%
def cal_loan_count_flag(df):
    
    loan_count = df['loan_count']
    
    if loan_count == 1:
        return 'New Client'
    else:
        return 'Repeat Client'

# %%
df_loans['Loan Count Flag'] = df_loans.apply(lambda x: cal_loan_count_flag(x), axis = 1)

df_loans.head(5)
# Out:
#    loan_mifos_id store_number  loan_status  term_frequency  \
# 0          60553       930988          600               1
# 1          60590      7049959          600               1
# 2          60828       210507          600               1
# 3          60977      7278566          600               7
# 4          61245      7569133          600               7
#
#    principal_disbursed  principal_outstanding  interest_outstanding  \
# 0             20000.00                   0.00                  0.00
# 1              2500.00                   0.00                  0.00
# 2              5000.00                   0.00                  0.00
# 3              1800.00                   0.00                  0.00
# 4             43000.00                   0.00                  0.00
#
#    fee_charges_charged  fee_charges_outstanding  penalty_charges_charged  \
# 0                 0.00                     0.00                     0.00
# 1                18.68                     0.00                    20.00
# 2                 0.00                     0.00                     0.00
# 3                 0.00                     0.00                     0.00
# 4                 0.00                     0.00                     0.00
#
#    penalty_charges_outstanding  total_expected_repayment  total_repayment  \
# 0                         0.00                  20080.00         20080.00
# 1                         0.00                   2548.68          2548.68
# 2                         0.00                   5020.00          5020.00
# 3                         0.00                   1846.81          1846.81
# 4                         0.00                  44118.01         44118.01
#
#    total_outstanding  safaricom_loan_balance  bloom_version disbursed_on_date  \
# 0               0.00                    0.00           2.00        2022-04-05
# 1               0.00                    0.00           2.00        2022-04-05
# 2               0.00                    0.00           2.00        2022-04-06
# 3               0.00                    0.00           2.00        2022-04-06
# 4               0.00                    0.00           2.00        2022-04-06
#
#   expected_matured_on_date end_rollvr_dt      dpd_30     dpd_d60     dpd_d90  \
# 0               2022-04-06    2022-04-07  2022-05-07  2022-06-06  2022-07-06
# 1               2022-04-06    2022-04-07  2022-05-07  2022-06-06  2022-07-06
# 2               2022-04-07    2022-04-08  2022-05-08  2022-06-07  2022-07-07
# 3               2022-04-13    2022-04-16  2022-05-16  2022-06-15  2022-07-15
# 4               2022-04-13    2022-04-16  2022-05-16  2022-06-15  2022-07-15
#
#    loan_count Loan Count Flag
# 0       26.00   Repeat Client
# 1        2.00   Repeat Client
# 2       39.00   Repeat Client
# 3        5.00   Repeat Client
# 4       17.00   Repeat Client

# %%
current_defaulters = df_loans[(df_loans['penalty_charges_charged'] > 0) & (df_loans['total_outstanding'] > 0) & (df_loans['safaricom_loan_balance'] > 0) & (df_loans['loan_status'] == 300)]

current_defaulters.shape
# Out:
# (25787, 24)

# %%
defaulters = df_loans[(df_loans['penalty_charges_charged'] > 0)]

defaulters.shape
# Out:
# (65988, 24)

# %%
defaulters_bloom_one = defaulters[(defaulters['bloom_version'] == 1)]

defaulters_bloom_one.shape
# Out:
# (21120, 24)

# %%
defaulters_bloom_two = defaulters[(defaulters['bloom_version'] == 2)]

defaulters_bloom_two.shape
# Out:
# (44868, 24)

# %%
defaulters_bloom_two[(defaulters_bloom_two['store_number'] == '7468569')]
# Out:
#         loan_mifos_id store_number  loan_status  term_frequency  \
# 131290         228595      7468569          300              21
# 135822         106687      7468569          600              21
# 135892         127075      7468569          300              21
#
#         principal_disbursed  principal_outstanding  interest_outstanding  \
# 131290              7400.00                 154.38                  0.00
# 135822              8500.00                   0.00                  0.00
# 135892              7000.00                  34.29                  0.00
#
#         fee_charges_charged  fee_charges_outstanding  penalty_charges_charged  \
# 131290               150.00                     0.00                     4.38
# 135822               149.14                     0.00                     3.31
# 135892                24.00                     0.00                    10.28
#
#         penalty_charges_outstanding  total_expected_repayment  \
# 131290                         0.00                   8229.26
# 135822                         0.00                   9298.46
# 135892                         0.00                   7566.29
#
#         total_repayment  total_outstanding  safaricom_loan_balance  \
# 131290          8074.88             154.38                    0.00
# 135822          9298.46               0.00                    0.00
# 135892          7532.00              34.29                    0.00
#
#         bloom_version disbursed_on_date expected_matured_on_date  \
# 131290           2.00        2022-10-12               2022-11-02
# 135822           2.00        2022-05-26               2022-06-16
# 135892           2.00        2022-06-17               2022-07-08
#
#        end_rollvr_dt      dpd_30     dpd_d60     dpd_d90  loan_count  \
# 131290    2022-11-07  2022-12-07  2023-01-06  2023-02-05       21.00
# 135822    2022-06-21  2022-07-21  2022-08-20  2022-09-19       21.00
# 135892    2022-07-13  2022-08-12  2022-09-11  2022-10-11       21.00
#
#        Loan Count Flag
# 131290   Repeat Client
# 135822   Repeat Client
# 135892   Repeat Client

# %%
# grouping store_number to find the count of bloom one defaulters
defaulters_bloom_one_count = defaulters_bloom_one.groupby(['store_number'], as_index=False)['loan_mifos_id'].count()
defaulters_bloom_one_count = defaulters_bloom_one_count.rename(columns={'loan_mifos_id':'defaulters_bloom_one_count'})

defaulters_bloom_one_count.head()
# Out:
#   store_number  defaulters_bloom_one_count
# 0       058169                           1
# 1       101705                           1
# 2       103914                           1
# 3       105639                           1
# 4       105649                           1

# %%
# grouping store_number to find the count of bloom two defaulters
defaulters_bloom_two_count = defaulters_bloom_two.groupby(['store_number'], as_index=False)['loan_mifos_id'].count()
defaulters_bloom_two_count = defaulters_bloom_two_count.rename(columns={'loan_mifos_id':'defaulters_bloom_two_count'})

defaulters_bloom_two_count.head()
# Out:
#   store_number  defaulters_bloom_two_count
# 0       000030                           1
# 1       003227                           5
# 2       058133                           1
# 3       105570                           1
# 4       105652                           3

# %%
defaulters_count = pd.merge(defaulters_bloom_one_count, defaulters_bloom_two_count, on = 'store_number', how = 'outer')

defaulters_count = defaulters_count.fillna(0)

defaulters_count.head(15)
# Out:
#    store_number  defaulters_bloom_one_count  defaulters_bloom_two_count
# 0        058169                        1.00                        0.00
# 1        101705                        1.00                        0.00
# 2        103914                        1.00                        0.00
# 3        105639                        1.00                        0.00
# 4        105649                        1.00                        0.00
# 5        105754                        1.00                        0.00
# 6        110138                        2.00                        0.00
# 7        110169                        1.00                        1.00
# 8        110398                        1.00                        0.00
# 9        110501                        1.00                        2.00
# 10       110596                        3.00                        0.00
# 11       110913                        1.00                        0.00
# 12       110918                        1.00                        0.00
# 13       110922                        1.00                        0.00
# 14       111135                        1.00                        0.00

# %%
current_defaulters['loan_status'].value_counts()
# Out:
# 300    25787
# Name: loan_status, dtype: int64

# %%
current_defaulters_bloom_one = current_defaulters[current_defaulters['bloom_version'] == 1]

current_defaulters_bloom_one.shape
# Out:
# (5736, 24)

# %%
current_defaulters_bloom_one.head()
# Out:
#      loan_mifos_id store_number  loan_status  term_frequency  \
# 433         170892       604194          300              30
# 445         171103       530658          300              30
# 453         171381       567823          300              30
# 454         171391       740928          300              30
# 460         171510       218210          300              30
#
#      principal_disbursed  principal_outstanding  interest_outstanding  \
# 433              5000.00                5000.00                350.00
# 445              5000.00                5000.00                350.00
# 453              5000.00                5000.00                350.00
# 454              5000.00                5000.00                350.00
# 460             40000.00               40000.00               2800.00
#
#      fee_charges_charged  fee_charges_outstanding  penalty_charges_charged  \
# 433               294.00                   294.00                  2322.00
# 445               294.00                   294.00                  2322.00
# 453               294.00                   294.00                  2322.00
# 454               294.00                   294.00                  2322.00
# 460              2354.00                  2354.00                 17866.00
#
#      penalty_charges_outstanding  total_expected_repayment  total_repayment  \
# 433                      2322.00                   7966.00             0.00
# 445                      2322.00                   7966.00             0.00
# 453                      2222.00                   7966.00           100.00
# 454                      2322.00                   7966.00             0.00
# 460                     15866.00                  63020.00          2000.00
#
#      total_outstanding  safaricom_loan_balance  bloom_version  \
# 433            7966.00                 7966.00           1.00
# 445            7966.00                 7966.00           1.00
# 453            7866.00                 7866.00           1.00
# 454            7966.00                 7966.00           1.00
# 460           61020.00                61020.00           1.00
#
#     disbursed_on_date expected_matured_on_date end_rollvr_dt dpd_30 dpd_d60  \
# 433        2019-12-09               2020-01-08           NaT   None    None
# 445        2019-12-10               2020-01-09           NaT   None    None
# 453        2019-12-11               2020-01-10           NaT   None    None
# 454        2019-12-11               2020-01-10           NaT   None    None
# 460        2019-12-11               2020-01-10           NaT   None    None
#
#     dpd_d90  loan_count Loan Count Flag
# 433    None        3.00   Repeat Client
# 445    None        6.00   Repeat Client
# 453    None        3.00   Repeat Client
# 454    None        3.00   Repeat Client
# 460    None       17.00   Repeat Client

# %%
current_defaulters_bloom_one = pd.merge(current_defaulters_bloom_one, defaulters_bloom_one_count, on = 'store_number', how = 'left')

current_defaulters_bloom_one.head()
# Out:
#    loan_mifos_id store_number  loan_status  term_frequency  \
# 0         170892       604194          300              30
# 1         171103       530658          300              30
# 2         171381       567823          300              30
# 3         171391       740928          300              30
# 4         171510       218210          300              30
#
#    principal_disbursed  principal_outstanding  interest_outstanding  \
# 0              5000.00                5000.00                350.00
# 1              5000.00                5000.00                350.00
# 2              5000.00                5000.00                350.00
# 3              5000.00                5000.00                350.00
# 4             40000.00               40000.00               2800.00
#
#    fee_charges_charged  fee_charges_outstanding  penalty_charges_charged  \
# 0               294.00                   294.00                  2322.00
# 1               294.00                   294.00                  2322.00
# 2               294.00                   294.00                  2322.00
# 3               294.00                   294.00                  2322.00
# 4              2354.00                  2354.00                 17866.00
#
#    penalty_charges_outstanding  total_expected_repayment  total_repayment  \
# 0                      2322.00                   7966.00             0.00
# 1                      2322.00                   7966.00             0.00
# 2                      2222.00                   7966.00           100.00
# 3                      2322.00                   7966.00             0.00
# 4                     15866.00                  63020.00          2000.00
#
#    total_outstanding  safaricom_loan_balance  bloom_version disbursed_on_date  \
# 0            7966.00                 7966.00           1.00        2019-12-09
# 1            7966.00                 7966.00           1.00        2019-12-10
# 2            7866.00                 7866.00           1.00        2019-12-11
# 3            7966.00                 7966.00           1.00        2019-12-11
# 4           61020.00                61020.00           1.00        2019-12-11
#
#   expected_matured_on_date end_rollvr_dt dpd_30 dpd_d60 dpd_d90  loan_count  \
# 0               2020-01-08           NaT   None    None    None        3.00
# 1               2020-01-09           NaT   None    None    None        6.00
# 2               2020-01-10           NaT   None    None    None        3.00
# 3               2020-01-10           NaT   None    None    None        3.00
# 4               2020-01-10           NaT   None    None    None       17.00
#
#   Loan Count Flag  defaulters_bloom_one_count
# 0   Repeat Client                           1
# 1   Repeat Client                           1
# 2   Repeat Client                           1
# 3   Repeat Client                           1
# 4   Repeat Client                           1

# %%
def cal_first_bloom_one_default(df):
    
    defaulters_bloom_one_count = df['defaulters_bloom_one_count']
    
    if defaulters_bloom_one_count == 1:
        return 'Bloom One First Default'
    else:
        return 'Bloom One Subsequent Default'

# %%
current_defaulters_bloom_one['Default Flag'] = current_defaulters_bloom_one.apply(lambda x: cal_first_bloom_one_default(x), axis = 1)

current_defaulters_bloom_one.head(5)
# Out:
#    loan_mifos_id store_number  loan_status  term_frequency  \
# 0         170892       604194          300              30
# 1         171103       530658          300              30
# 2         171381       567823          300              30
# 3         171391       740928          300              30
# 4         171510       218210          300              30
#
#    principal_disbursed  principal_outstanding  interest_outstanding  \
# 0              5000.00                5000.00                350.00
# 1              5000.00                5000.00                350.00
# 2              5000.00                5000.00                350.00
# 3              5000.00                5000.00                350.00
# 4             40000.00               40000.00               2800.00
#
#    fee_charges_charged  fee_charges_outstanding  penalty_charges_charged  \
# 0               294.00                   294.00                  2322.00
# 1               294.00                   294.00                  2322.00
# 2               294.00                   294.00                  2322.00
# 3               294.00                   294.00                  2322.00
# 4              2354.00                  2354.00                 17866.00
#
#    penalty_charges_outstanding  total_expected_repayment  total_repayment  \
# 0                      2322.00                   7966.00             0.00
# 1                      2322.00                   7966.00             0.00
# 2                      2222.00                   7966.00           100.00
# 3                      2322.00                   7966.00             0.00
# 4                     15866.00                  63020.00          2000.00
#
#    total_outstanding  safaricom_loan_balance  bloom_version disbursed_on_date  \
# 0            7966.00                 7966.00           1.00        2019-12-09
# 1            7966.00                 7966.00           1.00        2019-12-10
# 2            7866.00                 7866.00           1.00        2019-12-11
# 3            7966.00                 7966.00           1.00        2019-12-11
# 4           61020.00                61020.00           1.00        2019-12-11
#
#   expected_matured_on_date end_rollvr_dt dpd_30 dpd_d60 dpd_d90  loan_count  \
# 0               2020-01-08           NaT   None    None    None        3.00
# 1               2020-01-09           NaT   None    None    None        6.00
# 2               2020-01-10           NaT   None    None    None        3.00
# 3               2020-01-10           NaT   None    None    None        3.00
# 4               2020-01-10           NaT   None    None    None       17.00
#
#   Loan Count Flag  defaulters_bloom_one_count             Default Flag
# 0   Repeat Client                           1  Bloom One First Default
# 1   Repeat Client                           1  Bloom One First Default
# 2   Repeat Client                           1  Bloom One First Default
# 3   Repeat Client                           1  Bloom One First Default
# 4   Repeat Client                           1  Bloom One First Default

# %%
current_defaulters_bloom_one['Default Flag'].value_counts()
# Out:
# Bloom One First Default         4433
# Bloom One Subsequent Default    1303
# Name: Default Flag, dtype: int64

# %%
current_defaulters_bloom_two = current_defaulters[current_defaulters['bloom_version'] == 2]

current_defaulters_bloom_two.shape
# Out:
# (20051, 24)

# %%
current_defaulters_bloom_two = pd.merge(current_defaulters_bloom_two, defaulters_bloom_two_count, on = 'store_number', how = 'left')

current_defaulters_bloom_two.head()
# Out:
#    loan_mifos_id store_number  loan_status  term_frequency  \
# 0          86961      7803525          300               1
# 1          87075       916139          300              21
# 2          87171       772622          300               1
# 3          87286      7801651          300              21
# 4          87291      7965219          300               7
#
#    principal_disbursed  principal_outstanding  interest_outstanding  \
# 0              2800.00                2800.00                 11.20
# 1              3300.00                3300.00                250.81
# 2              5700.00                  88.35                  0.00
# 3             28400.00                 595.77                  0.00
# 4              1200.00                 959.92                  0.00
#
#    fee_charges_charged  fee_charges_outstanding  penalty_charges_charged  \
# 0                21.00                    21.00                   915.06
# 1                49.50                    49.50                  1504.78
# 2                42.75                     0.00                    45.60
# 3               426.00                     0.00                   180.40
# 4                30.00                     0.00                   427.51
#
#    penalty_charges_outstanding  total_expected_repayment  total_repayment  \
# 0                       847.86                   3747.26            67.20
# 1                      1425.58                   5105.09            79.20
# 2                         0.00                   5811.15          5722.80
# 3                         0.00                  31164.81         30569.04
# 4                         0.00                   1688.72           728.80
#
#    total_outstanding  safaricom_loan_balance  bloom_version disbursed_on_date  \
# 0            3680.06                 3680.06           2.00        2022-05-06
# 1            5025.89                 5025.89           2.00        2022-05-06
# 2              88.35                   88.35           2.00        2022-05-06
# 3             595.77                  595.77           2.00        2022-05-06
# 4             959.92                  959.92           2.00        2022-05-06
#
#   expected_matured_on_date end_rollvr_dt      dpd_30     dpd_d60     dpd_d90  \
# 0               2022-05-07    2022-05-08  2022-06-07  2022-07-07  2022-08-06
# 1               2022-05-27    2022-06-01  2022-07-01  2022-07-31  2022-08-30
# 2               2022-05-07    2022-05-08  2022-06-07  2022-07-07  2022-08-06
# 3               2022-05-27    2022-06-01  2022-07-01  2022-07-31  2022-08-30
# 4               2022-05-13    2022-05-16  2022-06-15  2022-07-15  2022-08-14
#
#    loan_count Loan Count Flag  defaulters_bloom_two_count
# 0        1.00      New Client                           1
# 1       12.00   Repeat Client                           2
# 2       87.00   Repeat Client                           6
# 3       15.00   Repeat Client                           7
# 4        1.00      New Client                           1

# %%
current_defaulters_bloom_two[(current_defaulters_bloom_two['store_number'] == '7468569')]
# Out:
# Empty DataFrame
# Columns: [loan_mifos_id, store_number, loan_status, term_frequency, principal_disbursed, principal_outstanding, interest_outstanding, fee_charges_charged, fee_charges_outstanding, penalty_charges_charged, penalty_charges_outstanding, total_expected_repayment, total_repayment, total_outstanding, safaricom_loan_balance, bloom_version, disbursed_on_date, expected_matured_on_date, end_rollvr_dt, dpd_30, dpd_d60, dpd_d90, loan_count, Loan Count Flag, defaulters_bloom_two_count]
# Index: []

# %%
def cal_first_bloom_two_default(df):
    
    defaulters_bloom_two_count = df['defaulters_bloom_two_count']
    
    if defaulters_bloom_two_count == 1:
        return 'Bloom Two First Default'
    else:
        return 'Bloom Two Subsequent Default'

# %%
current_defaulters_bloom_two['Default Flag'] = current_defaulters_bloom_two.apply(lambda x: cal_first_bloom_two_default(x), axis = 1)

current_defaulters_bloom_two.head(5)
# Out:
#    loan_mifos_id store_number  loan_status  term_frequency  \
# 0          86961      7803525          300               1
# 1          87075       916139          300              21
# 2          87171       772622          300               1
# 3          87286      7801651          300              21
# 4          87291      7965219          300               7
#
#    principal_disbursed  principal_outstanding  interest_outstanding  \
# 0              2800.00                2800.00                 11.20
# 1              3300.00                3300.00                250.81
# 2              5700.00                  88.35                  0.00
# 3             28400.00                 595.77                  0.00
# 4              1200.00                 959.92                  0.00
#
#    fee_charges_charged  fee_charges_outstanding  penalty_charges_charged  \
# 0                21.00                    21.00                   915.06
# 1                49.50                    49.50                  1504.78
# 2                42.75                     0.00                    45.60
# 3               426.00                     0.00                   180.40
# 4                30.00                     0.00                   427.51
#
#    penalty_charges_outstanding  total_expected_repayment  total_repayment  \
# 0                       847.86                   3747.26            67.20
# 1                      1425.58                   5105.09            79.20
# 2                         0.00                   5811.15          5722.80
# 3                         0.00                  31164.81         30569.04
# 4                         0.00                   1688.72           728.80
#
#    total_outstanding  safaricom_loan_balance  bloom_version disbursed_on_date  \
# 0            3680.06                 3680.06           2.00        2022-05-06
# 1            5025.89                 5025.89           2.00        2022-05-06
# 2              88.35                   88.35           2.00        2022-05-06
# 3             595.77                  595.77           2.00        2022-05-06
# 4             959.92                  959.92           2.00        2022-05-06
#
#   expected_matured_on_date end_rollvr_dt      dpd_30     dpd_d60     dpd_d90  \
# 0               2022-05-07    2022-05-08  2022-06-07  2022-07-07  2022-08-06
# 1               2022-05-27    2022-06-01  2022-07-01  2022-07-31  2022-08-30
# 2               2022-05-07    2022-05-08  2022-06-07  2022-07-07  2022-08-06
# 3               2022-05-27    2022-06-01  2022-07-01  2022-07-31  2022-08-30
# 4               2022-05-13    2022-05-16  2022-06-15  2022-07-15  2022-08-14
#
#    loan_count Loan Count Flag  defaulters_bloom_two_count  \
# 0        1.00      New Client                           1
# 1       12.00   Repeat Client                           2
# 2       87.00   Repeat Client                           6
# 3       15.00   Repeat Client                           7
# 4        1.00      New Client                           1
#
#                    Default Flag
# 0       Bloom Two First Default
# 1  Bloom Two Subsequent Default
# 2  Bloom Two Subsequent Default
# 3  Bloom Two Subsequent Default
# 4       Bloom Two First Default

# %%
current_defaulters_bloom_two['Default Flag'].value_counts()
# Out:
# Bloom Two First Default         13391
# Bloom Two Subsequent Default     6660
# Name: Default Flag, dtype: int64

# %%
current_defaulters_bloom_two.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20051 entries, 0 to 20050
# Data columns (total 26 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   loan_mifos_id                20051 non-null  int64
#  1   store_number                 20051 non-null  object
#  2   loan_status                  20051 non-null  int64
#  3   term_frequency               20051 non-null  int64
#  4   principal_disbursed          20051 non-null  float64
#  5   principal_outstanding        20051 non-null  float64
#  6   interest_outstanding         20051 non-null  float64
#  7   fee_charges_charged          20051 non-null  float64
#  8   fee_charges_outstanding      20051 non-null  float64
#  9   penalty_charges_charged      20051 non-null  float64
#  10  penalty_charges_outstanding  20051 non-null  float64
#  11  total_expected_repayment     20051 non-null  float64
#  12  total_repayment              20051 non-null  float64
#  13  total_outstanding            20051 non-null  float64
#  14  safaricom_loan_balance       20051 non-null  float64
#  15  bloom_version                20051 non-null  float64
#  16  disbursed_on_date            20051 non-null  datetime64[ns]
#  17  expected_matured_on_date     20051 non-null  datetime64[ns]
#  18  end_rollvr_dt                20051 non-null  datetime64[ns]
#  19  dpd_30                       20051 non-null  object
#  20  dpd_d60                      20051 non-null  object
#  21  dpd_d90                      20051 non-null  object
#  22  loan_count                   20051 non-null  float64
#  23  Loan Count Flag              20051 non-null  object
#  24  defaulters_bloom_two_count   20051 non-null  int64
#  25  Default Flag                 20051 non-null  object
# dtypes: datetime64[ns](3), float64(13), int64(4), object(6)
# memory usage: 4.1+ MB

# %%
def cal_occurred_after_first_limit_reductions(df):
    
    expected_matured_on_date = df['expected_matured_on_date']
    disbursed_on_date = df['disbursed_on_date']
    
    if ((disbursed_on_date <= pd.to_datetime('2022-07-27')) and (expected_matured_on_date > pd.to_datetime('2022-07-27'))):
        return 'Default occurred after first limit reductions'
    else:
        return 'Default occurred before first limit reductions'

# %%
current_defaulters_bloom_two['First Limit Reductions Flag'] = current_defaulters_bloom_two.apply(lambda x: cal_occurred_after_first_limit_reductions(x), axis = 1)

current_defaulters_bloom_two.head(5)
# Out:
#    loan_mifos_id store_number  loan_status  term_frequency  \
# 0          86961      7803525          300               1
# 1          87075       916139          300              21
# 2          87171       772622          300               1
# 3          87286      7801651          300              21
# 4          87291      7965219          300               7
#
#    principal_disbursed  principal_outstanding  interest_outstanding  \
# 0              2800.00                2800.00                 11.20
# 1              3300.00                3300.00                250.81
# 2              5700.00                  88.35                  0.00
# 3             28400.00                 595.77                  0.00
# 4              1200.00                 959.92                  0.00
#
#    fee_charges_charged  fee_charges_outstanding  penalty_charges_charged  \
# 0                21.00                    21.00                   915.06
# 1                49.50                    49.50                  1504.78
# 2                42.75                     0.00                    45.60
# 3               426.00                     0.00                   180.40
# 4                30.00                     0.00                   427.51
#
#    penalty_charges_outstanding  total_expected_repayment  total_repayment  \
# 0                       847.86                   3747.26            67.20
# 1                      1425.58                   5105.09            79.20
# 2                         0.00                   5811.15          5722.80
# 3                         0.00                  31164.81         30569.04
# 4                         0.00                   1688.72           728.80
#
#    total_outstanding  safaricom_loan_balance  bloom_version disbursed_on_date  \
# 0            3680.06                 3680.06           2.00        2022-05-06
# 1            5025.89                 5025.89           2.00        2022-05-06
# 2              88.35                   88.35           2.00        2022-05-06
# 3             595.77                  595.77           2.00        2022-05-06
# 4             959.92                  959.92           2.00        2022-05-06
#
#   expected_matured_on_date end_rollvr_dt      dpd_30     dpd_d60     dpd_d90  \
# 0               2022-05-07    2022-05-08  2022-06-07  2022-07-07  2022-08-06
# 1               2022-05-27    2022-06-01  2022-07-01  2022-07-31  2022-08-30
# 2               2022-05-07    2022-05-08  2022-06-07  2022-07-07  2022-08-06
# 3               2022-05-27    2022-06-01  2022-07-01  2022-07-31  2022-08-30
# 4               2022-05-13    2022-05-16  2022-06-15  2022-07-15  2022-08-14
#
#    loan_count Loan Count Flag  defaulters_bloom_two_count  \
# 0        1.00      New Client                           1
# 1       12.00   Repeat Client                           2
# 2       87.00   Repeat Client                           6
# 3       15.00   Repeat Client                           7
# 4        1.00      New Client                           1
#
#                    Default Flag  \
# 0       Bloom Two First Default
# 1  Bloom Two Subsequent Default
# 2  Bloom Two Subsequent Default
# 3  Bloom Two Subsequent Default
# 4       Bloom Two First Default
#
#                       First Limit Reductions Flag
# 0  Default occurred before first limit reductions
# 1  Default occurred before first limit reductions
# 2  Default occurred before first limit reductions
# 3  Default occurred before first limit reductions
# 4  Default occurred before first limit reductions

# %%
def cal_occurred_after_second_limit_reductions(df):
    
    expected_matured_on_date = df['expected_matured_on_date']
    disbursed_on_date = df['disbursed_on_date']
    
    if ((disbursed_on_date <= pd.to_datetime('2022-08-03')) and (expected_matured_on_date > pd.to_datetime('2022-08-03'))):
        return 'Default occurred after second limit reductions'
    else:
        return 'Default occurred before second limit reductions'

# %%
current_defaulters_bloom_two['Second Limit Reductions Flag'] = current_defaulters_bloom_two.apply(lambda x: cal_occurred_after_second_limit_reductions(x), axis = 1)

current_defaulters_bloom_two.head(5)
# Out:
#    loan_mifos_id store_number  loan_status  term_frequency  \
# 0          86961      7803525          300               1
# 1          87075       916139          300              21
# 2          87171       772622          300               1
# 3          87286      7801651          300              21
# 4          87291      7965219          300               7
#
#    principal_disbursed  principal_outstanding  interest_outstanding  \
# 0              2800.00                2800.00                 11.20
# 1              3300.00                3300.00                250.81
# 2              5700.00                  88.35                  0.00
# 3             28400.00                 595.77                  0.00
# 4              1200.00                 959.92                  0.00
#
#    fee_charges_charged  fee_charges_outstanding  penalty_charges_charged  \
# 0                21.00                    21.00                   915.06
# 1                49.50                    49.50                  1504.78
# 2                42.75                     0.00                    45.60
# 3               426.00                     0.00                   180.40
# 4                30.00                     0.00                   427.51
#
#    penalty_charges_outstanding  total_expected_repayment  total_repayment  \
# 0                       847.86                   3747.26            67.20
# 1                      1425.58                   5105.09            79.20
# 2                         0.00                   5811.15          5722.80
# 3                         0.00                  31164.81         30569.04
# 4                         0.00                   1688.72           728.80
#
#    total_outstanding  safaricom_loan_balance  bloom_version disbursed_on_date  \
# 0            3680.06                 3680.06           2.00        2022-05-06
# 1            5025.89                 5025.89           2.00        2022-05-06
# 2              88.35                   88.35           2.00        2022-05-06
# 3             595.77                  595.77           2.00        2022-05-06
# 4             959.92                  959.92           2.00        2022-05-06
#
#   expected_matured_on_date end_rollvr_dt      dpd_30     dpd_d60     dpd_d90  \
# 0               2022-05-07    2022-05-08  2022-06-07  2022-07-07  2022-08-06
# 1               2022-05-27    2022-06-01  2022-07-01  2022-07-31  2022-08-30
# 2               2022-05-07    2022-05-08  2022-06-07  2022-07-07  2022-08-06
# 3               2022-05-27    2022-06-01  2022-07-01  2022-07-31  2022-08-30
# 4               2022-05-13    2022-05-16  2022-06-15  2022-07-15  2022-08-14
#
#    loan_count Loan Count Flag  defaulters_bloom_two_count  \
# 0        1.00      New Client                           1
# 1       12.00   Repeat Client                           2
# 2       87.00   Repeat Client                           6
# 3       15.00   Repeat Client                           7
# 4        1.00      New Client                           1
#
#                    Default Flag  \
# 0       Bloom Two First Default
# 1  Bloom Two Subsequent Default
# 2  Bloom Two Subsequent Default
# 3  Bloom Two Subsequent Default
# 4       Bloom Two First Default
#
#                       First Limit Reductions Flag  \
# 0  Default occurred before first limit reductions
# 1  Default occurred before first limit reductions
# 2  Default occurred before first limit reductions
# 3  Default occurred before first limit reductions
# 4  Default occurred before first limit reductions
#
#                       Second Limit Reductions Flag
# 0  Default occurred before second limit reductions
# 1  Default occurred before second limit reductions
# 2  Default occurred before second limit reductions
# 3  Default occurred before second limit reductions
# 4  Default occurred before second limit reductions

# %%
current_defaulters_bloom_two['First Limit Reductions Flag'].value_counts()
# Out:
# Default occurred before first limit reductions    18988
# Default occurred after first limit reductions      1063
# Name: First Limit Reductions Flag, dtype: int64

# %%
current_defaulters_bloom_two['Second Limit Reductions Flag'].value_counts()
# Out:
# Default occurred before second limit reductions    18931
# Default occurred after second limit reductions      1120
# Name: Second Limit Reductions Flag, dtype: int64

# %%
current_defaulters_bloom_two['Loan Count Flag'].value_counts()
# Out:
# Repeat Client    15422
# New Client        4629
# Name: Loan Count Flag, dtype: int64

# %%
def saf_loan_balance(df):
    
    safaricom_loan_balance = df['safaricom_loan_balance']
    
    if safaricom_loan_balance >= 0:
        return 'yes'
    else:
        return 'no'

# %%
current_defaulters_bloom_two['saf_loan_balance'] = current_defaulters_bloom_two.apply(lambda x: saf_loan_balance(x), axis = 1)

current_defaulters_bloom_two.head(5)
# Out:
#    loan_mifos_id store_number  loan_status  term_frequency  \
# 0          86961      7803525          300               1
# 1          87075       916139          300              21
# 2          87171       772622          300               1
# 3          87286      7801651          300              21
# 4          87291      7965219          300               7
#
#    principal_disbursed  principal_outstanding  interest_outstanding  \
# 0              2800.00                2800.00                 11.20
# 1              3300.00                3300.00                250.81
# 2              5700.00                  88.35                  0.00
# 3             28400.00                 595.77                  0.00
# 4              1200.00                 959.92                  0.00
#
#    fee_charges_charged  fee_charges_outstanding  penalty_charges_charged  \
# 0                21.00                    21.00                   915.06
# 1                49.50                    49.50                  1504.78
# 2                42.75                     0.00                    45.60
# 3               426.00                     0.00                   180.40
# 4                30.00                     0.00                   427.51
#
#    penalty_charges_outstanding  total_expected_repayment  total_repayment  \
# 0                       847.86                   3747.26            67.20
# 1                      1425.58                   5105.09            79.20
# 2                         0.00                   5811.15          5722.80
# 3                         0.00                  31164.81         30569.04
# 4                         0.00                   1688.72           728.80
#
#    total_outstanding  safaricom_loan_balance  bloom_version disbursed_on_date  \
# 0            3680.06                 3680.06           2.00        2022-05-06
# 1            5025.89                 5025.89           2.00        2022-05-06
# 2              88.35                   88.35           2.00        2022-05-06
# 3             595.77                  595.77           2.00        2022-05-06
# 4             959.92                  959.92           2.00        2022-05-06
#
#   expected_matured_on_date end_rollvr_dt      dpd_30     dpd_d60     dpd_d90  \
# 0               2022-05-07    2022-05-08  2022-06-07  2022-07-07  2022-08-06
# 1               2022-05-27    2022-06-01  2022-07-01  2022-07-31  2022-08-30
# 2               2022-05-07    2022-05-08  2022-06-07  2022-07-07  2022-08-06
# 3               2022-05-27    2022-06-01  2022-07-01  2022-07-31  2022-08-30
# 4               2022-05-13    2022-05-16  2022-06-15  2022-07-15  2022-08-14
#
#    loan_count Loan Count Flag  defaulters_bloom_two_count  \
# 0        1.00      New Client                           1
# 1       12.00   Repeat Client                           2
# 2       87.00   Repeat Client                           6
# 3       15.00   Repeat Client                           7
# 4        1.00      New Client                           1
#
#                    Default Flag  \
# 0       Bloom Two First Default
# 1  Bloom Two Subsequent Default
# 2  Bloom Two Subsequent Default
# 3  Bloom Two Subsequent Default
# 4       Bloom Two First Default
#
#                       First Limit Reductions Flag  \
# 0  Default occurred before first limit reductions
# 1  Default occurred before first limit reductions
# 2  Default occurred before first limit reductions
# 3  Default occurred before first limit reductions
# 4  Default occurred before first limit reductions
#
#                       Second Limit Reductions Flag saf_loan_balance
# 0  Default occurred before second limit reductions              yes
# 1  Default occurred before second limit reductions              yes
# 2  Default occurred before second limit reductions              yes
# 3  Default occurred before second limit reductions              yes
# 4  Default occurred before second limit reductions              yes

# %%
def calc_loan_balance(df):
    
    saf_loan_balance = df['saf_loan_balance']
    total_outstanding = df['total_outstanding']
    safaricom_loan_balance = df['safaricom_loan_balance']
    
    if saf_loan_balance == 'yes':
        return safaricom_loan_balance
    else:
        return total_outstanding

# %%
current_defaulters_bloom_two['loan_balance'] = current_defaulters_bloom_two.apply(lambda x: calc_loan_balance(x), axis = 1)

current_defaulters_bloom_two.head(5)
# Out:
#    loan_mifos_id store_number  loan_status  term_frequency  \
# 0          86961      7803525          300               1
# 1          87075       916139          300              21
# 2          87171       772622          300               1
# 3          87286      7801651          300              21
# 4          87291      7965219          300               7
#
#    principal_disbursed  principal_outstanding  interest_outstanding  \
# 0              2800.00                2800.00                 11.20
# 1              3300.00                3300.00                250.81
# 2              5700.00                  88.35                  0.00
# 3             28400.00                 595.77                  0.00
# 4              1200.00                 959.92                  0.00
#
#    fee_charges_charged  fee_charges_outstanding  penalty_charges_charged  \
# 0                21.00                    21.00                   915.06
# 1                49.50                    49.50                  1504.78
# 2                42.75                     0.00                    45.60
# 3               426.00                     0.00                   180.40
# 4                30.00                     0.00                   427.51
#
#    penalty_charges_outstanding  total_expected_repayment  total_repayment  \
# 0                       847.86                   3747.26            67.20
# 1                      1425.58                   5105.09            79.20
# 2                         0.00                   5811.15          5722.80
# 3                         0.00                  31164.81         30569.04
# 4                         0.00                   1688.72           728.80
#
#    total_outstanding  safaricom_loan_balance  bloom_version disbursed_on_date  \
# 0            3680.06                 3680.06           2.00        2022-05-06
# 1            5025.89                 5025.89           2.00        2022-05-06
# 2              88.35                   88.35           2.00        2022-05-06
# 3             595.77                  595.77           2.00        2022-05-06
# 4             959.92                  959.92           2.00        2022-05-06
#
#   expected_matured_on_date end_rollvr_dt      dpd_30     dpd_d60     dpd_d90  \
# 0               2022-05-07    2022-05-08  2022-06-07  2022-07-07  2022-08-06
# 1               2022-05-27    2022-06-01  2022-07-01  2022-07-31  2022-08-30
# 2               2022-05-07    2022-05-08  2022-06-07  2022-07-07  2022-08-06
# 3               2022-05-27    2022-06-01  2022-07-01  2022-07-31  2022-08-30
# 4               2022-05-13    2022-05-16  2022-06-15  2022-07-15  2022-08-14
#
#    loan_count Loan Count Flag  defaulters_bloom_two_count  \
# 0        1.00      New Client                           1
# 1       12.00   Repeat Client                           2
# 2       87.00   Repeat Client                           6
# 3       15.00   Repeat Client                           7
# 4        1.00      New Client                           1
#
#                    Default Flag  \
# 0       Bloom Two First Default
# 1  Bloom Two Subsequent Default
# 2  Bloom Two Subsequent Default
# 3  Bloom Two Subsequent Default
# 4       Bloom Two First Default
#
#                       First Limit Reductions Flag  \
# 0  Default occurred before first limit reductions
# 1  Default occurred before first limit reductions
# 2  Default occurred before first limit reductions
# 3  Default occurred before first limit reductions
# 4  Default occurred before first limit reductions
#
#                       Second Limit Reductions Flag saf_loan_balance  \
# 0  Default occurred before second limit reductions              yes
# 1  Default occurred before second limit reductions              yes
# 2  Default occurred before second limit reductions              yes
# 3  Default occurred before second limit reductions              yes
# 4  Default occurred before second limit reductions              yes
#
#    loan_balance
# 0       3680.06
# 1       5025.89
# 2         88.35
# 3        595.77
# 4        959.92

# %%
host = '157.245.248.249'
port = int(5432)
dbname = 'ubuntu'
user = 'jacklinengenia'
password = 'x3MX&8#!'


def get_query_results_postgres():
    with psycopg2.connect(host = host,
                          port = port,
                          database = dbname,
                          user = user,
                          password = password) as conn:
        sql = "select store_number, adjusted_21_limit, adjusted_7_limit, adjusted_1_limit, final_21_limit, final_7_limit, final_1_limit, model_version from bloomlive.temp_scoring_summaries where model_version in('2022-005[2022-05-14, 2022-07-27]', '2022-005[2022-05-14, 2022-08-03]', '2022-007[2022-05-14, 2022-11-03]')"
        df = pd.read_sql(sql, conn)
        
    return df

    conn.close()

# %%
limits = get_query_results_postgres()

limits.head(3)
# Out:
# /opt/tljh/user/lib/python3.9/site-packages/pandas/io/sql.py:758: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#   store_number  adjusted_21_limit  adjusted_7_limit  adjusted_1_limit  \
# 0      7290826               0.00            262.94            262.94
# 1      7373821               0.00            602.38            602.38
# 2      7465042               0.00            471.00            471.00
#
#    final_21_limit  final_7_limit  final_1_limit  \
# 0               0              0              0
# 1               0              0              0
# 2               0              0              0
#
#                       model_version
# 0  2022-005[2022-05-14, 2022-07-27]
# 1  2022-005[2022-05-14, 2022-07-27]
# 2  2022-005[2022-05-14, 2022-07-27]

# %%
limits["adjusted_21_limit"] = (np.ceil(limits["adjusted_21_limit"] / 100) * 100).astype(int)
limits["adjusted_7_limit"] = (np.ceil(limits["adjusted_7_limit"] / 100) * 100).astype(int)
limits["adjusted_1_limit"] = (np.ceil(limits["adjusted_1_limit"] / 100) * 100).astype(int)

limits["adjusted_global_limit"] = limits[["adjusted_21_limit", "adjusted_7_limit", "adjusted_1_limit"]].max(axis=1)
limits["final_global_limit"] = limits[["final_21_limit", "final_7_limit", "final_1_limit"]].max(axis=1)

limits.head()
# Out:
#   store_number  adjusted_21_limit  adjusted_7_limit  adjusted_1_limit  \
# 0      7290826                  0               300               300
# 1      7373821                  0               700               700
# 2      7465042                  0               500               500
# 3      7480355                  0               300               300
# 4      7506256                  0               600               600
#
#    final_21_limit  final_7_limit  final_1_limit  \
# 0               0              0              0
# 1               0              0              0
# 2               0              0              0
# 3               0              0              0
# 4               0              0              0
#
#                       model_version  adjusted_global_limit  final_global_limit
# 0  2022-005[2022-05-14, 2022-07-27]                    300                   0
# 1  2022-005[2022-05-14, 2022-07-27]                    700                   0
# 2  2022-005[2022-05-14, 2022-07-27]                    500                   0
# 3  2022-005[2022-05-14, 2022-07-27]                    300                   0
# 4  2022-005[2022-05-14, 2022-07-27]                    600                   0

# %%
limits = limits[['store_number', 'model_version', 'adjusted_global_limit', 'final_global_limit']]

limits.head()
# Out:
#   store_number                     model_version  adjusted_global_limit  \
# 0      7290826  2022-005[2022-05-14, 2022-07-27]                    300
# 1      7373821  2022-005[2022-05-14, 2022-07-27]                    700
# 2      7465042  2022-005[2022-05-14, 2022-07-27]                    500
# 3      7480355  2022-005[2022-05-14, 2022-07-27]                    300
# 4      7506256  2022-005[2022-05-14, 2022-07-27]                    600
#
#    final_global_limit
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   0

# %%
first_refresh = limits[limits['model_version'] == '2022-005[2022-05-14, 2022-07-27]']
del first_refresh['model_version']

second_refresh = limits[limits['model_version'] == '2022-005[2022-05-14, 2022-08-03]']
del second_refresh['model_version']

current_refresh = limits[limits['model_version'] == '2022-007[2022-05-14, 2022-11-03]']
del current_refresh['model_version']

# %%
current_defaulters_bloom_two = pd.merge(current_defaulters_bloom_two, first_refresh, on = 'store_number', how = 'left')
current_defaulters_bloom_two = current_defaulters_bloom_two.rename(columns={'adjusted_global_limit':'first_adjusted_global_limit', 'final_global_limit':'first_final_global_limit'})
current_defaulters_bloom_two['first_adjusted_global_limit'] = current_defaulters_bloom_two['first_adjusted_global_limit'].fillna(0)
current_defaulters_bloom_two['first_final_global_limit'] = current_defaulters_bloom_two['first_final_global_limit'].fillna(0)

current_defaulters_bloom_two = pd.merge(current_defaulters_bloom_two, second_refresh, on = 'store_number', how = 'left')
current_defaulters_bloom_two = current_defaulters_bloom_two.rename(columns={'adjusted_global_limit':'second_adjusted_global_limit', 'final_global_limit':'second_final_global_limit'})
current_defaulters_bloom_two['second_adjusted_global_limit'] = current_defaulters_bloom_two['second_adjusted_global_limit'].fillna(0)
current_defaulters_bloom_two['second_final_global_limit'] = current_defaulters_bloom_two['second_final_global_limit'].fillna(0)

current_defaulters_bloom_two = pd.merge(current_defaulters_bloom_two, current_refresh, on = 'store_number', how = 'left')
current_defaulters_bloom_two = current_defaulters_bloom_two.rename(columns={'adjusted_global_limit':'current_adjusted_global_limit', 'final_global_limit':'current_final_global_limit'})
current_defaulters_bloom_two['current_adjusted_global_limit'] = current_defaulters_bloom_two['current_adjusted_global_limit'].fillna(0)
current_defaulters_bloom_two['current_final_global_limit'] = current_defaulters_bloom_two['current_final_global_limit'].fillna(0)

#current_defaulters_bloom_two["adjusted_global_limit"] = current_defaulters_bloom_two[["adjusted_21_limit", "adjusted_7_limit", "adjusted_1_limit"]].max(axis=1)
#current_defaulters_bloom_two["final_global_limit"] = current_defaulters_bloom_two[["final_21_limit", "final_7_limit", "final_1_limit"]].max(axis=1)

current_defaulters_bloom_two.head()
# Out:
#    loan_mifos_id store_number  loan_status  term_frequency  \
# 0          86961      7803525          300               1
# 1          87075       916139          300              21
# 2          87171       772622          300               1
# 3          87286      7801651          300              21
# 4          87291      7965219          300               7
#
#    principal_disbursed  principal_outstanding  interest_outstanding  \
# 0              2800.00                2800.00                 11.20
# 1              3300.00                3300.00                250.81
# 2              5700.00                  88.35                  0.00
# 3             28400.00                 595.77                  0.00
# 4              1200.00                 959.92                  0.00
#
#    fee_charges_charged  fee_charges_outstanding  penalty_charges_charged  \
# 0                21.00                    21.00                   915.06
# 1                49.50                    49.50                  1504.78
# 2                42.75                     0.00                    45.60
# 3               426.00                     0.00                   180.40
# 4                30.00                     0.00                   427.51
#
#    penalty_charges_outstanding  total_expected_repayment  total_repayment  \
# 0                       847.86                   3747.26            67.20
# 1                      1425.58                   5105.09            79.20
# 2                         0.00                   5811.15          5722.80
# 3                         0.00                  31164.81         30569.04
# 4                         0.00                   1688.72           728.80
#
#    total_outstanding  safaricom_loan_balance  bloom_version disbursed_on_date  \
# 0            3680.06                 3680.06           2.00        2022-05-06
# 1            5025.89                 5025.89           2.00        2022-05-06
# 2              88.35                   88.35           2.00        2022-05-06
# 3             595.77                  595.77           2.00        2022-05-06
# 4             959.92                  959.92           2.00        2022-05-06
#
#   expected_matured_on_date end_rollvr_dt      dpd_30     dpd_d60     dpd_d90  \
# 0               2022-05-07    2022-05-08  2022-06-07  2022-07-07  2022-08-06
# 1               2022-05-27    2022-06-01  2022-07-01  2022-07-31  2022-08-30
# 2               2022-05-07    2022-05-08  2022-06-07  2022-07-07  2022-08-06
# 3               2022-05-27    2022-06-01  2022-07-01  2022-07-31  2022-08-30
# 4               2022-05-13    2022-05-16  2022-06-15  2022-07-15  2022-08-14
#
#    loan_count Loan Count Flag  defaulters_bloom_two_count  \
# 0        1.00      New Client                           1
# 1       12.00   Repeat Client                           2
# 2       87.00   Repeat Client                           6
# 3       15.00   Repeat Client                           7
# 4        1.00      New Client                           1
#
#                    Default Flag  \
# 0       Bloom Two First Default
# 1  Bloom Two Subsequent Default
# 2  Bloom Two Subsequent Default
# 3  Bloom Two Subsequent Default
# 4       Bloom Two First Default
#
#                       First Limit Reductions Flag  \
# 0  Default occurred before first limit reductions
# 1  Default occurred before first limit reductions
# 2  Default occurred before first limit reductions
# 3  Default occurred before first limit reductions
# 4  Default occurred before first limit reductions
#
#                       Second Limit Reductions Flag saf_loan_balance  \
# 0  Default occurred before second limit reductions              yes
# 1  Default occurred before second limit reductions              yes
# 2  Default occurred before second limit reductions              yes
# 3  Default occurred before second limit reductions              yes
# 4  Default occurred before second limit reductions              yes
#
#    loan_balance  first_adjusted_global_limit  first_final_global_limit  \
# 0       3680.06                         0.00                      0.00
# 1       5025.89                         0.00                      0.00
# 2         88.35                     16200.00                   5000.00
# 3        595.77                     37000.00                  26800.00
# 4        959.92                         0.00                      0.00
#
#    second_adjusted_global_limit  second_final_global_limit  \
# 0                          0.00                       0.00
# 1                          0.00                       0.00
# 2                      20400.00                       0.00
# 3                      55700.00                       0.00
# 4                          0.00                       0.00
#
#    current_adjusted_global_limit  current_final_global_limit
# 0                           0.00                        0.00
# 1                           0.00                        0.00
# 2                           0.00                        0.00
# 3                           0.00                        0.00
# 4                           0.00                        0.00

# %%
current_defaulters_bloom_two.shape
# Out:
# (20051, 36)

# %%
current_defaulters_bloom_two[['first_adjusted_global_limit', 'first_final_global_limit', 'second_adjusted_global_limit', 'second_final_global_limit', 'current_adjusted_global_limit', 'current_final_global_limit']].sum()
# Out:
# first_adjusted_global_limit     294487900.00
# first_final_global_limit        178210600.00
# second_adjusted_global_limit    294528600.00
# second_final_global_limit        60490900.00
# current_adjusted_global_limit   179870100.00
# current_final_global_limit       33999900.00
# dtype: float64

# %%
def calc_first_zeroized(df):
    
    first_adjusted_global_limit = df['first_adjusted_global_limit']
    first_final_global_limit = df['first_final_global_limit']
    
    if first_final_global_limit == 0 and first_adjusted_global_limit > 0:
        return 'first zeroized'
    else:
        return 'first not zeroized'
    
    
def calc_second_zeroized(df):
    
    second_adjusted_global_limit = df['second_adjusted_global_limit']
    second_final_global_limit = df['second_final_global_limit']
    
    if second_final_global_limit == 0 and second_adjusted_global_limit > 0:
        return 'second zeroized'
    else:
        return 'second not zeroized'

# %%
current_defaulters_bloom_two['first zeroized'] = current_defaulters_bloom_two.apply(lambda x: calc_first_zeroized(x), axis = 1)
current_defaulters_bloom_two['second zeroized'] = current_defaulters_bloom_two.apply(lambda x: calc_second_zeroized(x), axis = 1)


current_defaulters_bloom_two.head(5)
# Out:
#    loan_mifos_id store_number  loan_status  term_frequency  \
# 0          86961      7803525          300               1
# 1          87075       916139          300              21
# 2          87171       772622          300               1
# 3          87286      7801651          300              21
# 4          87291      7965219          300               7
#
#    principal_disbursed  principal_outstanding  interest_outstanding  \
# 0              2800.00                2800.00                 11.20
# 1              3300.00                3300.00                250.81
# 2              5700.00                  88.35                  0.00
# 3             28400.00                 595.77                  0.00
# 4              1200.00                 959.92                  0.00
#
#    fee_charges_charged  fee_charges_outstanding  penalty_charges_charged  \
# 0                21.00                    21.00                   915.06
# 1                49.50                    49.50                  1504.78
# 2                42.75                     0.00                    45.60
# 3               426.00                     0.00                   180.40
# 4                30.00                     0.00                   427.51
#
#    penalty_charges_outstanding  total_expected_repayment  total_repayment  \
# 0                       847.86                   3747.26            67.20
# 1                      1425.58                   5105.09            79.20
# 2                         0.00                   5811.15          5722.80
# 3                         0.00                  31164.81         30569.04
# 4                         0.00                   1688.72           728.80
#
#    total_outstanding  safaricom_loan_balance  bloom_version disbursed_on_date  \
# 0            3680.06                 3680.06           2.00        2022-05-06
# 1            5025.89                 5025.89           2.00        2022-05-06
# 2              88.35                   88.35           2.00        2022-05-06
# 3             595.77                  595.77           2.00        2022-05-06
# 4             959.92                  959.92           2.00        2022-05-06
#
#   expected_matured_on_date end_rollvr_dt      dpd_30     dpd_d60     dpd_d90  \
# 0               2022-05-07    2022-05-08  2022-06-07  2022-07-07  2022-08-06
# 1               2022-05-27    2022-06-01  2022-07-01  2022-07-31  2022-08-30
# 2               2022-05-07    2022-05-08  2022-06-07  2022-07-07  2022-08-06
# 3               2022-05-27    2022-06-01  2022-07-01  2022-07-31  2022-08-30
# 4               2022-05-13    2022-05-16  2022-06-15  2022-07-15  2022-08-14
#
#    loan_count Loan Count Flag  defaulters_bloom_two_count  \
# 0        1.00      New Client                           1
# 1       12.00   Repeat Client                           2
# 2       87.00   Repeat Client                           6
# 3       15.00   Repeat Client                           7
# 4        1.00      New Client                           1
#
#                    Default Flag  \
# 0       Bloom Two First Default
# 1  Bloom Two Subsequent Default
# 2  Bloom Two Subsequent Default
# 3  Bloom Two Subsequent Default
# 4       Bloom Two First Default
#
#                       First Limit Reductions Flag  \
# 0  Default occurred before first limit reductions
# 1  Default occurred before first limit reductions
# 2  Default occurred before first limit reductions
# 3  Default occurred before first limit reductions
# 4  Default occurred before first limit reductions
#
#                       Second Limit Reductions Flag saf_loan_balance  \
# 0  Default occurred before second limit reductions              yes
# 1  Default occurred before second limit reductions              yes
# 2  Default occurred before second limit reductions              yes
# 3  Default occurred before second limit reductions              yes
# 4  Default occurred before second limit reductions              yes
#
#    loan_balance  first_adjusted_global_limit  first_final_global_limit  \
# 0       3680.06                         0.00                      0.00
# 1       5025.89                         0.00                      0.00
# 2         88.35                     16200.00                   5000.00
# 3        595.77                     37000.00                  26800.00
# 4        959.92                         0.00                      0.00
#
#    second_adjusted_global_limit  second_final_global_limit  \
# 0                          0.00                       0.00
# 1                          0.00                       0.00
# 2                      20400.00                       0.00
# 3                      55700.00                       0.00
# 4                          0.00                       0.00
#
#    current_adjusted_global_limit  current_final_global_limit  \
# 0                           0.00                        0.00
# 1                           0.00                        0.00
# 2                           0.00                        0.00
# 3                           0.00                        0.00
# 4                           0.00                        0.00
#
#        first zeroized      second zeroized
# 0  first not zeroized  second not zeroized
# 1  first not zeroized  second not zeroized
# 2  first not zeroized      second zeroized
# 3  first not zeroized      second zeroized
# 4  first not zeroized  second not zeroized

# %%
current_defaulters_bloom_two[current_defaulters_bloom_two['second_adjusted_global_limit'] > current_defaulters_bloom_two['loan_balance']]
# Out:
#        loan_mifos_id store_number  loan_status  term_frequency  \
# 2              87171       772622          300               1
# 3              87286      7801651          300              21
# 8             155623      7186034          300               1
# 12             87296      7148467          300               7
# 44             45895      7273381          300               7
# ...              ...          ...          ...             ...
# 20017          58744       854851          300              21
# 20020          86973       619121          300              21
# 20021          86987       442317          300              21
# 20025          88593      7918597          300              21
# 20031          30447       786841          300               7
#
#        principal_disbursed  principal_outstanding  interest_outstanding  \
# 2                  5700.00                  88.35                  0.00
# 3                 28400.00                 595.77                  0.00
# 8                 20900.00                1766.93                  0.00
# 12                23000.00                 297.72                  0.00
# 44                 6700.00                6700.00                174.21
# ...                    ...                    ...                   ...
# 20017             19400.00                 422.70                  0.00
# 20020             17600.00                 369.39                  0.00
# 20021             30000.00                 629.32                  0.00
# 20025            160000.00                2561.61                  0.00
# 20031              1800.00                1800.00                 61.21
#
#        fee_charges_charged  fee_charges_outstanding  penalty_charges_charged  \
# 2                    42.75                     0.00                    45.60
# 3                   426.00                     0.00                   180.40
# 8                   156.75                     0.00                  1610.18
# 12                  575.00                     0.00                    73.46
# 44                   13.02                    13.02                  1969.80
# ...                    ...                      ...                      ...
# 20017               349.37                     0.00                    82.67
# 20020               264.00                     0.00                   110.32
# 20021               450.00                     0.00                   190.55
# 20025              1832.41                     0.00                   774.86
# 20031                62.13                    62.13                   475.20
#
#        penalty_charges_outstanding  total_expected_repayment  total_repayment  \
# 2                             0.00                   5811.15          5722.80
# 3                             0.00                  31164.81         30569.04
# 8                             0.00                  22750.53         20983.60
# 12                            0.00                  24246.47         23948.75
# 44                         1728.60                   8857.03           241.20
# ...                            ...                       ...              ...
# 20017                         0.00                  21306.45         20883.75
# 20020                         0.00                  19311.93         18942.54
# 20021                         0.00                  32920.56         32291.24
# 20025                         0.00                 174767.28        172205.67
# 20031                       475.20                   2398.54             0.00
#
#        total_outstanding  safaricom_loan_balance  bloom_version  \
# 2                  88.35                   88.35           2.00
# 3                 595.77                  595.77           2.00
# 8                1766.93                 1766.93           2.00
# 12                297.72                  297.72           2.00
# 44               8615.83                 8615.83           2.00
# ...                  ...                     ...            ...
# 20017             422.70                  422.70           2.00
# 20020             369.39                  369.39           2.00
# 20021             629.32                  629.32           2.00
# 20025            2561.61                 2561.61           2.00
# 20031            2398.54                 2398.54           2.00
#
#       disbursed_on_date expected_matured_on_date end_rollvr_dt      dpd_30  \
# 2            2022-05-06               2022-05-07    2022-05-08  2022-06-07
# 3            2022-05-06               2022-05-27    2022-06-01  2022-07-01
# 8            2022-07-07               2022-07-08    2022-07-09  2022-08-08
# 12           2022-05-06               2022-05-13    2022-05-16  2022-06-15
# 44           2022-03-18               2022-03-25    2022-03-28  2022-04-27
# ...                 ...                      ...           ...         ...
# 20017        2022-04-02               2022-04-23    2022-04-28  2022-05-28
# 20020        2022-05-06               2022-05-27    2022-06-01  2022-07-01
# 20021        2022-05-06               2022-05-27    2022-06-01  2022-07-01
# 20025        2022-05-06               2022-05-27    2022-06-01  2022-07-01
# 20031        2022-02-19               2022-02-26    2022-03-01  2022-03-31
#
#           dpd_d60     dpd_d90  loan_count Loan Count Flag  \
# 2      2022-07-07  2022-08-06       87.00   Repeat Client
# 3      2022-07-31  2022-08-30       15.00   Repeat Client
# 8      2022-09-07  2022-10-07       16.00   Repeat Client
# 12     2022-07-15  2022-08-14       15.00   Repeat Client
# 44     2022-05-27  2022-06-26        1.00      New Client
# ...           ...         ...         ...             ...
# 20017  2022-06-27  2022-07-27       26.00   Repeat Client
# 20020  2022-07-31  2022-08-30       36.00   Repeat Client
# 20021  2022-07-31  2022-08-30       48.00   Repeat Client
# 20025  2022-07-31  2022-08-30       14.00   Repeat Client
# 20031  2022-04-30  2022-05-30        1.00      New Client
#
#        defaulters_bloom_two_count                  Default Flag  \
# 2                               6  Bloom Two Subsequent Default
# 3                               7  Bloom Two Subsequent Default
# 8                               2  Bloom Two Subsequent Default
# 12                              2  Bloom Two Subsequent Default
# 44                              1       Bloom Two First Default
# ...                           ...                           ...
# 20017                           2  Bloom Two Subsequent Default
# 20020                           6  Bloom Two Subsequent Default
# 20021                           1       Bloom Two First Default
# 20025                           6  Bloom Two Subsequent Default
# 20031                           1       Bloom Two First Default
#
#                           First Limit Reductions Flag  \
# 2      Default occurred before first limit reductions
# 3      Default occurred before first limit reductions
# 8      Default occurred before first limit reductions
# 12     Default occurred before first limit reductions
# 44     Default occurred before first limit reductions
# ...                                               ...
# 20017  Default occurred before first limit reductions
# 20020  Default occurred before first limit reductions
# 20021  Default occurred before first limit reductions
# 20025  Default occurred before first limit reductions
# 20031  Default occurred before first limit reductions
#
#                           Second Limit Reductions Flag saf_loan_balance  \
# 2      Default occurred before second limit reductions              yes
# 3      Default occurred before second limit reductions              yes
# 8      Default occurred before second limit reductions              yes
# 12     Default occurred before second limit reductions              yes
# 44     Default occurred before second limit reductions              yes
# ...                                                ...              ...
# 20017  Default occurred before second limit reductions              yes
# 20020  Default occurred before second limit reductions              yes
# 20021  Default occurred before second limit reductions              yes
# 20025  Default occurred before second limit reductions              yes
# 20031  Default occurred before second limit reductions              yes
#
#        loan_balance  first_adjusted_global_limit  first_final_global_limit  \
# 2             88.35                     16200.00                   5000.00
# 3            595.77                     37000.00                  26800.00
# 8           1766.93                     80200.00                      0.00
# 12           297.72                     41800.00                  41800.00
# 44          8615.83                     14100.00                   6300.00
# ...             ...                          ...                       ...
# 20017        422.70                      7100.00                   7100.00
# 20020        369.39                     18900.00                  18900.00
# 20021        629.32                     23700.00                  11000.00
# 20025       2561.61                    142800.00                 142800.00
# 20031       2398.54                      3600.00                   1600.00
#
#        second_adjusted_global_limit  second_final_global_limit  \
# 2                          20400.00                       0.00
# 3                          55700.00                       0.00
# 8                          66800.00                       0.00
# 12                         44000.00                       0.00
# 44                         13400.00                       0.00
# ...                             ...                        ...
# 20017                       7100.00                       0.00
# 20020                      17300.00                       0.00
# 20021                      28600.00                   11000.00
# 20025                      92800.00                       0.00
# 20031                       3300.00                       0.00
#
#        current_adjusted_global_limit  current_final_global_limit  \
# 2                               0.00                        0.00
# 3                               0.00                        0.00
# 8                          165900.00                        0.00
# 12                          72300.00                        0.00
# 44                          13800.00                        0.00
# ...                              ...                         ...
# 20017                        6300.00                        0.00
# 20020                       20100.00                    17700.00
# 20021                       33900.00                    28700.00
# 20025                           0.00                        0.00
# 20031                           0.00                        0.00
#
#            first zeroized      second zeroized
# 2      first not zeroized      second zeroized
# 3      first not zeroized      second zeroized
# 8          first zeroized      second zeroized
# 12     first not zeroized      second zeroized
# 44     first not zeroized      second zeroized
# ...                   ...                  ...
# 20017  first not zeroized      second zeroized
# 20020  first not zeroized      second zeroized
# 20021  first not zeroized  second not zeroized
# 20025  first not zeroized      second zeroized
# 20031  first not zeroized      second zeroized
#
# [3353 rows x 38 columns]

# %%
def calc_first_balance_limit_flag(df):
    
    loan_balance = df['loan_balance']
    first_adjusted_global_limit = df['first_adjusted_global_limit']
    
    if first_adjusted_global_limit < loan_balance:
        return 'Lower than balance'
    elif first_adjusted_global_limit > loan_balance:
        return 'Higher than balance'
    elif loan_balance == first_adjusted_global_limit:
        return 'Equal Balances'
    

def calc_second_balance_limit_flag(df):
    
    loan_balance = df['loan_balance']
    second_adjusted_global_limit = df['second_adjusted_global_limit']
    
    if second_adjusted_global_limit < loan_balance:
        return 'Lower than balance'
    elif second_adjusted_global_limit > loan_balance:
        return 'Higher than balance'
    elif loan_balance == second_adjusted_global_limit:
        return 'Equal Balances'

# %%
current_defaulters_bloom_two['first_balance_limit_flag'] = current_defaulters_bloom_two.apply(lambda x: calc_first_balance_limit_flag(x), axis = 1)
current_defaulters_bloom_two['second_balance_limit_flag'] = current_defaulters_bloom_two.apply(lambda x: calc_second_balance_limit_flag(x), axis = 1)


current_defaulters_bloom_two.head(5)
# Out:
#    loan_mifos_id store_number  loan_status  term_frequency  \
# 0          86961      7803525          300               1
# 1          87075       916139          300              21
# 2          87171       772622          300               1
# 3          87286      7801651          300              21
# 4          87291      7965219          300               7
#
#    principal_disbursed  principal_outstanding  interest_outstanding  \
# 0              2800.00                2800.00                 11.20
# 1              3300.00                3300.00                250.81
# 2              5700.00                  88.35                  0.00
# 3             28400.00                 595.77                  0.00
# 4              1200.00                 959.92                  0.00
#
#    fee_charges_charged  fee_charges_outstanding  penalty_charges_charged  \
# 0                21.00                    21.00                   915.06
# 1                49.50                    49.50                  1504.78
# 2                42.75                     0.00                    45.60
# 3               426.00                     0.00                   180.40
# 4                30.00                     0.00                   427.51
#
#    penalty_charges_outstanding  total_expected_repayment  total_repayment  \
# 0                       847.86                   3747.26            67.20
# 1                      1425.58                   5105.09            79.20
# 2                         0.00                   5811.15          5722.80
# 3                         0.00                  31164.81         30569.04
# 4                         0.00                   1688.72           728.80
#
#    total_outstanding  safaricom_loan_balance  bloom_version disbursed_on_date  \
# 0            3680.06                 3680.06           2.00        2022-05-06
# 1            5025.89                 5025.89           2.00        2022-05-06
# 2              88.35                   88.35           2.00        2022-05-06
# 3             595.77                  595.77           2.00        2022-05-06
# 4             959.92                  959.92           2.00        2022-05-06
#
#   expected_matured_on_date end_rollvr_dt      dpd_30     dpd_d60     dpd_d90  \
# 0               2022-05-07    2022-05-08  2022-06-07  2022-07-07  2022-08-06
# 1               2022-05-27    2022-06-01  2022-07-01  2022-07-31  2022-08-30
# 2               2022-05-07    2022-05-08  2022-06-07  2022-07-07  2022-08-06
# 3               2022-05-27    2022-06-01  2022-07-01  2022-07-31  2022-08-30
# 4               2022-05-13    2022-05-16  2022-06-15  2022-07-15  2022-08-14
#
#    loan_count Loan Count Flag  defaulters_bloom_two_count  \
# 0        1.00      New Client                           1
# 1       12.00   Repeat Client                           2
# 2       87.00   Repeat Client                           6
# 3       15.00   Repeat Client                           7
# 4        1.00      New Client                           1
#
#                    Default Flag  \
# 0       Bloom Two First Default
# 1  Bloom Two Subsequent Default
# 2  Bloom Two Subsequent Default
# 3  Bloom Two Subsequent Default
# 4       Bloom Two First Default
#
#                       First Limit Reductions Flag  \
# 0  Default occurred before first limit reductions
# 1  Default occurred before first limit reductions
# 2  Default occurred before first limit reductions
# 3  Default occurred before first limit reductions
# 4  Default occurred before first limit reductions
#
#                       Second Limit Reductions Flag saf_loan_balance  \
# 0  Default occurred before second limit reductions              yes
# 1  Default occurred before second limit reductions              yes
# 2  Default occurred before second limit reductions              yes
# 3  Default occurred before second limit reductions              yes
# 4  Default occurred before second limit reductions              yes
#
#    loan_balance  first_adjusted_global_limit  first_final_global_limit  \
# 0       3680.06                         0.00                      0.00
# 1       5025.89                         0.00                      0.00
# 2         88.35                     16200.00                   5000.00
# 3        595.77                     37000.00                  26800.00
# 4        959.92                         0.00                      0.00
#
#    second_adjusted_global_limit  second_final_global_limit  \
# 0                          0.00                       0.00
# 1                          0.00                       0.00
# 2                      20400.00                       0.00
# 3                      55700.00                       0.00
# 4                          0.00                       0.00
#
#    current_adjusted_global_limit  current_final_global_limit  \
# 0                           0.00                        0.00
# 1                           0.00                        0.00
# 2                           0.00                        0.00
# 3                           0.00                        0.00
# 4                           0.00                        0.00
#
#        first zeroized      second zeroized first_balance_limit_flag  \
# 0  first not zeroized  second not zeroized       Lower than balance
# 1  first not zeroized  second not zeroized       Lower than balance
# 2  first not zeroized      second zeroized      Higher than balance
# 3  first not zeroized      second zeroized      Higher than balance
# 4  first not zeroized  second not zeroized       Lower than balance
#
#   second_balance_limit_flag
# 0        Lower than balance
# 1        Lower than balance
# 2       Higher than balance
# 3       Higher than balance
# 4        Lower than balance

# %%
current_defaulters_bloom_two = current_defaulters_bloom_two.sort_values(by = 'disbursed_on_date')

current_defaulters_bloom_two = current_defaulters_bloom_two.drop_duplicates(subset=['store_number'], keep='last')

current_defaulters_bloom_two.head()
# Out:
#        loan_mifos_id store_number  loan_status  term_frequency  \
# 1005            3699       735346          300               7
# 2139            3749       438125          300              21
# 1099            3760       970016          300              21
# 19780           3768       583528          300              21
# 19815           3757       913867          300              21
#
#        principal_disbursed  principal_outstanding  interest_outstanding  \
# 1005                150.00                 150.00                  5.09
# 2139               8000.00                8000.00                695.47
# 1099              80000.00               80000.00               6954.74
# 19780             31000.00               31000.00               2694.96
# 19815              7500.00                7500.00                652.01
#
#        fee_charges_charged  fee_charges_outstanding  penalty_charges_charged  \
# 1005                  0.00                     0.00                    20.40
# 2139                434.80                   434.80                  2736.00
# 1099               4348.00                  4348.00                 27840.00
# 19780              1684.85                  1684.85                 11036.00
# 19815               407.63                   407.63                  2670.00
#
#        penalty_charges_outstanding  total_expected_repayment  total_repayment  \
# 1005                         20.40                    175.49             0.00
# 2139                       2736.00                  11866.27             0.00
# 1099                      24840.00                 119142.74          3000.00
# 19780                     11036.00                  46415.81             0.00
# 19815                      2670.00                  11229.64             0.00
#
#        total_outstanding  safaricom_loan_balance  bloom_version  \
# 1005              175.49                  175.49           2.00
# 2139            11866.27                11866.27           2.00
# 1099           116142.74               116142.74           2.00
# 19780           46415.81                46415.81           2.00
# 19815           11229.64                11229.64           2.00
#
#       disbursed_on_date expected_matured_on_date end_rollvr_dt      dpd_30  \
# 1005         2021-11-05               2021-11-12    2021-11-15  2021-12-15
# 2139         2021-11-11               2021-12-02    2021-12-07  2022-01-06
# 1099         2021-11-12               2021-12-03    2021-12-08  2022-01-07
# 19780        2021-11-12               2021-12-03    2021-12-08  2022-01-07
# 19815        2021-11-12               2021-12-03    2021-12-08  2022-01-07
#
#           dpd_d60     dpd_d90  loan_count Loan Count Flag  \
# 1005   2022-01-14  2022-02-13      100.00   Repeat Client
# 2139   2022-02-05  2022-03-07        6.00   Repeat Client
# 1099   2022-02-06  2022-03-08        2.00   Repeat Client
# 19780  2022-02-06  2022-03-08        8.00   Repeat Client
# 19815  2022-02-06  2022-03-08       10.00   Repeat Client
#
#        defaulters_bloom_two_count                  Default Flag  \
# 1005                           10  Bloom Two Subsequent Default
# 2139                            1       Bloom Two First Default
# 1099                            1       Bloom Two First Default
# 19780                           1       Bloom Two First Default
# 19815                           1       Bloom Two First Default
#
#                           First Limit Reductions Flag  \
# 1005   Default occurred before first limit reductions
# 2139   Default occurred before first limit reductions
# 1099   Default occurred before first limit reductions
# 19780  Default occurred before first limit reductions
# 19815  Default occurred before first limit reductions
#
#                           Second Limit Reductions Flag saf_loan_balance  \
# 1005   Default occurred before second limit reductions              yes
# 2139   Default occurred before second limit reductions              yes
# 1099   Default occurred before second limit reductions              yes
# 19780  Default occurred before second limit reductions              yes
# 19815  Default occurred before second limit reductions              yes
#
#        loan_balance  first_adjusted_global_limit  first_final_global_limit  \
# 1005         175.49                         0.00                      0.00
# 2139       11866.27                         0.00                      0.00
# 1099      116142.74                         0.00                      0.00
# 19780      46415.81                         0.00                      0.00
# 19815      11229.64                         0.00                      0.00
#
#        second_adjusted_global_limit  second_final_global_limit  \
# 1005                           0.00                       0.00
# 2139                           0.00                       0.00
# 1099                           0.00                       0.00
# 19780                          0.00                       0.00
# 19815                          0.00                       0.00
#
#        current_adjusted_global_limit  current_final_global_limit  \
# 1005                            0.00                        0.00
# 2139                            0.00                        0.00
# 1099                        44800.00                        0.00
# 19780                           0.00                        0.00
# 19815                           0.00                        0.00
#
#            first zeroized      second zeroized first_balance_limit_flag  \
# 1005   first not zeroized  second not zeroized       Lower than balance
# 2139   first not zeroized  second not zeroized       Lower than balance
# 1099   first not zeroized  second not zeroized       Lower than balance
# 19780  first not zeroized  second not zeroized       Lower than balance
# 19815  first not zeroized  second not zeroized       Lower than balance
#
#       second_balance_limit_flag
# 1005         Lower than balance
# 2139         Lower than balance
# 1099         Lower than balance
# 19780        Lower than balance
# 19815        Lower than balance

# %%
current_defaulters_bloom_two = current_defaulters_bloom_two[['store_number', 'Loan Count Flag', 'Default Flag', 'First Limit Reductions Flag', 'Second Limit Reductions Flag', 'total_outstanding', 'safaricom_loan_balance', 'loan_balance', 'first_adjusted_global_limit', 'first_final_global_limit', 'second_adjusted_global_limit', 'second_final_global_limit', 'current_adjusted_global_limit', 'second_final_global_limit', 'second_final_global_limit', 'first zeroized', 'second zeroized', 'first_balance_limit_flag', 'second_balance_limit_flag']]

current_defaulters_bloom_two.head()
# Out:
#       store_number Loan Count Flag                  Default Flag  \
# 1005        735346   Repeat Client  Bloom Two Subsequent Default
# 2139        438125   Repeat Client       Bloom Two First Default
# 1099        970016   Repeat Client       Bloom Two First Default
# 19780       583528   Repeat Client       Bloom Two First Default
# 19815       913867   Repeat Client       Bloom Two First Default
#
#                           First Limit Reductions Flag  \
# 1005   Default occurred before first limit reductions
# 2139   Default occurred before first limit reductions
# 1099   Default occurred before first limit reductions
# 19780  Default occurred before first limit reductions
# 19815  Default occurred before first limit reductions
#
#                           Second Limit Reductions Flag  total_outstanding  \
# 1005   Default occurred before second limit reductions             175.49
# 2139   Default occurred before second limit reductions           11866.27
# 1099   Default occurred before second limit reductions          116142.74
# 19780  Default occurred before second limit reductions           46415.81
# 19815  Default occurred before second limit reductions           11229.64
#
#        safaricom_loan_balance  loan_balance  first_adjusted_global_limit  \
# 1005                   175.49        175.49                         0.00
# 2139                 11866.27      11866.27                         0.00
# 1099                116142.74     116142.74                         0.00
# 19780                46415.81      46415.81                         0.00
# 19815                11229.64      11229.64                         0.00
#
#        first_final_global_limit  second_adjusted_global_limit  \
# 1005                       0.00                          0.00
# 2139                       0.00                          0.00
# 1099                       0.00                          0.00
# 19780                      0.00                          0.00
# 19815                      0.00                          0.00
#
#        second_final_global_limit  current_adjusted_global_limit  \
# 1005                        0.00                           0.00
# 2139                        0.00                           0.00
# 1099                        0.00                       44800.00
# 19780                       0.00                           0.00
# 19815                       0.00                           0.00
#
#        second_final_global_limit  second_final_global_limit  \
# 1005                        0.00                       0.00
# 2139                        0.00                       0.00
# 1099                        0.00                       0.00
# 19780                       0.00                       0.00
# 19815                       0.00                       0.00
#
#            first zeroized      second zeroized first_balance_limit_flag  \
# 1005   first not zeroized  second not zeroized       Lower than balance
# 2139   first not zeroized  second not zeroized       Lower than balance
# 1099   first not zeroized  second not zeroized       Lower than balance
# 19780  first not zeroized  second not zeroized       Lower than balance
# 19815  first not zeroized  second not zeroized       Lower than balance
#
#       second_balance_limit_flag
# 1005         Lower than balance
# 2139         Lower than balance
# 1099         Lower than balance
# 19780        Lower than balance
# 19815        Lower than balance

# %%
current_defaulters_bloom_two['store_number'].nunique()
# Out:
# 19740

# %%
current_defaulters_bloom_two.shape
# Out:
# (19740, 19)

# %%
current_defaulters_bloom_two['first_balance_limit_flag'].value_counts()
# Out:
# Lower than balance     16631
# Higher than balance     3109
# Name: first_balance_limit_flag, dtype: int64

# %%
first_batch = current_defaulters_bloom_two[(current_defaulters_bloom_two['Default Flag'] == 'Bloom Two First Default') & (current_defaulters_bloom_two['First Limit Reductions Flag'] == 'Default occurred after first limit reductions') & (current_defaulters_bloom_two['first_balance_limit_flag'] == 'Lower than balance') & (current_defaulters_bloom_two['first zeroized'] == 'first zeroized')]

first_batch = first_batch[['store_number', 'Loan Count Flag', 'Default Flag', 'First Limit Reductions Flag', 'loan_balance', 'first_adjusted_global_limit', 'first_final_global_limit', 'current_adjusted_global_limit', 'first zeroized', 'first_balance_limit_flag']]

first_batch.head()
# Out:
#      store_number Loan Count Flag             Default Flag  \
# 5264      7187782   Repeat Client  Bloom Two First Default
# 5578      7343046   Repeat Client  Bloom Two First Default
# 4469      7057564   Repeat Client  Bloom Two First Default
# 8647      7072094   Repeat Client  Bloom Two First Default
# 9786      7184468   Repeat Client  Bloom Two First Default
#
#                         First Limit Reductions Flag  loan_balance  \
# 5264  Default occurred after first limit reductions      10973.33
# 5578  Default occurred after first limit reductions      37699.62
# 4469  Default occurred after first limit reductions       6761.95
# 8647  Default occurred after first limit reductions      14217.48
# 9786  Default occurred after first limit reductions     286231.88
#
#       first_adjusted_global_limit  first_final_global_limit  \
# 5264                       100.00                      0.00
# 5578                     13800.00                      0.00
# 4469                      5000.00                      0.00
# 8647                     11600.00                      0.00
# 9786                     12800.00                      0.00
#
#       current_adjusted_global_limit  first zeroized first_balance_limit_flag
# 5264                           0.00  first zeroized       Lower than balance
# 5578                           0.00  first zeroized       Lower than balance
# 4469                        2500.00  first zeroized       Lower than balance
# 8647                           0.00  first zeroized       Lower than balance
# 9786                           0.00  first zeroized       Lower than balance

# %%
first_batch.shape
# Out:
# (51, 10)

# %%
first_batch.to_excel('First Batch Defaulters.xlsx')

# %%
second_batch = current_defaulters_bloom_two[(current_defaulters_bloom_two['Default Flag'] == 'Bloom Two First Default') & (current_defaulters_bloom_two['Second Limit Reductions Flag'] == 'Default occurred after second limit reductions') & (current_defaulters_bloom_two['second_balance_limit_flag'] == 'Lower than balance') & (current_defaulters_bloom_two['second zeroized'] == 'second zeroized')]

second_batch = second_batch[['store_number', 'Loan Count Flag', 'Default Flag', 'Second Limit Reductions Flag', 'loan_balance', 'second_adjusted_global_limit', 'second_final_global_limit', 'current_adjusted_global_limit', 'second zeroized', 'second_balance_limit_flag']]

second_batch.head()
# Out:
#       store_number Loan Count Flag             Default Flag  \
# 15187      7321104   Repeat Client  Bloom Two First Default
# 3989       7759217   Repeat Client  Bloom Two First Default
# 8207       7565981   Repeat Client  Bloom Two First Default
# 9990       7484507   Repeat Client  Bloom Two First Default
# 15088      7898485   Repeat Client  Bloom Two First Default
#
#                          Second Limit Reductions Flag  loan_balance  \
# 15187  Default occurred after second limit reductions      14983.62
# 3989   Default occurred after second limit reductions      16516.03
# 8207   Default occurred after second limit reductions      14660.42
# 9990   Default occurred after second limit reductions      74165.06
# 15088  Default occurred after second limit reductions      11932.88
#
#        second_adjusted_global_limit  second_final_global_limit  \
# 15187                       4200.00                       0.00
# 3989                        6700.00                       0.00
# 8207                        8700.00                       0.00
# 9990                       34900.00                       0.00
# 15088                       3200.00                       0.00
#
#        second_final_global_limit  second_final_global_limit  \
# 15187                       0.00                       0.00
# 3989                        0.00                       0.00
# 8207                        0.00                       0.00
# 9990                        0.00                       0.00
# 15088                       0.00                       0.00
#
#        current_adjusted_global_limit  second zeroized  \
# 15187                           0.00  second zeroized
# 3989                            0.00  second zeroized
# 8207                            0.00  second zeroized
# 9990                            0.00  second zeroized
# 15088                           0.00  second zeroized
#
#       second_balance_limit_flag
# 15187        Lower than balance
# 3989         Lower than balance
# 8207         Lower than balance
# 9990         Lower than balance
# 15088        Lower than balance

# %%
second_batch.to_excel('Second Batch Defaulters.xlsx')

# %%
second_batch.shape
# Out:
# (147, 12)

# %%
current_defaulters_bloom_two.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19740 entries, 1005 to 9793
# Data columns (total 19 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   store_number                   19740 non-null  object
#  1   Loan Count Flag                19740 non-null  object
#  2   Default Flag                   19740 non-null  object
#  3   First Limit Reductions Flag    19740 non-null  object
#  4   Second Limit Reductions Flag   19740 non-null  object
#  5   total_outstanding              19740 non-null  float64
#  6   safaricom_loan_balance         19740 non-null  float64
#  7   loan_balance                   19740 non-null  float64
#  8   first_adjusted_global_limit    19740 non-null  float64
#  9   first_final_global_limit       19740 non-null  float64
#  10  second_adjusted_global_limit   19740 non-null  float64
#  11  second_final_global_limit      19740 non-null  float64
#  12  current_adjusted_global_limit  19740 non-null  float64
#  13  second_final_global_limit      19740 non-null  float64
#  14  second_final_global_limit      19740 non-null  float64
#  15  first zeroized                 19740 non-null  object
#  16  second zeroized                19740 non-null  object
#  17  first_balance_limit_flag       19740 non-null  object
#  18  second_balance_limit_flag      19740 non-null  object
# dtypes: float64(10), object(9)
# memory usage: 3.0+ MB

# %%
# current_defaulters_700 = current_defaulters[current_defaulters['loan_status'] == 700]

# current_defaulters_700 = current_defaulters_700[['loan_mifos_id', 'store_number', 'loan_status', 'principal_outstanding', 'interest_outstanding', 'fee_charges_outstanding', 'penalty_charges_outstanding', 'total_outstanding']]

# current_defaulters_700['total_outstanding_calculated'] = current_defaulters_700['principal_outstanding'] + current_defaulters_700['interest_outstanding'] + current_defaulters_700['fee_charges_outstanding'] + current_defaulters_700['penalty_charges_outstanding']

# current_defaulters_700.head()
