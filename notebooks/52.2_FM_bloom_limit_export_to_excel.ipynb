# %%
# Import modules
import sys

# %%
# Import custom modules
sys.path.append('../')

from src.models.upload_data import *

# %%
# Set notebook attributes
pd.set_option('display.max_colwidth', 500)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 300)
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
# Set magic attributes
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
# Configuration
args = argparse.ArgumentParser()
args.add_argument("--config", default="../params.yaml")
parsed_args = vars(args.parse_args(""))
config_path = parsed_args['config']

# %%
# Load configurations
config = read_params(config_path)
project_dir = config["project_dir"]
scored_limits_risk_review_data_path_excel_parquet = config["processed_data_config"]["scored_limits_risk_review_data_excel_parquet"]
before_21d_graduation_limits_data_path = config["interim_data_config"]["before_21d_graduation_limits_data_parquet"]
after_rmdd_ge95_data_path = config["interim_data_config"]["after_rmdd_ge95_data_parquet"]
after_rmdd_ge96_data_path = config["interim_data_config"]["after_rmdd_ge96_data_parquet"]

# %% [markdown]
# ### Limit Investigation

# %% [markdown]
# #### Legacy

# %%
# Columns not in scope
df_columns_not_in_scope = ['sum_3_months_trx_val', 'approx_30_days_trx_val', 'model_version', 'created_at', 'record_added_to_warehouse_on_timestamp', 'old_src_crdt_score']
# df_columns_not_in_scope = ['sum_3_months_trx_val', 'approx_30_days_trx_val', 'record_added_to_warehouse_on_timestamp', 'old_src_crdt_score']
limit_cols = ['final_21_limit', 'final_7_limit', 'final_1_limit']

# %%
# Legacy system refresh run
# df = pd.read_excel('../data/external/07_JN_Limits_refresh_summary_20221006_multiple_products_rec_new_2.xlsx')
# df.to_parquet('../data/external/07_JN_Limits_refresh_summary_20221006_multiple_products_rec_new_2.parquet', index=False)
df_raw = pd.read_parquet('../data/external/07_JN_Limits_refresh_summary_20221006_multiple_products_rec_new_2.parquet')
df_raw['store_number'] = df_raw['store_number'].astype('str')
df = df_raw.drop(columns=df_columns_not_in_scope)
df.rename(columns={'avg_3_months_trx_val': 'approx_30_days_trx_val'}, inplace=True)
df.sample(2)
# Out:
#       mobile_number store_number  approx_30_days_trx_val  \
# 20975  254713662215      7008186               123734.33
# 6537   254722838106       965396                19751.81
#
#       most_recent_trx_date_past_30_days last_trx_date  expected_trx_days  \
# 20975                        2022-09-09    2022-10-04                 26
# 6537                         2022-09-06    2022-10-05                 30
#
#        actual_trx_days  page_active_days     inference_col  \
# 20975                9              0.35  No_rules_relaxed
# 6537                26              0.87       relax_rules
#
#        days_since_last_trx transacted_last_5_days  weight_till_recency  \
# 20975                 2.00                    Yes                 1.00
# 6537                  1.00                    Yes                 1.00
#
#        national_id idm_recommendation  idm_limit  is_iprs_validated  \
# 20975  28262287.00             Reject       0.00               True
# 6537    5180428.00            Approve    3000.00               True
#
#        client_mobile_number  loan_count  loan_status  term_frequency  \
# 20975       254713662215.00           6       300.00           21.00
# 6537                    NaN          24       600.00           30.00
#
#        principal_disbursed  principal_repaid disbursed_on_date  \
# 20975            171500.00              0.00        2022-06-20
# 6537              10000.00          10000.00        2020-03-29
#
#       expected_matured_on_date closed_on_date due_date_fixed  days_past_due  \
# 20975               2022-07-11            NaT     2022-07-11          86.00
# 6537                2020-04-28     2020-04-28     2020-04-28           0.00
#
#        bloom_version loan_repayment_status  src_crdt_score  \
# 20975           2.00        active_default          430.00
# 6537            1.00        closed_on_time             NaN
#
#        max_principal_amount max_loan_disbursement_date  count_good_loans  \
# 20975             171500.00                 2022-06-20              5.00
# 6537               40000.00                 2019-11-04             24.00
#
#        good_loans_repayment_ratio  num_days_since_last_disbursement  \
# 20975                        0.83                            107.00
# 6537                         1.00                            920.00
#
#        weight_dpd  adjusted_loan_count  limit_factor_21  limit_factor_7  \
# 20975           0                    6             0.35            0.12
# 6537            1                    0             0.50            0.17
#
#        limit_factor_1  idm_factor_21  idm_factor_7  idm_factor_1  \
# 20975            0.12           0.70          0.71          0.71
# 6537             0.17           1.00          1.00          1.00
#
#       trading_consistency_bands loan_count_bands  new_limit_factor_21  \
# 20975                    Band 2           Band 4                 0.05
# 6537                     Band 6           Band 8                 0.50
#
#        new_limit_factor_7  new_limit_factor_1  \
# 20975                0.10                0.10
# 6537                 0.28                0.28
#
#        weight_good_loans_repayment_ratio  weight_consistency  weight_recency  \
# 20975                                  0                   0               2
# 6537                                   1                   1               1
#
#        risk_rules_factor  ultimate_factor_21  ultimate_factor_7  \
# 20975               0.50                0.02               0.04
# 6537                1.00                0.50               0.28
#
#        ultimate_factor_1  limit_21_day  limit_7_day  limit_1_day  \
# 20975               0.04       2165.35      4367.09      4367.09
# 6537                0.28       9875.91      5431.75      5431.75
#
#        adjusted_21_limit  adjusted_7_limit  adjusted_1_limit  final_21_limit  \
# 20975               0.00              0.00              0.00               0
# 6537                0.00           5431.75           5431.75               0
#
#        final_7_limit  final_1_limit  blacklist_flag  total_final_21_limit  \
# 20975              0              0               1                376900
# 6537            7200           7200               0                175000
#
#        previous_21_limit  previous_7_limit  previous_1_limit
# 20975                  0                 0                 0
# 6537                   0              7200              7200

# %%
# Risk columns in scope
df.columns
# Out:
# Index(['mobile_number', 'store_number', 'approx_30_days_trx_val',
#        'most_recent_trx_date_past_30_days', 'last_trx_date',
#        'expected_trx_days', 'actual_trx_days', 'page_active_days',
#        'inference_col', 'days_since_last_trx', 'transacted_last_5_days',
#        'weight_till_recency', 'national_id', 'idm_recommendation', 'idm_limit',
#        'is_iprs_validated', 'client_mobile_number', 'loan_count',
#        'loan_status', 'term_frequency', 'principal_disbursed',
#        'principal_repaid', 'disbursed_on_date', 'expected_matured_on_date',
#        'closed_on_date', 'due_date_fixed', 'days_past_due', 'bloom_version',
#        'loan_repayment_status', 'src_crdt_score', 'max_principal_amount',
#        'max_loan_disbursement_date', 'count_good_loans',
#        'good_loans_repayment_ratio', 'num_days_since_last_disbursement',
#        'weight_dpd', 'adjusted_loan_count', 'limit_factor_21',
#        'limit_factor_7', 'limit_factor_1', 'idm_factor_21', 'idm_factor_7',
#        'idm_factor_1', 'trading_consistency_bands', 'loan_count_bands',
#        'new_limit_factor_21', 'new_limit_factor_7', 'new_limit_factor_1',
#        'weight_good_loans_repayment_ratio', 'weight_consistency',
#        'weight_recency', 'risk_rules_factor', 'ultimate_factor_21',
#        'ultimate_factor_7', 'ultimate_factor_1', 'limit_21_day', 'limit_7_day',
#        'limit_1_day', 'adjusted_21_limit', 'adjusted_7_limit',
#        'adjusted_1_limit', 'final_21_limit', 'final_7_limit', 'final_1_limit',
#        'blacklist_flag', 'total_final_21_limit', 'previous_21_limit',
#        'previous_7_limit', 'previous_1_limit'],
#       dtype='object')

# %% [markdown]
# #### Baseline

# %%
# Baseline refresh run
df_baseline = pd.read_parquet('../data/processed/Limits_refresh_summary_20221115_multiple_products.parquet')
# df_baseline = df_baseline[df.columns]
df_baseline.sample(2)
# Out:
#       mobile_number store_number  approx_30_days_trx_val  \
# 38889  254702630591      7224320                60839.80
# 32908  254728015252      7326848                24148.83
#
#       most_recent_trx_date_past_30_days last_trx_date  expected_trx_days  \
# 38889                        2022-09-20    2022-10-20                 31
# 32908                        2022-09-21    2022-10-20                 30
#
#        actual_trx_days  page_active_days     inference_col  \
# 38889               30              0.97  No_rules_relaxed
# 32908               20              0.67  No_rules_relaxed
#
#        days_since_last_trx transacted_last_5_days  weight_till_recency  \
# 38889                25.00                     No                 0.00
# 32908                25.00                     No                 0.00
#
#       national_id idm_recommendation  idm_limit is_iprs_validated  \
# 38889     3342485             Reject       0.00              True
# 32908    30103503             Reject       0.00              True
#
#       client_mobile_number  loan_count  loan_status  term_frequency  \
# 38889         254702630591           2       300.00            7.00
# 32908         254728015252          16       300.00            1.00
#
#        principal_disbursed  principal_repaid disbursed_on_date  \
# 38889              2900.00              0.00        2022-10-20
# 32908              4000.00            283.93        2022-10-03
#
#       expected_matured_on_date closed_on_date due_date_fixed  days_past_due  \
# 38889               2022-10-27            NaT     2022-10-27          18.00
# 32908               2022-10-04            NaT     2022-10-04          41.00
#
#        bloom_version loan_repayment_status  src_crdt_score  \
# 38889           2.00        active_default          438.00
# 32908           2.00        active_default          425.00
#
#        max_principal_amount max_loan_disbursement_date  count_good_loans  \
# 38889               2900.00                 2022-10-20              1.00
# 32908               7000.00                 2022-07-11             15.00
#
#        good_loans_repayment_ratio  num_days_since_last_disbursement  \
# 38889                        0.50                             25.00
# 32908                        0.94                             42.00
#
#        weight_dpd  adjusted_loan_count  due_date_rm_ge_rm_1d  \
# 38889           0                    0                     1
# 32908           0                   16                     1
#
#        due_date_rm_ge_rm_add_back  rllvr_date_rm_ge_rm_add_back  \
# 38889                           1                             0
# 32908                           1                             1
#
#        limit_factor_21  limit_factor_7  limit_factor_1  idm_factor_21  \
# 38889             0.35            0.12            0.12           0.70
# 32908             0.35            0.12            0.12           0.70
#
#        idm_factor_7  idm_factor_1 trading_consistency_bands loan_count_bands  \
# 38889          0.71          0.71                    Band 7           Band 2
# 32908          0.71          0.71                    Band 4           Band 8
#
#        new_limit_factor_21  new_limit_factor_7  new_limit_factor_1  \
# 38889                 0.25                0.15                0.15
# 32908                 0.35                0.23                0.23
#
#        weight_good_loans_repayment_ratio  weight_consistency  weight_recency  \
# 38889                               0.00                1.00               0
# 32908                               0.00                0.00               0
#
#        risk_rules_factor  ultimate_factor_21  ultimate_factor_7  \
# 38889               0.25                0.04               0.03
# 32908               0.00                0.00               0.00
#
#        ultimate_factor_1  limit_21_day  limit_7_day  limit_1_day  \
# 38889               0.03       2661.74      1610.47      1610.47
# 32908               0.00          0.00         0.00         0.00
#
#        adjusted_21_limit  adjusted_7_limit  adjusted_1_limit  final_21_limit  \
# 38889               0.00              0.00              0.00               0
# 32908               0.00              0.00              0.00               0
#
#        final_7_limit  final_1_limit  blacklist_flag  total_final_21_limit  \
# 38889              0              0               0                     0
# 32908              0              0               0                 67400
#
#        previous_21_limit  previous_7_limit  previous_1_limit  \
# 38889                  0              2900              2900
# 32908                  0              8000              8000
#
#                           model_version          created_at
# 38889  2022-004[2022-05-14, 2022-11-15] 2022-11-15 15:53:24
# 32908  2022-004[2022-05-14, 2022-11-15] 2022-11-15 15:53:24

# %%
# Data set dimension
df_baseline.shape
# Out:
# (39261, 74)

# %%
# Data set schema
df_baseline.dtypes.to_frame().T
# Out:
#   mobile_number store_number approx_30_days_trx_val  \
# 0        object       object                float64
#
#   most_recent_trx_date_past_30_days   last_trx_date expected_trx_days  \
# 0                    datetime64[ns]  datetime64[ns]             int32
#
#   actual_trx_days page_active_days inference_col days_since_last_trx  \
# 0           int32          float64        object             float64
#
#   transacted_last_5_days weight_till_recency national_id idm_recommendation  \
# 0                 object             float64      object             object
#
#   idm_limit is_iprs_validated client_mobile_number loan_count loan_status  \
# 0   float64            object               object      int32     float64
#
#   term_frequency principal_disbursed principal_repaid disbursed_on_date  \
# 0        float64             float64          float64    datetime64[ns]
#
#   expected_matured_on_date  closed_on_date  due_date_fixed days_past_due  \
# 0           datetime64[ns]  datetime64[ns]  datetime64[ns]       float64
#
#   bloom_version loan_repayment_status src_crdt_score max_principal_amount  \
# 0       float64                object        float64              float64
#
#   max_loan_disbursement_date count_good_loans good_loans_repayment_ratio  \
# 0             datetime64[ns]          float64                    float64
#
#   num_days_since_last_disbursement weight_dpd adjusted_loan_count  \
# 0                          float64      int32               int32
#
#   due_date_rm_ge_rm_1d due_date_rm_ge_rm_add_back  \
# 0                int32                      int32
#
#   rllvr_date_rm_ge_rm_add_back limit_factor_21 limit_factor_7 limit_factor_1  \
# 0                        int32         float64        float64        float64
#
#   idm_factor_21 idm_factor_7 idm_factor_1 trading_consistency_bands  \
# 0       float64      float64      float64                    object
#
#   loan_count_bands new_limit_factor_21 new_limit_factor_7 new_limit_factor_1  \
# 0           object             float64            float64            float64
#
#   weight_good_loans_repayment_ratio weight_consistency weight_recency  \
# 0                           float64            float64          int32
#
#   risk_rules_factor ultimate_factor_21 ultimate_factor_7 ultimate_factor_1  \
# 0           float64            float64           float64           float64
#
#   limit_21_day limit_7_day limit_1_day adjusted_21_limit adjusted_7_limit  \
# 0      float64     float64     float64           float64          float64
#
#   adjusted_1_limit final_21_limit final_7_limit final_1_limit blacklist_flag  \
# 0          float64          int32         int32         int32          int32
#
#   total_final_21_limit previous_21_limit previous_7_limit previous_1_limit  \
# 0                int32             int32            int32            int32
#
#   model_version      created_at
# 0        object  datetime64[ns]

# %%
# Limits
df_baseline[limit_cols].sum()
# Out:
# final_21_limit    17225700
# final_7_limit     18194800
# final_1_limit     16377300
# dtype: int64

# %%
# %%time
# Export excel output
# df_baseline.to_excel('../data/processed/Limits_refresh_summary_20221019_multiple_products.xlsx', index=False)
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns

# %% [markdown]
# #### Impact assessment 1 and 2

# %%
# Impact assessment 1 and 2 refresh run
df_ia_1_2 = pd.read_parquet('../data/processed/Limits_refresh_summary_20221019_multiple_products_ia_01_02.parquet')
df_ia_1_2 = df_ia_1_2[df.columns]
df_ia_1_2.sample(2)
# Out:
#       mobile_number store_number  approx_30_days_trx_val  \
# 56641  254795416901      7737682                15374.58
# 12652  254711707054      7556387                91035.09
#
#       most_recent_trx_date_past_30_days last_trx_date  expected_trx_days  \
# 56641                        2022-09-18    2022-10-18                 31
# 12652                        2022-09-18    2022-10-18                 31
#
#        actual_trx_days  page_active_days     inference_col  \
# 56641               30              0.97  No_rules_relaxed
# 12652               31              1.00       relax_rules
#
#        days_since_last_trx transacted_last_5_days  weight_till_recency  \
# 56641                 0.00                    Yes                 1.00
# 12652                 0.00                    Yes                 1.00
#
#       national_id idm_recommendation  idm_limit is_iprs_validated  \
# 56641    37235159             Reject       0.00              True
# 12652    24921154             Reject       0.00              True
#
#       client_mobile_number  loan_count  loan_status  term_frequency  \
# 56641                 None           0          NaN             NaN
# 12652                  nan          10       300.00            7.00
#
#        principal_disbursed  principal_repaid disbursed_on_date  \
# 56641                  NaN               NaN               NaT
# 12652             12000.00              0.00        2022-03-15
#
#       expected_matured_on_date closed_on_date due_date_fixed  days_past_due  \
# 56641                      NaT            NaT            NaT           1.00
# 12652               2022-03-22            NaT     2022-03-22         210.00
#
#        bloom_version loan_repayment_status  src_crdt_score  \
# 56641            NaN                  None             NaN
# 12652           2.00        active_default          401.00
#
#        max_principal_amount max_loan_disbursement_date  count_good_loans  \
# 56641                   NaN                        NaT               NaN
# 12652              12000.00                 2022-03-15              9.00
#
#        good_loans_repayment_ratio  num_days_since_last_disbursement  \
# 56641                        1.00                               NaN
# 12652                        0.90                            217.00
#
#        weight_dpd  adjusted_loan_count  limit_factor_21  limit_factor_7  \
# 56641           0                    0             0.35            0.12
# 12652           0                    0             0.35            0.12
#
#        limit_factor_1  idm_factor_21  idm_factor_7  idm_factor_1  \
# 56641            0.12           0.70          0.71          0.71
# 12652            0.12           0.70          0.71          0.71
#
#       trading_consistency_bands loan_count_bands  new_limit_factor_21  \
# 56641                    Band 7           Band 1                 0.00
# 12652                    Band 7           Band 6                 0.45
#
#        new_limit_factor_7  new_limit_factor_1  \
# 56641                0.12                0.12
# 12652                0.25                0.25
#
#        weight_good_loans_repayment_ratio  weight_consistency  weight_recency  \
# 56641                               1.00                1.00               1
# 12652                               0.00                1.00               1
#
#        risk_rules_factor  ultimate_factor_21  ultimate_factor_7  \
# 56641               0.75                0.00               0.07
# 12652               0.50                0.16               0.09
#
#        ultimate_factor_1  limit_21_day  limit_7_day  limit_1_day  \
# 56641               0.07          0.00      1017.44      1017.44
# 12652               0.09      14338.03      8032.51      8032.51
#
#        adjusted_21_limit  adjusted_7_limit  adjusted_1_limit  final_21_limit  \
# 56641               0.00           1017.44           1017.44               0
# 12652               0.00           8032.51           8032.51               0
#
#        final_7_limit  final_1_limit  blacklist_flag  total_final_21_limit  \
# 56641              0            800               0                     0
# 12652              0              0               1                569900
#
#        previous_21_limit  previous_7_limit  previous_1_limit
# 56641                  0                 0               800
# 12652                  0                 0                 0

# %%
# Data set dimension
df_ia_1_2.shape
# Out:
# (62849, 69)

# %%
# Data set schema
df_ia_1_2.dtypes.to_frame().T
# Out:
#   mobile_number store_number approx_30_days_trx_val  \
# 0        object       object                float64
#
#   most_recent_trx_date_past_30_days   last_trx_date expected_trx_days  \
# 0                    datetime64[ns]  datetime64[ns]             int32
#
#   actual_trx_days page_active_days inference_col days_since_last_trx  \
# 0           int32          float64        object             float64
#
#   transacted_last_5_days weight_till_recency national_id idm_recommendation  \
# 0                 object             float64      object             object
#
#   idm_limit is_iprs_validated client_mobile_number loan_count loan_status  \
# 0   float64            object               object      int32     float64
#
#   term_frequency principal_disbursed principal_repaid disbursed_on_date  \
# 0        float64             float64          float64    datetime64[ns]
#
#   expected_matured_on_date  closed_on_date  due_date_fixed days_past_due  \
# 0           datetime64[ns]  datetime64[ns]  datetime64[ns]       float64
#
#   bloom_version loan_repayment_status src_crdt_score max_principal_amount  \
# 0       float64                object        float64              float64
#
#   max_loan_disbursement_date count_good_loans good_loans_repayment_ratio  \
# 0             datetime64[ns]          float64                    float64
#
#   num_days_since_last_disbursement weight_dpd adjusted_loan_count  \
# 0                          float64      int32               int32
#
#   limit_factor_21 limit_factor_7 limit_factor_1 idm_factor_21 idm_factor_7  \
# 0         float64        float64        float64       float64      float64
#
#   idm_factor_1 trading_consistency_bands loan_count_bands new_limit_factor_21  \
# 0      float64                    object           object             float64
#
#   new_limit_factor_7 new_limit_factor_1 weight_good_loans_repayment_ratio  \
# 0            float64            float64                           float64
#
#   weight_consistency weight_recency risk_rules_factor ultimate_factor_21  \
# 0            float64          int32           float64            float64
#
#   ultimate_factor_7 ultimate_factor_1 limit_21_day limit_7_day limit_1_day  \
# 0           float64           float64      float64     float64     float64
#
#   adjusted_21_limit adjusted_7_limit adjusted_1_limit final_21_limit  \
# 0           float64          float64          float64          int32
#
#   final_7_limit final_1_limit blacklist_flag total_final_21_limit  \
# 0         int32         int32          int32                int32
#
#   previous_21_limit previous_7_limit previous_1_limit
# 0             int32            int32            int32

# %%
# Limits
df_ia_1_2[limit_cols].sum()
# Out:
# final_21_limit    110810700
# final_7_limit     431382800
# final_1_limit     433585900
# dtype: int64

# %%
# %%time
# Export excel output
# df_baseline.to_excel('../data/processed/Limits_refresh_summary_20221019_multiple_products_ia_01_02.xlsx', index=False)
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
