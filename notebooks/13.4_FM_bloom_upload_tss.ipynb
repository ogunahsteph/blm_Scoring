# %%
# Import modules
import sys

# %%
# Import custom modules
sys.path.append('../')

from src.models.upload_data import *

# %%
# Set notebook attributes
pd.set_option('display.max_colwidth', 500)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 300)
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
# Set magic attributes
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
# Configuration
args = argparse.ArgumentParser()
args.add_argument("--config", default="../params.yaml")
parsed_args = vars(args.parse_args(""))
config_path = parsed_args['config']

# %% [markdown]
# ### Approved Limits Upload To TSS

# %%
# %%time
# Approved limits upload
df_upload_tss = push_data(config_path, "DWH", "tss", execution_date, refresh_date, record_added_to_warehouse_on_timestamp, created_at)
# Out:
# Connection successful
# The dataframe is NOT inserted to BLOOMLIVE.temp_scoring_summaries because push_limits flag = False
# Currently pulling tss_validate_push data set ...
# Connection successful
#                latest_model_version  num_of_customers_who_have_been_scored  \
# 0  2022-007[2022-10-21, 2022-11-29]                                  67163
#
#    gross_limit_allocation_for_21_day  gross_limit_allocation_for_7_day  \
# 0                          121829300                         320246100
#
#    gross_limit_allocation_for_1_day
# 0                         155407400
# ---------------------------------------------------------------------------------------------------------------------------------------
#       store_number  approx_30_days_trx_val most_recent_trx_date_past_30_days  \
# 1356        610164                11378.05                        2022-10-26
# 19800      7687795                44011.43                        2022-10-26
#
# ...

# %%
# Final dataset schema
df_upload_tss.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66557 entries, 0 to 66556
# Data columns (total 47 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   store_number                            66557 non-null  object
#  1   approx_30_days_trx_val                  66557 non-null  float64
#  2   most_recent_trx_date_past_30_days       66557 non-null  object
#  3   last_trx_date                           66557 non-null  object
#  4   expected_trx_days                       66557 non-null  int32
#  5   actual_trx_days                         66557 non-null  int32
#  6   page_active_days                        66557 non-null  float64
#  7   days_since_last_trx                     66557 non-null  float64
#  8   transacted_last_5_days                  66557 non-null  object
#  9   weight_till_recency                     66557 non-null  float64
# ...

# %%
# Limits
df_upload_tss[['final_21_limit', 'final_7_limit', 'final_1_limit']].sum()
# Out:
# final_21_limit    117341600
# final_7_limit     314397500
# final_1_limit     150131300
# dtype: int64
