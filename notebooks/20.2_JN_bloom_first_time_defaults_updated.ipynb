# %%
#import data processing libraries
import os
import pandas as pd
import numpy as np
import math as math
import datetime as dt
from scipy import stats

#import visualization libraries
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
sns.set_style('darkgrid')
# %matplotlib inline

#db connection libraries
import psycopg2
from sqlalchemy import create_engine
import psycopg2.extras as extras

# %%
pd.set_option('display.max_colwidth', 500)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 300)

#suppress scientific notation to 2 decimal places
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
host = '157.245.248.249'
port = int(5432)
dbname = 'ubuntu'
user = 'jacklinengenia'
password = 'x3MX&8#!'


def get_query_results_postgres():
    with psycopg2.connect(host = host,
                          port = port,
                          database = dbname,
                          user = user,
                          password = password) as conn:
        sql = 'select loan_mifos_id, store_number, loan_status, term_frequency, principal_disbursed, principal_outstanding, interest_outstanding, fee_charges_charged, fee_charges_outstanding, penalty_charges_charged, penalty_charges_outstanding, total_expected_repayment, total_repayment, total_outstanding, safaricom_loan_balance, bloom_version, disbursed_on_date, expected_matured_on_date, end_rollvr_dt, dpd_30, dpd_d60, dpd_d90 from bloomlive.loans_fact_table_materialized_summary_view'
        df = pd.read_sql(sql, conn)
        
    return df

    conn.close()

# %%
df_loans = get_query_results_postgres()

df_loans.head(3)
# Out:
# /opt/tljh/user/lib/python3.9/site-packages/pandas/io/sql.py:758: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#    loan_mifos_id store_number  loan_status  term_frequency  \
# 0          98788      7191795          600               7
# 1          98686      7498133          600               7
# 2         101319       799916          600              21
#
#    principal_disbursed  principal_outstanding  interest_outstanding  \
# 0             54600.00                   0.00                  0.00
# 1              3300.00                   0.00                  0.00
# 2            160000.00                   0.00                  0.00
#
#    fee_charges_charged  fee_charges_outstanding  penalty_charges_charged  \
# 0                 0.00                     0.00                     0.00
# 1                 0.00                     0.00                     0.00
# 2                 0.00                     0.00                     0.00
#
#    penalty_charges_outstanding  total_expected_repayment  total_repayment  \
# 0                         0.00                  56019.61         56019.61
# 1                         0.00                   3385.81          3385.81
# 2                         0.00                 172160.01        172160.01
#
#    total_outstanding  safaricom_loan_balance  bloom_version disbursed_on_date  \
# 0               0.00                    0.00           2.00        2022-05-19
# 1               0.00                    0.00           2.00        2022-05-19
# 2               0.00                    0.00           2.00        2022-05-20
#
#   expected_matured_on_date end_rollvr_dt      dpd_30     dpd_d60     dpd_d90
# 0               2022-05-26    2022-05-29  2022-06-28  2022-07-28  2022-08-27
# 1               2022-05-26    2022-05-29  2022-06-28  2022-07-28  2022-08-27
# 2               2022-06-10    2022-06-15  2022-07-15  2022-08-14  2022-09-13

# %%
df_loans.shape
# Out:
# (474953, 22)

# %%
#create loan count column i.e adds a new column that captures the num of loans a customer has taken
df_loans["loan_count"] = df_loans.groupby("store_number")["store_number"].transform('size')

df_loans.head(3)
# Out:
#    loan_mifos_id store_number  loan_status  term_frequency  \
# 0          98788      7191795          600               7
# 1          98686      7498133          600               7
# 2         101319       799916          600              21
#
#    principal_disbursed  principal_outstanding  interest_outstanding  \
# 0             54600.00                   0.00                  0.00
# 1              3300.00                   0.00                  0.00
# 2            160000.00                   0.00                  0.00
#
#    fee_charges_charged  fee_charges_outstanding  penalty_charges_charged  \
# 0                 0.00                     0.00                     0.00
# 1                 0.00                     0.00                     0.00
# 2                 0.00                     0.00                     0.00
#
#    penalty_charges_outstanding  total_expected_repayment  total_repayment  \
# 0                         0.00                  56019.61         56019.61
# 1                         0.00                   3385.81          3385.81
# 2                         0.00                 172160.01        172160.01
#
#    total_outstanding  safaricom_loan_balance  bloom_version disbursed_on_date  \
# 0               0.00                    0.00           2.00        2022-05-19
# 1               0.00                    0.00           2.00        2022-05-19
# 2               0.00                    0.00           2.00        2022-05-20
#
#   expected_matured_on_date end_rollvr_dt      dpd_30     dpd_d60     dpd_d90  \
# 0               2022-05-26    2022-05-29  2022-06-28  2022-07-28  2022-08-27
# 1               2022-05-26    2022-05-29  2022-06-28  2022-07-28  2022-08-27
# 2               2022-06-10    2022-06-15  2022-07-15  2022-08-14  2022-09-13
#
#    loan_count
# 0        3.00
# 1        5.00
# 2       26.00

# %%
#converting the current time to datetime format
curr_time = pd.to_datetime('today')

df_loans['disbursed_on_date'] = pd.to_datetime(df_loans['disbursed_on_date'], errors='coerce')
df_loans['end_rollvr_dt'] = pd.to_datetime(df_loans['end_rollvr_dt'], errors='coerce')
df_loans['expected_matured_on_date'] = pd.to_datetime(df_loans['expected_matured_on_date'], errors='coerce')

# %%
def saf_loan_balance(df):
    
    total_outstanding = df['total_outstanding']
    safaricom_loan_balance = df['safaricom_loan_balance']
    
    if safaricom_loan_balance >= 0:
        return safaricom_loan_balance
    else:
        return total_outstanding

# %%
df_loans['safaricom_loan_balance'] = df_loans.apply(lambda x: saf_loan_balance(x), axis = 1)

df_loans.head(5)
# Out:
#    loan_mifos_id store_number  loan_status  term_frequency  \
# 0          98788      7191795          600               7
# 1          98686      7498133          600               7
# 2         101319       799916          600              21
# 3         110344      7276538          300               7
# 4         108190      7376448          300               7
#
#    principal_disbursed  principal_outstanding  interest_outstanding  \
# 0             54600.00                   0.00                  0.00
# 1              3300.00                   0.00                  0.00
# 2            160000.00                   0.00                  0.00
# 3              2500.00                2500.00                 65.01
# 4              3400.00                3400.00                 88.41
#
#    fee_charges_charged  fee_charges_outstanding  penalty_charges_charged  \
# 0                 0.00                     0.00                     0.00
# 1                 0.00                     0.00                     0.00
# 2                 0.00                     0.00                     0.00
# 3                59.13                    59.13                   950.87
# 4                85.00                    85.00                  1562.05
#
#    penalty_charges_outstanding  total_expected_repayment  total_repayment  \
# 0                         0.00                  56019.61         56019.61
# 1                         0.00                   3385.81          3385.81
# 2                         0.00                 172160.01        172160.01
# 3                       456.44                   3575.01           494.43
# 4                      1500.82                   5135.46            61.23
#
#    total_outstanding  safaricom_loan_balance  bloom_version disbursed_on_date  \
# 0               0.00                    0.00           2.00        2022-05-19
# 1               0.00                    0.00           2.00        2022-05-19
# 2               0.00                    0.00           2.00        2022-05-20
# 3            3080.58                 3502.41           2.00        2022-05-31
# 4            5074.23                 5593.73           2.00        2022-05-27
#
#   expected_matured_on_date end_rollvr_dt      dpd_30     dpd_d60     dpd_d90  \
# 0               2022-05-26    2022-05-29  2022-06-28  2022-07-28  2022-08-27
# 1               2022-05-26    2022-05-29  2022-06-28  2022-07-28  2022-08-27
# 2               2022-06-10    2022-06-15  2022-07-15  2022-08-14  2022-09-13
# 3               2022-06-07    2022-06-10  2022-07-10  2022-08-09  2022-09-08
# 4               2022-06-03    2022-06-06  2022-07-06  2022-08-05  2022-09-04
#
#    loan_count
# 0        3.00
# 1        5.00
# 2       26.00
# 3        8.00
# 4        1.00

# %%
def cal_loan_count_flag(df):
    
    loan_count = df['loan_count']
    
    if loan_count == 1:
        return 'New Client'
    else:
        return 'Repeat Client'

# %%
df_loans['Loan Count Flag'] = df_loans.apply(lambda x: cal_loan_count_flag(x), axis = 1)

df_loans.head(5)
# Out:
#    loan_mifos_id store_number  loan_status  term_frequency  \
# 0          98788      7191795          600               7
# 1          98686      7498133          600               7
# 2         101319       799916          600              21
# 3         110344      7276538          300               7
# 4         108190      7376448          300               7
#
#    principal_disbursed  principal_outstanding  interest_outstanding  \
# 0             54600.00                   0.00                  0.00
# 1              3300.00                   0.00                  0.00
# 2            160000.00                   0.00                  0.00
# 3              2500.00                2500.00                 65.01
# 4              3400.00                3400.00                 88.41
#
#    fee_charges_charged  fee_charges_outstanding  penalty_charges_charged  \
# 0                 0.00                     0.00                     0.00
# 1                 0.00                     0.00                     0.00
# 2                 0.00                     0.00                     0.00
# 3                59.13                    59.13                   950.87
# 4                85.00                    85.00                  1562.05
#
#    penalty_charges_outstanding  total_expected_repayment  total_repayment  \
# 0                         0.00                  56019.61         56019.61
# 1                         0.00                   3385.81          3385.81
# 2                         0.00                 172160.01        172160.01
# 3                       456.44                   3575.01           494.43
# 4                      1500.82                   5135.46            61.23
#
#    total_outstanding  safaricom_loan_balance  bloom_version disbursed_on_date  \
# 0               0.00                    0.00           2.00        2022-05-19
# 1               0.00                    0.00           2.00        2022-05-19
# 2               0.00                    0.00           2.00        2022-05-20
# 3            3080.58                 3502.41           2.00        2022-05-31
# 4            5074.23                 5593.73           2.00        2022-05-27
#
#   expected_matured_on_date end_rollvr_dt      dpd_30     dpd_d60     dpd_d90  \
# 0               2022-05-26    2022-05-29  2022-06-28  2022-07-28  2022-08-27
# 1               2022-05-26    2022-05-29  2022-06-28  2022-07-28  2022-08-27
# 2               2022-06-10    2022-06-15  2022-07-15  2022-08-14  2022-09-13
# 3               2022-06-07    2022-06-10  2022-07-10  2022-08-09  2022-09-08
# 4               2022-06-03    2022-06-06  2022-07-06  2022-08-05  2022-09-04
#
#    loan_count Loan Count Flag
# 0        3.00   Repeat Client
# 1        5.00   Repeat Client
# 2       26.00   Repeat Client
# 3        8.00   Repeat Client
# 4        1.00      New Client

# %%
current_defaulters = df_loans[(df_loans['penalty_charges_charged'] > 0) & (df_loans['total_outstanding'] > 0) & (df_loans['safaricom_loan_balance'] > 0) & (df_loans['loan_status'] == 300)]

current_defaulters.shape
# Out:
# (26251, 24)

# %%
defaulters = df_loans[(df_loans['penalty_charges_charged'] > 0)]

defaulters.shape
# Out:
# (67303, 24)

# %%
defaulters_bloom_one = defaulters[(defaulters['bloom_version'] == 1)]

defaulters_bloom_one.shape
# Out:
# (21120, 24)

# %%
defaulters_bloom_two = defaulters[(defaulters['bloom_version'] == 2)]

defaulters_bloom_two.shape
# Out:
# (46183, 24)

# %%
defaulters_bloom_two[(defaulters_bloom_two['store_number'] == '7468569')]
# Out:
#         loan_mifos_id store_number  loan_status  term_frequency  \
# 68394          106687      7468569          600              21
# 440914         127075      7468569          300              21
# 469253         228595      7468569          300              21
#
#         principal_disbursed  principal_outstanding  interest_outstanding  \
# 68394               8500.00                   0.00                  0.00
# 440914              7000.00                  34.29                  0.00
# 469253              7400.00                 164.72                  0.00
#
#         fee_charges_charged  fee_charges_outstanding  penalty_charges_charged  \
# 68394                149.14                     0.00                     3.31
# 440914                24.00                     0.00                    10.28
# 469253               150.00                     0.00                    14.72
#
#         penalty_charges_outstanding  total_expected_repayment  \
# 68394                          0.00                   9298.46
# 440914                         0.00                   7566.29
# 469253                         0.00                   8239.60
#
#         total_repayment  total_outstanding  safaricom_loan_balance  \
# 68394           9298.46               0.00                    0.00
# 440914          7532.00              34.29                    0.00
# 469253          8074.88             164.72                    0.00
#
#         bloom_version disbursed_on_date expected_matured_on_date  \
# 68394            2.00        2022-05-26               2022-06-16
# 440914           2.00        2022-06-17               2022-07-08
# 469253           2.00        2022-10-12               2022-11-02
#
#        end_rollvr_dt      dpd_30     dpd_d60     dpd_d90  loan_count  \
# 68394     2022-06-21  2022-07-21  2022-08-20  2022-09-19       21.00
# 440914    2022-07-13  2022-08-12  2022-09-11  2022-10-11       21.00
# 469253    2022-11-07  2022-12-07  2023-01-06  2023-02-05       21.00
#
#        Loan Count Flag
# 68394    Repeat Client
# 440914   Repeat Client
# 469253   Repeat Client

# %%
# grouping store_number to find the count of bloom one defaulters
defaulters_bloom_one_count = defaulters_bloom_one.groupby(['store_number'], as_index=False)['loan_mifos_id'].count()
defaulters_bloom_one_count = defaulters_bloom_one_count.rename(columns={'loan_mifos_id':'defaulters_bloom_one_count'})

defaulters_bloom_one_count.head()
# Out:
#   store_number  defaulters_bloom_one_count
# 0       058169                           1
# 1       101705                           1
# 2       103914                           1
# 3       105639                           1
# 4       105649                           1

# %%
# grouping store_number to find the count of bloom two defaulters
defaulters_bloom_two_count = defaulters_bloom_two.groupby(['store_number'], as_index=False)['loan_mifos_id'].count()
defaulters_bloom_two_count = defaulters_bloom_two_count.rename(columns={'loan_mifos_id':'defaulters_bloom_two_count'})

defaulters_bloom_two_count.head()
# Out:
#   store_number  defaulters_bloom_two_count
# 0       000030                           1
# 1       003227                           5
# 2       058133                           1
# 3       105570                           1
# 4       105652                           3

# %%
defaulters_count = pd.merge(defaulters_bloom_one_count, defaulters_bloom_two_count, on = 'store_number', how = 'outer')

defaulters_count = defaulters_count.fillna(0)

defaulters_count.head(15)
# Out:
#    store_number  defaulters_bloom_one_count  defaulters_bloom_two_count
# 0        058169                        1.00                        0.00
# 1        101705                        1.00                        0.00
# 2        103914                        1.00                        0.00
# 3        105639                        1.00                        0.00
# 4        105649                        1.00                        0.00
# 5        105754                        1.00                        0.00
# 6        110138                        2.00                        0.00
# 7        110169                        1.00                        1.00
# 8        110398                        1.00                        0.00
# 9        110501                        1.00                        2.00
# 10       110596                        3.00                        0.00
# 11       110913                        1.00                        0.00
# 12       110918                        1.00                        0.00
# 13       110922                        1.00                        0.00
# 14       111135                        1.00                        0.00

# %%
current_defaulters['loan_status'].value_counts()
# Out:
# 300    26251
# Name: loan_status, dtype: int64

# %%
current_defaulters_bloom_one = current_defaulters[current_defaulters['bloom_version'] == 1]

current_defaulters_bloom_one.shape
# Out:
# (5735, 24)

# %%
current_defaulters_bloom_one.head()
# Out:
#       loan_mifos_id store_number  loan_status  term_frequency  \
# 751          230443       257900          300              30
# 942          230662       540238          300              30
# 984          230576       919946          300              30
# 1828         231651       607332          300              30
# 4744         230995       819715          300              30
#
#       principal_disbursed  principal_outstanding  interest_outstanding  \
# 751              62000.00               62000.00               4340.00
# 942              21000.00               21000.00               1470.00
# 984              25000.00               25000.00               1750.00
# 1828             18900.00               18900.00               1323.00
# 4744             40000.00               40000.00               2800.00
#
#       fee_charges_charged  fee_charges_outstanding  penalty_charges_charged  \
# 751               3649.00                  3649.00                 20181.00
# 942               1181.00                  1181.00                  6784.00
# 984               1472.00                  1472.00                  8327.00
# 1828               948.00                   948.00                  5363.00
# 4744              2310.00                  2310.00                 12894.00
#
#       penalty_charges_outstanding  total_expected_repayment  total_repayment  \
# 751                      12681.00                  90170.00          7500.00
# 942                       4744.00                  30435.00          2040.00
# 984                       8327.00                  36549.00             0.00
# 1828                      2363.00                  26534.00          3000.00
# 4744                      9137.00                  58004.00          3757.00
#
#       total_outstanding  safaricom_loan_balance  bloom_version  \
# 751            82670.00                82670.00           1.00
# 942            28395.00                28395.00           1.00
# 984            36549.00                36549.00           1.00
# 1828           23534.00                23534.00           1.00
# 4744           54247.00                54247.00           1.00
#
#      disbursed_on_date expected_matured_on_date end_rollvr_dt dpd_30 dpd_d60  \
# 751         2021-11-05               2021-12-05           NaT   None    None
# 942         2021-11-06               2021-12-06           NaT   None    None
# 984         2021-11-05               2021-12-05           NaT   None    None
# 1828        2021-11-10               2021-12-10           NaT   None    None
# 4744        2021-11-08               2021-12-08           NaT   None    None
#
#      dpd_d90  loan_count Loan Count Flag
# 751     None       53.00   Repeat Client
# 942     None        3.00   Repeat Client
# 984     None        2.00   Repeat Client
# 1828    None        7.00   Repeat Client
# 4744    None        2.00   Repeat Client

# %%
current_defaulters_bloom_one = pd.merge(current_defaulters_bloom_one, defaulters_bloom_one_count, on = 'store_number', how = 'left')

current_defaulters_bloom_one.head()
# Out:
#    loan_mifos_id store_number  loan_status  term_frequency  \
# 0         230443       257900          300              30
# 1         230662       540238          300              30
# 2         230576       919946          300              30
# 3         231651       607332          300              30
# 4         230995       819715          300              30
#
#    principal_disbursed  principal_outstanding  interest_outstanding  \
# 0             62000.00               62000.00               4340.00
# 1             21000.00               21000.00               1470.00
# 2             25000.00               25000.00               1750.00
# 3             18900.00               18900.00               1323.00
# 4             40000.00               40000.00               2800.00
#
#    fee_charges_charged  fee_charges_outstanding  penalty_charges_charged  \
# 0              3649.00                  3649.00                 20181.00
# 1              1181.00                  1181.00                  6784.00
# 2              1472.00                  1472.00                  8327.00
# 3               948.00                   948.00                  5363.00
# 4              2310.00                  2310.00                 12894.00
#
#    penalty_charges_outstanding  total_expected_repayment  total_repayment  \
# 0                     12681.00                  90170.00          7500.00
# 1                      4744.00                  30435.00          2040.00
# 2                      8327.00                  36549.00             0.00
# 3                      2363.00                  26534.00          3000.00
# 4                      9137.00                  58004.00          3757.00
#
#    total_outstanding  safaricom_loan_balance  bloom_version disbursed_on_date  \
# 0           82670.00                82670.00           1.00        2021-11-05
# 1           28395.00                28395.00           1.00        2021-11-06
# 2           36549.00                36549.00           1.00        2021-11-05
# 3           23534.00                23534.00           1.00        2021-11-10
# 4           54247.00                54247.00           1.00        2021-11-08
#
#   expected_matured_on_date end_rollvr_dt dpd_30 dpd_d60 dpd_d90  loan_count  \
# 0               2021-12-05           NaT   None    None    None       53.00
# 1               2021-12-06           NaT   None    None    None        3.00
# 2               2021-12-05           NaT   None    None    None        2.00
# 3               2021-12-10           NaT   None    None    None        7.00
# 4               2021-12-08           NaT   None    None    None        2.00
#
#   Loan Count Flag  defaulters_bloom_one_count
# 0   Repeat Client                           1
# 1   Repeat Client                           1
# 2   Repeat Client                           1
# 3   Repeat Client                           1
# 4   Repeat Client                           1

# %%
def cal_first_bloom_one_default(df):
    
    defaulters_bloom_one_count = df['defaulters_bloom_one_count']
    
    if defaulters_bloom_one_count == 1:
        return 'Bloom One First Default'
    else:
        return 'Bloom One Subsequent Default'

# %%
current_defaulters_bloom_one['Default Flag'] = current_defaulters_bloom_one.apply(lambda x: cal_first_bloom_one_default(x), axis = 1)

current_defaulters_bloom_one.head(5)
# Out:
#    loan_mifos_id store_number  loan_status  term_frequency  \
# 0         230443       257900          300              30
# 1         230662       540238          300              30
# 2         230576       919946          300              30
# 3         231651       607332          300              30
# 4         230995       819715          300              30
#
#    principal_disbursed  principal_outstanding  interest_outstanding  \
# 0             62000.00               62000.00               4340.00
# 1             21000.00               21000.00               1470.00
# 2             25000.00               25000.00               1750.00
# 3             18900.00               18900.00               1323.00
# 4             40000.00               40000.00               2800.00
#
#    fee_charges_charged  fee_charges_outstanding  penalty_charges_charged  \
# 0              3649.00                  3649.00                 20181.00
# 1              1181.00                  1181.00                  6784.00
# 2              1472.00                  1472.00                  8327.00
# 3               948.00                   948.00                  5363.00
# 4              2310.00                  2310.00                 12894.00
#
#    penalty_charges_outstanding  total_expected_repayment  total_repayment  \
# 0                     12681.00                  90170.00          7500.00
# 1                      4744.00                  30435.00          2040.00
# 2                      8327.00                  36549.00             0.00
# 3                      2363.00                  26534.00          3000.00
# 4                      9137.00                  58004.00          3757.00
#
#    total_outstanding  safaricom_loan_balance  bloom_version disbursed_on_date  \
# 0           82670.00                82670.00           1.00        2021-11-05
# 1           28395.00                28395.00           1.00        2021-11-06
# 2           36549.00                36549.00           1.00        2021-11-05
# 3           23534.00                23534.00           1.00        2021-11-10
# 4           54247.00                54247.00           1.00        2021-11-08
#
#   expected_matured_on_date end_rollvr_dt dpd_30 dpd_d60 dpd_d90  loan_count  \
# 0               2021-12-05           NaT   None    None    None       53.00
# 1               2021-12-06           NaT   None    None    None        3.00
# 2               2021-12-05           NaT   None    None    None        2.00
# 3               2021-12-10           NaT   None    None    None        7.00
# 4               2021-12-08           NaT   None    None    None        2.00
#
#   Loan Count Flag  defaulters_bloom_one_count             Default Flag
# 0   Repeat Client                           1  Bloom One First Default
# 1   Repeat Client                           1  Bloom One First Default
# 2   Repeat Client                           1  Bloom One First Default
# 3   Repeat Client                           1  Bloom One First Default
# 4   Repeat Client                           1  Bloom One First Default

# %%
current_defaulters_bloom_one['Default Flag'].value_counts()
# Out:
# Bloom One First Default         4433
# Bloom One Subsequent Default    1302
# Name: Default Flag, dtype: int64

# %%
current_defaulters_bloom_two = current_defaulters[current_defaulters['bloom_version'] == 2]

current_defaulters_bloom_two.shape
# Out:
# (20516, 24)

# %%
current_defaulters_bloom_two = pd.merge(current_defaulters_bloom_two, defaulters_bloom_two_count, on = 'store_number', how = 'left')

current_defaulters_bloom_two.head()
# Out:
#    loan_mifos_id store_number  loan_status  term_frequency  \
# 0         110344      7276538          300               7
# 1         108190      7376448          300               7
# 2         156885      7278403          300              21
# 3         179316      7593440          300               7
# 4         200776      7270475          300               7
#
#    principal_disbursed  principal_outstanding  interest_outstanding  \
# 0              2500.00                2500.00                 65.01
# 1              3400.00                3400.00                 88.41
# 2              7900.00                7900.00                600.41
# 3              1700.00                 831.41                  0.00
# 4              6500.00                  49.71                  0.00
#
#    fee_charges_charged  fee_charges_outstanding  penalty_charges_charged  \
# 0                59.13                    59.13                   950.87
# 1                85.00                    85.00                  1562.05
# 2               135.33                   135.33                  4071.57
# 3                92.13                     0.00                   465.07
# 4               201.08                     0.00                    49.71
#
#    penalty_charges_outstanding  total_expected_repayment  total_repayment  \
# 0                       456.44                   3575.01           494.43
# 1                      1500.82                   5135.46            61.23
# 2                      4071.57                  12707.31             0.00
# 3                         0.00                   2301.41          1470.00
# 4                         0.00                   6953.59          6903.88
#
#    total_outstanding  safaricom_loan_balance  bloom_version disbursed_on_date  \
# 0            3080.58                 3502.41           2.00        2022-05-31
# 1            5074.23                 5593.73           2.00        2022-05-27
# 2           12707.31                13467.12           2.00        2022-07-15
# 3             831.41                  812.02           2.00        2022-07-28
# 4              49.71                 6903.88           2.00        2022-08-27
#
#   expected_matured_on_date end_rollvr_dt      dpd_30     dpd_d60     dpd_d90  \
# 0               2022-06-07    2022-06-10  2022-07-10  2022-08-09  2022-09-08
# 1               2022-06-03    2022-06-06  2022-07-06  2022-08-05  2022-09-04
# 2               2022-08-05    2022-08-10  2022-09-09  2022-10-09  2022-11-08
# 3               2022-08-04    2022-08-07  2022-09-06  2022-10-06  2022-11-05
# 4               2022-09-03    2022-09-06  2022-10-06  2022-11-05  2022-12-05
#
#    loan_count Loan Count Flag  defaulters_bloom_two_count
# 0        8.00   Repeat Client                           1
# 1        1.00      New Client                           1
# 2       17.00   Repeat Client                           5
# 3        3.00   Repeat Client                           3
# 4        4.00   Repeat Client                           3

# %%
current_defaulters_bloom_two[(current_defaulters_bloom_two['store_number'] == '7468569')]
# Out:
# Empty DataFrame
# Columns: [loan_mifos_id, store_number, loan_status, term_frequency, principal_disbursed, principal_outstanding, interest_outstanding, fee_charges_charged, fee_charges_outstanding, penalty_charges_charged, penalty_charges_outstanding, total_expected_repayment, total_repayment, total_outstanding, safaricom_loan_balance, bloom_version, disbursed_on_date, expected_matured_on_date, end_rollvr_dt, dpd_30, dpd_d60, dpd_d90, loan_count, Loan Count Flag, defaulters_bloom_two_count]
# Index: []

# %%
def cal_first_bloom_two_default(df):
    
    defaulters_bloom_two_count = df['defaulters_bloom_two_count']
    
    if defaulters_bloom_two_count == 1:
        return 'Bloom Two First Default'
    else:
        return 'Bloom Two Subsequent Default'

# %%
current_defaulters_bloom_two['Default Flag'] = current_defaulters_bloom_two.apply(lambda x: cal_first_bloom_two_default(x), axis = 1)

current_defaulters_bloom_two.head(5)
# Out:
#    loan_mifos_id store_number  loan_status  term_frequency  \
# 0         110344      7276538          300               7
# 1         108190      7376448          300               7
# 2         156885      7278403          300              21
# 3         179316      7593440          300               7
# 4         200776      7270475          300               7
#
#    principal_disbursed  principal_outstanding  interest_outstanding  \
# 0              2500.00                2500.00                 65.01
# 1              3400.00                3400.00                 88.41
# 2              7900.00                7900.00                600.41
# 3              1700.00                 831.41                  0.00
# 4              6500.00                  49.71                  0.00
#
#    fee_charges_charged  fee_charges_outstanding  penalty_charges_charged  \
# 0                59.13                    59.13                   950.87
# 1                85.00                    85.00                  1562.05
# 2               135.33                   135.33                  4071.57
# 3                92.13                     0.00                   465.07
# 4               201.08                     0.00                    49.71
#
#    penalty_charges_outstanding  total_expected_repayment  total_repayment  \
# 0                       456.44                   3575.01           494.43
# 1                      1500.82                   5135.46            61.23
# 2                      4071.57                  12707.31             0.00
# 3                         0.00                   2301.41          1470.00
# 4                         0.00                   6953.59          6903.88
#
#    total_outstanding  safaricom_loan_balance  bloom_version disbursed_on_date  \
# 0            3080.58                 3502.41           2.00        2022-05-31
# 1            5074.23                 5593.73           2.00        2022-05-27
# 2           12707.31                13467.12           2.00        2022-07-15
# 3             831.41                  812.02           2.00        2022-07-28
# 4              49.71                 6903.88           2.00        2022-08-27
#
#   expected_matured_on_date end_rollvr_dt      dpd_30     dpd_d60     dpd_d90  \
# 0               2022-06-07    2022-06-10  2022-07-10  2022-08-09  2022-09-08
# 1               2022-06-03    2022-06-06  2022-07-06  2022-08-05  2022-09-04
# 2               2022-08-05    2022-08-10  2022-09-09  2022-10-09  2022-11-08
# 3               2022-08-04    2022-08-07  2022-09-06  2022-10-06  2022-11-05
# 4               2022-09-03    2022-09-06  2022-10-06  2022-11-05  2022-12-05
#
#    loan_count Loan Count Flag  defaulters_bloom_two_count  \
# 0        8.00   Repeat Client                           1
# 1        1.00      New Client                           1
# 2       17.00   Repeat Client                           5
# 3        3.00   Repeat Client                           3
# 4        4.00   Repeat Client                           3
#
#                    Default Flag
# 0       Bloom Two First Default
# 1       Bloom Two First Default
# 2  Bloom Two Subsequent Default
# 3  Bloom Two Subsequent Default
# 4  Bloom Two Subsequent Default

# %%
current_defaulters_bloom_two['Default Flag'].value_counts()
# Out:
# Bloom Two First Default         13631
# Bloom Two Subsequent Default     6885
# Name: Default Flag, dtype: int64

# %%
current_defaulters_bloom_two.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20516 entries, 0 to 20515
# Data columns (total 26 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   loan_mifos_id                20516 non-null  int64
#  1   store_number                 20516 non-null  object
#  2   loan_status                  20516 non-null  int64
#  3   term_frequency               20516 non-null  int64
#  4   principal_disbursed          20516 non-null  float64
#  5   principal_outstanding        20516 non-null  float64
#  6   interest_outstanding         20516 non-null  float64
#  7   fee_charges_charged          20516 non-null  float64
#  8   fee_charges_outstanding      20516 non-null  float64
#  9   penalty_charges_charged      20516 non-null  float64
#  10  penalty_charges_outstanding  20516 non-null  float64
#  11  total_expected_repayment     20516 non-null  float64
#  12  total_repayment              20516 non-null  float64
#  13  total_outstanding            20516 non-null  float64
#  14  safaricom_loan_balance       20516 non-null  float64
#  15  bloom_version                20516 non-null  float64
#  16  disbursed_on_date            20516 non-null  datetime64[ns]
#  17  expected_matured_on_date     20516 non-null  datetime64[ns]
#  18  end_rollvr_dt                20516 non-null  datetime64[ns]
#  19  dpd_30                       20516 non-null  object
#  20  dpd_d60                      20516 non-null  object
#  21  dpd_d90                      20516 non-null  object
#  22  loan_count                   20516 non-null  float64
#  23  Loan Count Flag              20516 non-null  object
#  24  defaulters_bloom_two_count   20516 non-null  int64
#  25  Default Flag                 20516 non-null  object
# dtypes: datetime64[ns](3), float64(13), int64(4), object(6)
# memory usage: 4.2+ MB

# %%
def cal_occurred_after_first_limit_reductions(df):
    
    expected_matured_on_date = df['expected_matured_on_date']
    disbursed_on_date = df['disbursed_on_date']
    
    if ((disbursed_on_date <= pd.to_datetime('2022-07-27')) and (expected_matured_on_date > pd.to_datetime('2022-07-27'))):
        return 'Default occurred after first limit reductions'
    else:
        return 'Default occurred before first limit reductions'

# %%
current_defaulters_bloom_two['First Limit Reductions Flag'] = current_defaulters_bloom_two.apply(lambda x: cal_occurred_after_first_limit_reductions(x), axis = 1)

current_defaulters_bloom_two.head(5)
# Out:
#    loan_mifos_id store_number  loan_status  term_frequency  \
# 0         110344      7276538          300               7
# 1         108190      7376448          300               7
# 2         156885      7278403          300              21
# 3         179316      7593440          300               7
# 4         200776      7270475          300               7
#
#    principal_disbursed  principal_outstanding  interest_outstanding  \
# 0              2500.00                2500.00                 65.01
# 1              3400.00                3400.00                 88.41
# 2              7900.00                7900.00                600.41
# 3              1700.00                 831.41                  0.00
# 4              6500.00                  49.71                  0.00
#
#    fee_charges_charged  fee_charges_outstanding  penalty_charges_charged  \
# 0                59.13                    59.13                   950.87
# 1                85.00                    85.00                  1562.05
# 2               135.33                   135.33                  4071.57
# 3                92.13                     0.00                   465.07
# 4               201.08                     0.00                    49.71
#
#    penalty_charges_outstanding  total_expected_repayment  total_repayment  \
# 0                       456.44                   3575.01           494.43
# 1                      1500.82                   5135.46            61.23
# 2                      4071.57                  12707.31             0.00
# 3                         0.00                   2301.41          1470.00
# 4                         0.00                   6953.59          6903.88
#
#    total_outstanding  safaricom_loan_balance  bloom_version disbursed_on_date  \
# 0            3080.58                 3502.41           2.00        2022-05-31
# 1            5074.23                 5593.73           2.00        2022-05-27
# 2           12707.31                13467.12           2.00        2022-07-15
# 3             831.41                  812.02           2.00        2022-07-28
# 4              49.71                 6903.88           2.00        2022-08-27
#
#   expected_matured_on_date end_rollvr_dt      dpd_30     dpd_d60     dpd_d90  \
# 0               2022-06-07    2022-06-10  2022-07-10  2022-08-09  2022-09-08
# 1               2022-06-03    2022-06-06  2022-07-06  2022-08-05  2022-09-04
# 2               2022-08-05    2022-08-10  2022-09-09  2022-10-09  2022-11-08
# 3               2022-08-04    2022-08-07  2022-09-06  2022-10-06  2022-11-05
# 4               2022-09-03    2022-09-06  2022-10-06  2022-11-05  2022-12-05
#
#    loan_count Loan Count Flag  defaulters_bloom_two_count  \
# 0        8.00   Repeat Client                           1
# 1        1.00      New Client                           1
# 2       17.00   Repeat Client                           5
# 3        3.00   Repeat Client                           3
# 4        4.00   Repeat Client                           3
#
#                    Default Flag  \
# 0       Bloom Two First Default
# 1       Bloom Two First Default
# 2  Bloom Two Subsequent Default
# 3  Bloom Two Subsequent Default
# 4  Bloom Two Subsequent Default
#
#                       First Limit Reductions Flag
# 0  Default occurred before first limit reductions
# 1  Default occurred before first limit reductions
# 2   Default occurred after first limit reductions
# 3  Default occurred before first limit reductions
# 4  Default occurred before first limit reductions

# %%
def cal_occurred_after_second_limit_reductions(df):
    
    expected_matured_on_date = df['expected_matured_on_date']
    disbursed_on_date = df['disbursed_on_date']
    
    if ((disbursed_on_date <= pd.to_datetime('2022-08-03')) and (expected_matured_on_date > pd.to_datetime('2022-08-03'))):
        return 'Default occurred after second limit reductions'
    else:
        return 'Default occurred before second limit reductions'

# %%
current_defaulters_bloom_two['Second Limit Reductions Flag'] = current_defaulters_bloom_two.apply(lambda x: cal_occurred_after_second_limit_reductions(x), axis = 1)

current_defaulters_bloom_two.head(5)
# Out:
#    loan_mifos_id store_number  loan_status  term_frequency  \
# 0         110344      7276538          300               7
# 1         108190      7376448          300               7
# 2         156885      7278403          300              21
# 3         179316      7593440          300               7
# 4         200776      7270475          300               7
#
#    principal_disbursed  principal_outstanding  interest_outstanding  \
# 0              2500.00                2500.00                 65.01
# 1              3400.00                3400.00                 88.41
# 2              7900.00                7900.00                600.41
# 3              1700.00                 831.41                  0.00
# 4              6500.00                  49.71                  0.00
#
#    fee_charges_charged  fee_charges_outstanding  penalty_charges_charged  \
# 0                59.13                    59.13                   950.87
# 1                85.00                    85.00                  1562.05
# 2               135.33                   135.33                  4071.57
# 3                92.13                     0.00                   465.07
# 4               201.08                     0.00                    49.71
#
#    penalty_charges_outstanding  total_expected_repayment  total_repayment  \
# 0                       456.44                   3575.01           494.43
# 1                      1500.82                   5135.46            61.23
# 2                      4071.57                  12707.31             0.00
# 3                         0.00                   2301.41          1470.00
# 4                         0.00                   6953.59          6903.88
#
#    total_outstanding  safaricom_loan_balance  bloom_version disbursed_on_date  \
# 0            3080.58                 3502.41           2.00        2022-05-31
# 1            5074.23                 5593.73           2.00        2022-05-27
# 2           12707.31                13467.12           2.00        2022-07-15
# 3             831.41                  812.02           2.00        2022-07-28
# 4              49.71                 6903.88           2.00        2022-08-27
#
#   expected_matured_on_date end_rollvr_dt      dpd_30     dpd_d60     dpd_d90  \
# 0               2022-06-07    2022-06-10  2022-07-10  2022-08-09  2022-09-08
# 1               2022-06-03    2022-06-06  2022-07-06  2022-08-05  2022-09-04
# 2               2022-08-05    2022-08-10  2022-09-09  2022-10-09  2022-11-08
# 3               2022-08-04    2022-08-07  2022-09-06  2022-10-06  2022-11-05
# 4               2022-09-03    2022-09-06  2022-10-06  2022-11-05  2022-12-05
#
#    loan_count Loan Count Flag  defaulters_bloom_two_count  \
# 0        8.00   Repeat Client                           1
# 1        1.00      New Client                           1
# 2       17.00   Repeat Client                           5
# 3        3.00   Repeat Client                           3
# 4        4.00   Repeat Client                           3
#
#                    Default Flag  \
# 0       Bloom Two First Default
# 1       Bloom Two First Default
# 2  Bloom Two Subsequent Default
# 3  Bloom Two Subsequent Default
# 4  Bloom Two Subsequent Default
#
#                       First Limit Reductions Flag  \
# 0  Default occurred before first limit reductions
# 1  Default occurred before first limit reductions
# 2   Default occurred after first limit reductions
# 3  Default occurred before first limit reductions
# 4  Default occurred before first limit reductions
#
#                       Second Limit Reductions Flag
# 0  Default occurred before second limit reductions
# 1  Default occurred before second limit reductions
# 2   Default occurred after second limit reductions
# 3   Default occurred after second limit reductions
# 4  Default occurred before second limit reductions

# %%
current_defaulters_bloom_two['First Limit Reductions Flag'].value_counts()
# Out:
# Default occurred before first limit reductions    19460
# Default occurred after first limit reductions      1056
# Name: First Limit Reductions Flag, dtype: int64

# %%
current_defaulters_bloom_two['Second Limit Reductions Flag'].value_counts()
# Out:
# Default occurred before second limit reductions    19403
# Default occurred after second limit reductions      1113
# Name: Second Limit Reductions Flag, dtype: int64

# %%
current_defaulters_bloom_two['Loan Count Flag'].value_counts()
# Out:
# Repeat Client    15789
# New Client        4727
# Name: Loan Count Flag, dtype: int64

# %%
def saf_loan_balance(df):
    
    safaricom_loan_balance = df['safaricom_loan_balance']
    
    if safaricom_loan_balance >= 0:
        return 'yes'
    else:
        return 'no'

# %%
current_defaulters_bloom_two['saf_loan_balance'] = current_defaulters_bloom_two.apply(lambda x: saf_loan_balance(x), axis = 1)

current_defaulters_bloom_two.head(5)
# Out:
#    loan_mifos_id store_number  loan_status  term_frequency  \
# 0         110344      7276538          300               7
# 1         108190      7376448          300               7
# 2         156885      7278403          300              21
# 3         179316      7593440          300               7
# 4         200776      7270475          300               7
#
#    principal_disbursed  principal_outstanding  interest_outstanding  \
# 0              2500.00                2500.00                 65.01
# 1              3400.00                3400.00                 88.41
# 2              7900.00                7900.00                600.41
# 3              1700.00                 831.41                  0.00
# 4              6500.00                  49.71                  0.00
#
#    fee_charges_charged  fee_charges_outstanding  penalty_charges_charged  \
# 0                59.13                    59.13                   950.87
# 1                85.00                    85.00                  1562.05
# 2               135.33                   135.33                  4071.57
# 3                92.13                     0.00                   465.07
# 4               201.08                     0.00                    49.71
#
#    penalty_charges_outstanding  total_expected_repayment  total_repayment  \
# 0                       456.44                   3575.01           494.43
# 1                      1500.82                   5135.46            61.23
# 2                      4071.57                  12707.31             0.00
# 3                         0.00                   2301.41          1470.00
# 4                         0.00                   6953.59          6903.88
#
#    total_outstanding  safaricom_loan_balance  bloom_version disbursed_on_date  \
# 0            3080.58                 3502.41           2.00        2022-05-31
# 1            5074.23                 5593.73           2.00        2022-05-27
# 2           12707.31                13467.12           2.00        2022-07-15
# 3             831.41                  812.02           2.00        2022-07-28
# 4              49.71                 6903.88           2.00        2022-08-27
#
#   expected_matured_on_date end_rollvr_dt      dpd_30     dpd_d60     dpd_d90  \
# 0               2022-06-07    2022-06-10  2022-07-10  2022-08-09  2022-09-08
# 1               2022-06-03    2022-06-06  2022-07-06  2022-08-05  2022-09-04
# 2               2022-08-05    2022-08-10  2022-09-09  2022-10-09  2022-11-08
# 3               2022-08-04    2022-08-07  2022-09-06  2022-10-06  2022-11-05
# 4               2022-09-03    2022-09-06  2022-10-06  2022-11-05  2022-12-05
#
#    loan_count Loan Count Flag  defaulters_bloom_two_count  \
# 0        8.00   Repeat Client                           1
# 1        1.00      New Client                           1
# 2       17.00   Repeat Client                           5
# 3        3.00   Repeat Client                           3
# 4        4.00   Repeat Client                           3
#
#                    Default Flag  \
# 0       Bloom Two First Default
# 1       Bloom Two First Default
# 2  Bloom Two Subsequent Default
# 3  Bloom Two Subsequent Default
# 4  Bloom Two Subsequent Default
#
#                       First Limit Reductions Flag  \
# 0  Default occurred before first limit reductions
# 1  Default occurred before first limit reductions
# 2   Default occurred after first limit reductions
# 3  Default occurred before first limit reductions
# 4  Default occurred before first limit reductions
#
#                       Second Limit Reductions Flag saf_loan_balance
# 0  Default occurred before second limit reductions              yes
# 1  Default occurred before second limit reductions              yes
# 2   Default occurred after second limit reductions              yes
# 3   Default occurred after second limit reductions              yes
# 4  Default occurred before second limit reductions              yes

# %%
def calc_loan_balance(df):
    
    saf_loan_balance = df['saf_loan_balance']
    total_outstanding = df['total_outstanding']
    safaricom_loan_balance = df['safaricom_loan_balance']
    
    if saf_loan_balance == 'yes':
        return safaricom_loan_balance
    else:
        return total_outstanding

# %%
current_defaulters_bloom_two['loan_balance'] = current_defaulters_bloom_two.apply(lambda x: calc_loan_balance(x), axis = 1)

current_defaulters_bloom_two.head(5)
# Out:
#    loan_mifos_id store_number  loan_status  term_frequency  \
# 0         110344      7276538          300               7
# 1         108190      7376448          300               7
# 2         156885      7278403          300              21
# 3         179316      7593440          300               7
# 4         200776      7270475          300               7
#
#    principal_disbursed  principal_outstanding  interest_outstanding  \
# 0              2500.00                2500.00                 65.01
# 1              3400.00                3400.00                 88.41
# 2              7900.00                7900.00                600.41
# 3              1700.00                 831.41                  0.00
# 4              6500.00                  49.71                  0.00
#
#    fee_charges_charged  fee_charges_outstanding  penalty_charges_charged  \
# 0                59.13                    59.13                   950.87
# 1                85.00                    85.00                  1562.05
# 2               135.33                   135.33                  4071.57
# 3                92.13                     0.00                   465.07
# 4               201.08                     0.00                    49.71
#
#    penalty_charges_outstanding  total_expected_repayment  total_repayment  \
# 0                       456.44                   3575.01           494.43
# 1                      1500.82                   5135.46            61.23
# 2                      4071.57                  12707.31             0.00
# 3                         0.00                   2301.41          1470.00
# 4                         0.00                   6953.59          6903.88
#
#    total_outstanding  safaricom_loan_balance  bloom_version disbursed_on_date  \
# 0            3080.58                 3502.41           2.00        2022-05-31
# 1            5074.23                 5593.73           2.00        2022-05-27
# 2           12707.31                13467.12           2.00        2022-07-15
# 3             831.41                  812.02           2.00        2022-07-28
# 4              49.71                 6903.88           2.00        2022-08-27
#
#   expected_matured_on_date end_rollvr_dt      dpd_30     dpd_d60     dpd_d90  \
# 0               2022-06-07    2022-06-10  2022-07-10  2022-08-09  2022-09-08
# 1               2022-06-03    2022-06-06  2022-07-06  2022-08-05  2022-09-04
# 2               2022-08-05    2022-08-10  2022-09-09  2022-10-09  2022-11-08
# 3               2022-08-04    2022-08-07  2022-09-06  2022-10-06  2022-11-05
# 4               2022-09-03    2022-09-06  2022-10-06  2022-11-05  2022-12-05
#
#    loan_count Loan Count Flag  defaulters_bloom_two_count  \
# 0        8.00   Repeat Client                           1
# 1        1.00      New Client                           1
# 2       17.00   Repeat Client                           5
# 3        3.00   Repeat Client                           3
# 4        4.00   Repeat Client                           3
#
#                    Default Flag  \
# 0       Bloom Two First Default
# 1       Bloom Two First Default
# 2  Bloom Two Subsequent Default
# 3  Bloom Two Subsequent Default
# 4  Bloom Two Subsequent Default
#
#                       First Limit Reductions Flag  \
# 0  Default occurred before first limit reductions
# 1  Default occurred before first limit reductions
# 2   Default occurred after first limit reductions
# 3  Default occurred before first limit reductions
# 4  Default occurred before first limit reductions
#
#                       Second Limit Reductions Flag saf_loan_balance  \
# 0  Default occurred before second limit reductions              yes
# 1  Default occurred before second limit reductions              yes
# 2   Default occurred after second limit reductions              yes
# 3   Default occurred after second limit reductions              yes
# 4  Default occurred before second limit reductions              yes
#
#    loan_balance
# 0       3502.41
# 1       5593.73
# 2      13467.12
# 3        812.02
# 4       6903.88

# %%
host = '157.245.248.249'
port = int(5432)
dbname = 'ubuntu'
user = 'jacklinengenia'
password = 'x3MX&8#!'


def get_query_results_postgres():
    with psycopg2.connect(host = host,
                          port = port,
                          database = dbname,
                          user = user,
                          password = password) as conn:
        sql = "select store_number, final_21_limit, final_7_limit, final_1_limit, model_version from bloomlive.temp_scoring_summaries where model_version in('2022-004[2022-05-14, 2022-06-30]', '2022-005[2022-07-27, 2022-07-27]', '2022-005[2022-07-27, 2022-08-03]', '2022-007[2022-10-21, 2022-11-03]')"
        df = pd.read_sql(sql, conn)
        
    return df

    conn.close()

# %%
limits = get_query_results_postgres()

limits.head(3)
# Out:
# /opt/tljh/user/lib/python3.9/site-packages/pandas/io/sql.py:758: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#   store_number  final_21_limit  final_7_limit  final_1_limit  \
# 0       351645               0          18400              0
# 1       822369               0              0              0
# 2       786152               0              0              0
#
#                       model_version
# 0  2022-007[2022-10-21, 2022-11-03]
# 1  2022-004[2022-05-14, 2022-06-30]
# 2  2022-004[2022-05-14, 2022-06-30]

# %%
#limits["adjusted_21_limit"] = (np.ceil(limits["adjusted_21_limit"] / 100) * 100).astype(int)
#limits["adjusted_7_limit"] = (np.ceil(limits["adjusted_7_limit"] / 100) * 100).astype(int)
#limits["adjusted_1_limit"] = (np.ceil(limits["adjusted_1_limit"] / 100) * 100).astype(int)

#limits["adjusted_global_limit"] = limits[["adjusted_21_limit", "adjusted_7_limit", "adjusted_1_limit"]].max(axis=1)
limits["final_global_limit"] = limits[["final_21_limit", "final_7_limit", "final_1_limit"]].max(axis=1)

limits.head()
# Out:
#   store_number  final_21_limit  final_7_limit  final_1_limit  \
# 0       351645               0          18400              0
# 1       822369               0              0              0
# 2       786152               0              0              0
# 3       165978               0          23000          23000
# 4       836820               0              0              0
#
#                       model_version  final_global_limit
# 0  2022-007[2022-10-21, 2022-11-03]               18400
# 1  2022-004[2022-05-14, 2022-06-30]                   0
# 2  2022-004[2022-05-14, 2022-06-30]                   0
# 3  2022-004[2022-05-14, 2022-06-30]               23000
# 4  2022-004[2022-05-14, 2022-06-30]                   0

# %%
limits = limits[['store_number', 'model_version', 'final_global_limit']]

limits.head()
# Out:
#   store_number                     model_version  final_global_limit
# 0       351645  2022-007[2022-10-21, 2022-11-03]               18400
# 1       822369  2022-004[2022-05-14, 2022-06-30]                   0
# 2       786152  2022-004[2022-05-14, 2022-06-30]                   0
# 3       165978  2022-004[2022-05-14, 2022-06-30]               23000
# 4       836820  2022-004[2022-05-14, 2022-06-30]                   0

# %%
previous_refresh = limits[limits['model_version'] == '2022-004[2022-05-14, 2022-06-30]']
del previous_refresh['model_version']

first_refresh = limits[limits['model_version'] == '2022-005[2022-07-27, 2022-07-27]']
del first_refresh['model_version']

second_refresh = limits[limits['model_version'] == '2022-005[2022-07-27, 2022-08-03]']
del second_refresh['model_version']

current_refresh = limits[limits['model_version'] == '2022-007[2022-10-21, 2022-11-03]']
del current_refresh['model_version']

# %%
current_defaulters_bloom_two = pd.merge(current_defaulters_bloom_two, previous_refresh, on = 'store_number', how = 'left')
current_defaulters_bloom_two = current_defaulters_bloom_two.rename(columns={'final_global_limit':'previous_final_global_limit'})
current_defaulters_bloom_two['previous_final_global_limit'] = current_defaulters_bloom_two['previous_final_global_limit'].fillna(0)

current_defaulters_bloom_two = pd.merge(current_defaulters_bloom_two, first_refresh, on = 'store_number', how = 'left')
current_defaulters_bloom_two = current_defaulters_bloom_two.rename(columns={'final_global_limit':'first_final_global_limit'})
current_defaulters_bloom_two['first_final_global_limit'] = current_defaulters_bloom_two['first_final_global_limit'].fillna(0)

current_defaulters_bloom_two = pd.merge(current_defaulters_bloom_two, second_refresh, on = 'store_number', how = 'left')
current_defaulters_bloom_two = current_defaulters_bloom_two.rename(columns={'final_global_limit':'second_final_global_limit'})
current_defaulters_bloom_two['second_final_global_limit'] = current_defaulters_bloom_two['second_final_global_limit'].fillna(0)

current_defaulters_bloom_two = pd.merge(current_defaulters_bloom_two, current_refresh, on = 'store_number', how = 'left')
current_defaulters_bloom_two = current_defaulters_bloom_two.rename(columns={'final_global_limit':'current_final_global_limit'})
current_defaulters_bloom_two['current_final_global_limit'] = current_defaulters_bloom_two['current_final_global_limit'].fillna(0)

#current_defaulters_bloom_two["adjusted_global_limit"] = current_defaulters_bloom_two[["adjusted_21_limit", "adjusted_7_limit", "adjusted_1_limit"]].max(axis=1)
#current_defaulters_bloom_two["final_global_limit"] = current_defaulters_bloom_two[["final_21_limit", "final_7_limit", "final_1_limit"]].max(axis=1)

current_defaulters_bloom_two.head()
# Out:
#    loan_mifos_id store_number  loan_status  term_frequency  \
# 0         110344      7276538          300               7
# 1         108190      7376448          300               7
# 2         156885      7278403          300              21
# 3         179316      7593440          300               7
# 4         200776      7270475          300               7
#
#    principal_disbursed  principal_outstanding  interest_outstanding  \
# 0              2500.00                2500.00                 65.01
# 1              3400.00                3400.00                 88.41
# 2              7900.00                7900.00                600.41
# 3              1700.00                 831.41                  0.00
# 4              6500.00                  49.71                  0.00
#
#    fee_charges_charged  fee_charges_outstanding  penalty_charges_charged  \
# 0                59.13                    59.13                   950.87
# 1                85.00                    85.00                  1562.05
# 2               135.33                   135.33                  4071.57
# 3                92.13                     0.00                   465.07
# 4               201.08                     0.00                    49.71
#
#    penalty_charges_outstanding  total_expected_repayment  total_repayment  \
# 0                       456.44                   3575.01           494.43
# 1                      1500.82                   5135.46            61.23
# 2                      4071.57                  12707.31             0.00
# 3                         0.00                   2301.41          1470.00
# 4                         0.00                   6953.59          6903.88
#
#    total_outstanding  safaricom_loan_balance  bloom_version disbursed_on_date  \
# 0            3080.58                 3502.41           2.00        2022-05-31
# 1            5074.23                 5593.73           2.00        2022-05-27
# 2           12707.31                13467.12           2.00        2022-07-15
# 3             831.41                  812.02           2.00        2022-07-28
# 4              49.71                 6903.88           2.00        2022-08-27
#
#   expected_matured_on_date end_rollvr_dt      dpd_30     dpd_d60     dpd_d90  \
# 0               2022-06-07    2022-06-10  2022-07-10  2022-08-09  2022-09-08
# 1               2022-06-03    2022-06-06  2022-07-06  2022-08-05  2022-09-04
# 2               2022-08-05    2022-08-10  2022-09-09  2022-10-09  2022-11-08
# 3               2022-08-04    2022-08-07  2022-09-06  2022-10-06  2022-11-05
# 4               2022-09-03    2022-09-06  2022-10-06  2022-11-05  2022-12-05
#
#    loan_count Loan Count Flag  defaulters_bloom_two_count  \
# 0        8.00   Repeat Client                           1
# 1        1.00      New Client                           1
# 2       17.00   Repeat Client                           5
# 3        3.00   Repeat Client                           3
# 4        4.00   Repeat Client                           3
#
#                    Default Flag  \
# 0       Bloom Two First Default
# 1       Bloom Two First Default
# 2  Bloom Two Subsequent Default
# 3  Bloom Two Subsequent Default
# 4  Bloom Two Subsequent Default
#
#                       First Limit Reductions Flag  \
# 0  Default occurred before first limit reductions
# 1  Default occurred before first limit reductions
# 2   Default occurred after first limit reductions
# 3  Default occurred before first limit reductions
# 4  Default occurred before first limit reductions
#
#                       Second Limit Reductions Flag saf_loan_balance  \
# 0  Default occurred before second limit reductions              yes
# 1  Default occurred before second limit reductions              yes
# 2   Default occurred after second limit reductions              yes
# 3   Default occurred after second limit reductions              yes
# 4  Default occurred before second limit reductions              yes
#
#    loan_balance  previous_final_global_limit  first_final_global_limit  \
# 0       3502.41                      4600.00                      0.00
# 1       5593.73                      1900.00                   1300.00
# 2      13467.12                      7900.00                   4900.00
# 3        812.02                      1700.00                   1700.00
# 4       6903.88                      7000.00                   7000.00
#
#    second_final_global_limit  current_final_global_limit
# 0                       0.00                        0.00
# 1                       0.00                        0.00
# 2                       0.00                        0.00
# 3                       0.00                        0.00
# 4                    6900.00                        0.00

# %%
current_defaulters_bloom_two.shape
# Out:
# (20516, 34)

# %%
current_defaulters_bloom_two[['previous_final_global_limit', 'first_final_global_limit', 'second_final_global_limit', 'current_final_global_limit']].sum()
# Out:
# previous_final_global_limit   284050800.00
# first_final_global_limit      183306900.00
# second_final_global_limit      62488200.00
# current_final_global_limit     40705800.00
# dtype: float64

# %%
def calc_first_zeroized(df):
    
    previous_final_global_limit = df['previous_final_global_limit']
    first_final_global_limit = df['first_final_global_limit']
    
    if first_final_global_limit == 0 and previous_final_global_limit > 0:
        return 'first zeroized'
    else:
        return 'first not zeroized'
    
    
def calc_second_zeroized(df):
    
    previous_final_global_limit = df['previous_final_global_limit']
    second_final_global_limit = df['second_final_global_limit']
    
    if second_final_global_limit == 0 and previous_final_global_limit > 0:
        return 'second zeroized'
    else:
        return 'second not zeroized'

# %%
current_defaulters_bloom_two['first zeroized'] = current_defaulters_bloom_two.apply(lambda x: calc_first_zeroized(x), axis = 1)
current_defaulters_bloom_two['second zeroized'] = current_defaulters_bloom_two.apply(lambda x: calc_second_zeroized(x), axis = 1)


current_defaulters_bloom_two.head(5)
# Out:
#    loan_mifos_id store_number  loan_status  term_frequency  \
# 0         110344      7276538          300               7
# 1         108190      7376448          300               7
# 2         156885      7278403          300              21
# 3         179316      7593440          300               7
# 4         200776      7270475          300               7
#
#    principal_disbursed  principal_outstanding  interest_outstanding  \
# 0              2500.00                2500.00                 65.01
# 1              3400.00                3400.00                 88.41
# 2              7900.00                7900.00                600.41
# 3              1700.00                 831.41                  0.00
# 4              6500.00                  49.71                  0.00
#
#    fee_charges_charged  fee_charges_outstanding  penalty_charges_charged  \
# 0                59.13                    59.13                   950.87
# 1                85.00                    85.00                  1562.05
# 2               135.33                   135.33                  4071.57
# 3                92.13                     0.00                   465.07
# 4               201.08                     0.00                    49.71
#
#    penalty_charges_outstanding  total_expected_repayment  total_repayment  \
# 0                       456.44                   3575.01           494.43
# 1                      1500.82                   5135.46            61.23
# 2                      4071.57                  12707.31             0.00
# 3                         0.00                   2301.41          1470.00
# 4                         0.00                   6953.59          6903.88
#
#    total_outstanding  safaricom_loan_balance  bloom_version disbursed_on_date  \
# 0            3080.58                 3502.41           2.00        2022-05-31
# 1            5074.23                 5593.73           2.00        2022-05-27
# 2           12707.31                13467.12           2.00        2022-07-15
# 3             831.41                  812.02           2.00        2022-07-28
# 4              49.71                 6903.88           2.00        2022-08-27
#
#   expected_matured_on_date end_rollvr_dt      dpd_30     dpd_d60     dpd_d90  \
# 0               2022-06-07    2022-06-10  2022-07-10  2022-08-09  2022-09-08
# 1               2022-06-03    2022-06-06  2022-07-06  2022-08-05  2022-09-04
# 2               2022-08-05    2022-08-10  2022-09-09  2022-10-09  2022-11-08
# 3               2022-08-04    2022-08-07  2022-09-06  2022-10-06  2022-11-05
# 4               2022-09-03    2022-09-06  2022-10-06  2022-11-05  2022-12-05
#
#    loan_count Loan Count Flag  defaulters_bloom_two_count  \
# 0        8.00   Repeat Client                           1
# 1        1.00      New Client                           1
# 2       17.00   Repeat Client                           5
# 3        3.00   Repeat Client                           3
# 4        4.00   Repeat Client                           3
#
#                    Default Flag  \
# 0       Bloom Two First Default
# 1       Bloom Two First Default
# 2  Bloom Two Subsequent Default
# 3  Bloom Two Subsequent Default
# 4  Bloom Two Subsequent Default
#
#                       First Limit Reductions Flag  \
# 0  Default occurred before first limit reductions
# 1  Default occurred before first limit reductions
# 2   Default occurred after first limit reductions
# 3  Default occurred before first limit reductions
# 4  Default occurred before first limit reductions
#
#                       Second Limit Reductions Flag saf_loan_balance  \
# 0  Default occurred before second limit reductions              yes
# 1  Default occurred before second limit reductions              yes
# 2   Default occurred after second limit reductions              yes
# 3   Default occurred after second limit reductions              yes
# 4  Default occurred before second limit reductions              yes
#
#    loan_balance  previous_final_global_limit  first_final_global_limit  \
# 0       3502.41                      4600.00                      0.00
# 1       5593.73                      1900.00                   1300.00
# 2      13467.12                      7900.00                   4900.00
# 3        812.02                      1700.00                   1700.00
# 4       6903.88                      7000.00                   7000.00
#
#    second_final_global_limit  current_final_global_limit      first zeroized  \
# 0                       0.00                        0.00      first zeroized
# 1                       0.00                        0.00  first not zeroized
# 2                       0.00                        0.00  first not zeroized
# 3                       0.00                        0.00  first not zeroized
# 4                    6900.00                        0.00  first not zeroized
#
#        second zeroized
# 0      second zeroized
# 1      second zeroized
# 2      second zeroized
# 3      second zeroized
# 4  second not zeroized

# %%
current_defaulters_bloom_two[current_defaulters_bloom_two['previous_final_global_limit'] > current_defaulters_bloom_two['loan_balance']]
# Out:
#        loan_mifos_id store_number  loan_status  term_frequency  \
# 0             110344      7276538          300               7
# 3             179316      7593440          300               7
# 4             200776      7270475          300               7
# 18            140571      7523642          300               7
# 20            210522      7801326          300               7
# ...              ...          ...          ...             ...
# 20493         227880       698030          300              21
# 20496          22878       308492          300              21
# 20502         185627      4012089          300              21
# 20507          16527       278826          300               7
# 20513         220528       574531          300              21
#
#        principal_disbursed  principal_outstanding  interest_outstanding  \
# 0                  2500.00                2500.00                 65.01
# 3                  1700.00                 831.41                  0.00
# 4                  6500.00                  49.71                  0.00
# 18                 3700.00                3700.00                 96.21
# 20                 2300.00                 560.41                  0.00
# ...                    ...                    ...                   ...
# 20493             11000.00                 785.03                  0.00
# 20496            200000.00               11728.74                  0.00
# 20502             67400.00               36838.43                  0.00
# 20507              3000.00                3000.00                102.01
# 20513              8000.00                8000.00                729.60
#
#        fee_charges_charged  fee_charges_outstanding  penalty_charges_charged  \
# 0                    59.13                    59.13                   950.87
# 3                    92.13                     0.00                   465.07
# 4                   201.08                     0.00                    49.71
# 18                   34.80                    34.80                  1426.25
# 20                   71.16                     0.00                   417.49
# ...                    ...                      ...                      ...
# 20493               720.20                     0.00                    64.83
# 20496             10039.51                     0.00                  1689.22
# 20502              8294.49                     0.00                 18967.53
# 20507                75.00                    75.00                  1356.00
# 20513               523.78                   523.78                  1738.76
#
#        penalty_charges_outstanding  total_expected_repayment  total_repayment  \
# 0                           456.44                   3575.01           494.43
# 3                             0.00                   2301.41          1470.00
# 4                             0.00                   6953.59          6903.88
# 18                         1426.25                   5257.26             0.00
# 20                            0.00                   2860.41          2300.00
# ...                            ...                       ...              ...
# 20493                         0.00                  12788.23         12003.20
# 20496                         0.00                 229128.74        217400.00
# 20502                         0.00                  99784.43         62946.00
# 20507                      1356.00                   4533.01             0.00
# 20513                      1738.76                  10992.14             0.00
#
#        total_outstanding  safaricom_loan_balance  bloom_version  \
# 0                3080.58                 3502.41           2.00
# 3                 831.41                  812.02           2.00
# 4                  49.71                 6903.88           2.00
# 18               5257.26                 5589.41           2.00
# 20                560.41                  611.97           2.00
# ...                  ...                     ...            ...
# 20493             785.03                12003.20           2.00
# 20496           11728.74                11728.74           2.00
# 20502           36838.43                32061.83           2.00
# 20507            4533.01                 4533.01           2.00
# 20513           10992.14                11150.72           2.00
#
#       disbursed_on_date expected_matured_on_date end_rollvr_dt      dpd_30  \
# 0            2022-05-31               2022-06-07    2022-06-10  2022-07-10
# 3            2022-07-28               2022-08-04    2022-08-07  2022-09-06
# 4            2022-08-27               2022-09-03    2022-09-06  2022-10-06
# 18           2022-06-29               2022-07-06    2022-07-09  2022-08-08
# 20           2022-09-14               2022-09-21    2022-09-24  2022-10-24
# ...                 ...                      ...           ...         ...
# 20493        2022-10-13               2022-11-03    2022-11-08  2022-12-08
# 20496        2022-02-05               2022-02-26    2022-03-03  2022-04-02
# 20502        2022-08-04               2022-08-25    2022-08-30  2022-09-29
# 20507        2022-01-21               2022-01-28    2022-01-31  2022-03-02
# 20513        2022-09-30               2022-10-21    2022-10-26  2022-11-25
#
#           dpd_d60     dpd_d90  loan_count Loan Count Flag  \
# 0      2022-08-09  2022-09-08        8.00   Repeat Client
# 3      2022-10-06  2022-11-05        3.00   Repeat Client
# 4      2022-11-05  2022-12-05        4.00   Repeat Client
# 18     2022-09-07  2022-10-07        2.00   Repeat Client
# 20     2022-11-23  2022-12-23        1.00      New Client
# ...           ...         ...         ...             ...
# 20493  2023-01-07  2023-02-06       38.00   Repeat Client
# 20496  2022-05-02  2022-06-01       99.00   Repeat Client
# 20502  2022-10-29  2022-11-28       10.00   Repeat Client
# 20507  2022-04-01  2022-05-01        2.00   Repeat Client
# 20513  2022-12-25  2023-01-24       12.00   Repeat Client
#
#        defaulters_bloom_two_count                  Default Flag  \
# 0                               1       Bloom Two First Default
# 3                               3  Bloom Two Subsequent Default
# 4                               3  Bloom Two Subsequent Default
# 18                              1       Bloom Two First Default
# 20                              1       Bloom Two First Default
# ...                           ...                           ...
# 20493                           1       Bloom Two First Default
# 20496                           3  Bloom Two Subsequent Default
# 20502                           2  Bloom Two Subsequent Default
# 20507                           1       Bloom Two First Default
# 20513                           4  Bloom Two Subsequent Default
#
#                           First Limit Reductions Flag  \
# 0      Default occurred before first limit reductions
# 3      Default occurred before first limit reductions
# 4      Default occurred before first limit reductions
# 18     Default occurred before first limit reductions
# 20     Default occurred before first limit reductions
# ...                                               ...
# 20493  Default occurred before first limit reductions
# 20496  Default occurred before first limit reductions
# 20502  Default occurred before first limit reductions
# 20507  Default occurred before first limit reductions
# 20513  Default occurred before first limit reductions
#
#                           Second Limit Reductions Flag saf_loan_balance  \
# 0      Default occurred before second limit reductions              yes
# 3       Default occurred after second limit reductions              yes
# 4      Default occurred before second limit reductions              yes
# 18     Default occurred before second limit reductions              yes
# 20     Default occurred before second limit reductions              yes
# ...                                                ...              ...
# 20493  Default occurred before second limit reductions              yes
# 20496  Default occurred before second limit reductions              yes
# 20502  Default occurred before second limit reductions              yes
# 20507  Default occurred before second limit reductions              yes
# 20513  Default occurred before second limit reductions              yes
#
#        loan_balance  previous_final_global_limit  first_final_global_limit  \
# 0           3502.41                      4600.00                      0.00
# 3            812.02                      1700.00                   1700.00
# 4           6903.88                      7000.00                   7000.00
# 18          5589.41                      6000.00                   2800.00
# 20           611.97                      2300.00                   2300.00
# ...             ...                          ...                       ...
# 20493      12003.20                     35000.00                      0.00
# 20496      11728.74                    200000.00                 200000.00
# 20502      32061.83                     67400.00                  36900.00
# 20507       4533.01                     10900.00                  10400.00
# 20513      11150.72                     21500.00                  12000.00
#
#        second_final_global_limit  current_final_global_limit  \
# 0                           0.00                        0.00
# 3                           0.00                        0.00
# 4                        6900.00                        0.00
# 18                          0.00                        0.00
# 20                       2300.00                        0.00
# ...                          ...                         ...
# 20493                       0.00                     8000.00
# 20496                       0.00                   200000.00
# 20502                       0.00                        0.00
# 20507                       0.00                        0.00
# 20513                   12000.00                    10200.00
#
#            first zeroized      second zeroized
# 0          first zeroized      second zeroized
# 3      first not zeroized      second zeroized
# 4      first not zeroized  second not zeroized
# 18     first not zeroized      second zeroized
# 20     first not zeroized  second not zeroized
# ...                   ...                  ...
# 20493      first zeroized      second zeroized
# 20496  first not zeroized      second zeroized
# 20502  first not zeroized      second zeroized
# 20507  first not zeroized      second zeroized
# 20513  first not zeroized  second not zeroized
#
# [2746 rows x 36 columns]

# %%
def calc_first_balance_limit_flag(df):
    
    loan_balance = df['loan_balance']
    previous_final_global_limit = df['previous_final_global_limit']
    
    if previous_final_global_limit < loan_balance:
        return 'Lower than balance'
    elif previous_final_global_limit > loan_balance:
        return 'Higher than balance'
    elif loan_balance == previous_final_global_limit:
        return 'Equal Balances'
    

def calc_second_balance_limit_flag(df):
    
    loan_balance = df['loan_balance']
    previous_final_global_limit = df['previous_final_global_limit']
    
    if previous_final_global_limit < loan_balance:
        return 'Lower than balance'
    elif previous_final_global_limit > loan_balance:
        return 'Higher than balance'
    elif loan_balance == previous_final_global_limit:
        return 'Equal Balances'

# %%
current_defaulters_bloom_two['first_balance_limit_flag'] = current_defaulters_bloom_two.apply(lambda x: calc_first_balance_limit_flag(x), axis = 1)
current_defaulters_bloom_two['second_balance_limit_flag'] = current_defaulters_bloom_two.apply(lambda x: calc_second_balance_limit_flag(x), axis = 1)


current_defaulters_bloom_two.head(5)
# Out:
#    loan_mifos_id store_number  loan_status  term_frequency  \
# 0         110344      7276538          300               7
# 1         108190      7376448          300               7
# 2         156885      7278403          300              21
# 3         179316      7593440          300               7
# 4         200776      7270475          300               7
#
#    principal_disbursed  principal_outstanding  interest_outstanding  \
# 0              2500.00                2500.00                 65.01
# 1              3400.00                3400.00                 88.41
# 2              7900.00                7900.00                600.41
# 3              1700.00                 831.41                  0.00
# 4              6500.00                  49.71                  0.00
#
#    fee_charges_charged  fee_charges_outstanding  penalty_charges_charged  \
# 0                59.13                    59.13                   950.87
# 1                85.00                    85.00                  1562.05
# 2               135.33                   135.33                  4071.57
# 3                92.13                     0.00                   465.07
# 4               201.08                     0.00                    49.71
#
#    penalty_charges_outstanding  total_expected_repayment  total_repayment  \
# 0                       456.44                   3575.01           494.43
# 1                      1500.82                   5135.46            61.23
# 2                      4071.57                  12707.31             0.00
# 3                         0.00                   2301.41          1470.00
# 4                         0.00                   6953.59          6903.88
#
#    total_outstanding  safaricom_loan_balance  bloom_version disbursed_on_date  \
# 0            3080.58                 3502.41           2.00        2022-05-31
# 1            5074.23                 5593.73           2.00        2022-05-27
# 2           12707.31                13467.12           2.00        2022-07-15
# 3             831.41                  812.02           2.00        2022-07-28
# 4              49.71                 6903.88           2.00        2022-08-27
#
#   expected_matured_on_date end_rollvr_dt      dpd_30     dpd_d60     dpd_d90  \
# 0               2022-06-07    2022-06-10  2022-07-10  2022-08-09  2022-09-08
# 1               2022-06-03    2022-06-06  2022-07-06  2022-08-05  2022-09-04
# 2               2022-08-05    2022-08-10  2022-09-09  2022-10-09  2022-11-08
# 3               2022-08-04    2022-08-07  2022-09-06  2022-10-06  2022-11-05
# 4               2022-09-03    2022-09-06  2022-10-06  2022-11-05  2022-12-05
#
#    loan_count Loan Count Flag  defaulters_bloom_two_count  \
# 0        8.00   Repeat Client                           1
# 1        1.00      New Client                           1
# 2       17.00   Repeat Client                           5
# 3        3.00   Repeat Client                           3
# 4        4.00   Repeat Client                           3
#
#                    Default Flag  \
# 0       Bloom Two First Default
# 1       Bloom Two First Default
# 2  Bloom Two Subsequent Default
# 3  Bloom Two Subsequent Default
# 4  Bloom Two Subsequent Default
#
#                       First Limit Reductions Flag  \
# 0  Default occurred before first limit reductions
# 1  Default occurred before first limit reductions
# 2   Default occurred after first limit reductions
# 3  Default occurred before first limit reductions
# 4  Default occurred before first limit reductions
#
#                       Second Limit Reductions Flag saf_loan_balance  \
# 0  Default occurred before second limit reductions              yes
# 1  Default occurred before second limit reductions              yes
# 2   Default occurred after second limit reductions              yes
# 3   Default occurred after second limit reductions              yes
# 4  Default occurred before second limit reductions              yes
#
#    loan_balance  previous_final_global_limit  first_final_global_limit  \
# 0       3502.41                      4600.00                      0.00
# 1       5593.73                      1900.00                   1300.00
# 2      13467.12                      7900.00                   4900.00
# 3        812.02                      1700.00                   1700.00
# 4       6903.88                      7000.00                   7000.00
#
#    second_final_global_limit  current_final_global_limit      first zeroized  \
# 0                       0.00                        0.00      first zeroized
# 1                       0.00                        0.00  first not zeroized
# 2                       0.00                        0.00  first not zeroized
# 3                       0.00                        0.00  first not zeroized
# 4                    6900.00                        0.00  first not zeroized
#
#        second zeroized first_balance_limit_flag second_balance_limit_flag
# 0      second zeroized      Higher than balance       Higher than balance
# 1      second zeroized       Lower than balance        Lower than balance
# 2      second zeroized       Lower than balance        Lower than balance
# 3      second zeroized      Higher than balance       Higher than balance
# 4  second not zeroized      Higher than balance       Higher than balance

# %%
current_defaulters_bloom_two = current_defaulters_bloom_two.sort_values(by = 'disbursed_on_date')

current_defaulters_bloom_two = current_defaulters_bloom_two.drop_duplicates(subset=['store_number'], keep='last')

current_defaulters_bloom_two.head()
# Out:
#        loan_mifos_id store_number  loan_status  term_frequency  \
# 16008           3699       735346          300               7
# 10635           3749       438125          300              21
# 11988           3766       146964          300              21
# 17482           3757       913867          300              21
# 7347            3769       761748          300               7
#
#        principal_disbursed  principal_outstanding  interest_outstanding  \
# 16008               150.00                 150.00                  5.09
# 10635              8000.00                8000.00                695.47
# 11988             23400.00               23400.00               2034.26
# 17482              7500.00                7500.00                652.01
# 7347              15000.00               15000.00                509.47
#
#        fee_charges_charged  fee_charges_outstanding  penalty_charges_charged  \
# 16008                 0.00                     0.00                    20.40
# 10635               434.80                   434.80                  2736.00
# 11988              1271.79                  1271.79                  8330.40
# 17482               407.63                   407.63                  2670.00
# 7347                387.75                   387.75                  2880.00
#
#        penalty_charges_outstanding  total_expected_repayment  total_repayment  \
# 16008                        20.40                    175.49             0.00
# 10635                      2736.00                  11866.27             0.00
# 11988                      8330.40                  35036.45             0.00
# 17482                      2670.00                  11229.64             0.00
# 7347                       2880.00                  18777.22             0.00
#
#        total_outstanding  safaricom_loan_balance  bloom_version  \
# 16008             175.49                  175.49           2.00
# 10635           11866.27                11866.27           2.00
# 11988           35036.45                35036.45           2.00
# 17482           11229.64                11229.64           2.00
# 7347            18777.22                18777.22           2.00
#
#       disbursed_on_date expected_matured_on_date end_rollvr_dt      dpd_30  \
# 16008        2021-11-05               2021-11-12    2021-11-15  2021-12-15
# 10635        2021-11-11               2021-12-02    2021-12-07  2022-01-06
# 11988        2021-11-12               2021-12-03    2021-12-08  2022-01-07
# 17482        2021-11-12               2021-12-03    2021-12-08  2022-01-07
# 7347         2021-11-12               2021-11-19    2021-11-22  2021-12-22
#
#           dpd_d60     dpd_d90  loan_count Loan Count Flag  \
# 16008  2022-01-14  2022-02-13      102.00   Repeat Client
# 10635  2022-02-05  2022-03-07        6.00   Repeat Client
# 11988  2022-02-06  2022-03-08        5.00   Repeat Client
# 17482  2022-02-06  2022-03-08       10.00   Repeat Client
# 7347   2022-01-21  2022-02-20        1.00      New Client
#
#        defaulters_bloom_two_count                  Default Flag  \
# 16008                          10  Bloom Two Subsequent Default
# 10635                           1       Bloom Two First Default
# 11988                           1       Bloom Two First Default
# 17482                           1       Bloom Two First Default
# 7347                            1       Bloom Two First Default
#
#                           First Limit Reductions Flag  \
# 16008  Default occurred before first limit reductions
# 10635  Default occurred before first limit reductions
# 11988  Default occurred before first limit reductions
# 17482  Default occurred before first limit reductions
# 7347   Default occurred before first limit reductions
#
#                           Second Limit Reductions Flag saf_loan_balance  \
# 16008  Default occurred before second limit reductions              yes
# 10635  Default occurred before second limit reductions              yes
# 11988  Default occurred before second limit reductions              yes
# 17482  Default occurred before second limit reductions              yes
# 7347   Default occurred before second limit reductions              yes
#
#        loan_balance  previous_final_global_limit  first_final_global_limit  \
# 16008        175.49                         0.00                      0.00
# 10635      11866.27                         0.00                      0.00
# 11988      35036.45                         0.00                      0.00
# 17482      11229.64                         0.00                      0.00
# 7347       18777.22                         0.00                      0.00
#
#        second_final_global_limit  current_final_global_limit  \
# 16008                       0.00                        0.00
# 10635                       0.00                        0.00
# 11988                       0.00                        0.00
# 17482                       0.00                        0.00
# 7347                        0.00                        0.00
#
#            first zeroized      second zeroized first_balance_limit_flag  \
# 16008  first not zeroized  second not zeroized       Lower than balance
# 10635  first not zeroized  second not zeroized       Lower than balance
# 11988  first not zeroized  second not zeroized       Lower than balance
# 17482  first not zeroized  second not zeroized       Lower than balance
# 7347   first not zeroized  second not zeroized       Lower than balance
#
#       second_balance_limit_flag
# 16008        Lower than balance
# 10635        Lower than balance
# 11988        Lower than balance
# 17482        Lower than balance
# 7347         Lower than balance

# %%
current_defaulters_bloom_two = current_defaulters_bloom_two[['store_number', 'Loan Count Flag', 'Default Flag', 'First Limit Reductions Flag', 'Second Limit Reductions Flag', 'total_outstanding', 'safaricom_loan_balance', 'loan_balance', 'previous_final_global_limit', 'first_final_global_limit', 'second_final_global_limit', 'current_final_global_limit', 'first zeroized', 'second zeroized', 'first_balance_limit_flag', 'second_balance_limit_flag']]

current_defaulters_bloom_two.head()
# Out:
#       store_number Loan Count Flag                  Default Flag  \
# 16008       735346   Repeat Client  Bloom Two Subsequent Default
# 10635       438125   Repeat Client       Bloom Two First Default
# 11988       146964   Repeat Client       Bloom Two First Default
# 17482       913867   Repeat Client       Bloom Two First Default
# 7347        761748      New Client       Bloom Two First Default
#
#                           First Limit Reductions Flag  \
# 16008  Default occurred before first limit reductions
# 10635  Default occurred before first limit reductions
# 11988  Default occurred before first limit reductions
# 17482  Default occurred before first limit reductions
# 7347   Default occurred before first limit reductions
#
#                           Second Limit Reductions Flag  total_outstanding  \
# 16008  Default occurred before second limit reductions             175.49
# 10635  Default occurred before second limit reductions           11866.27
# 11988  Default occurred before second limit reductions           35036.45
# 17482  Default occurred before second limit reductions           11229.64
# 7347   Default occurred before second limit reductions           18777.22
#
#        safaricom_loan_balance  loan_balance  previous_final_global_limit  \
# 16008                  175.49        175.49                         0.00
# 10635                11866.27      11866.27                         0.00
# 11988                35036.45      35036.45                         0.00
# 17482                11229.64      11229.64                         0.00
# 7347                 18777.22      18777.22                         0.00
#
#        first_final_global_limit  second_final_global_limit  \
# 16008                      0.00                       0.00
# 10635                      0.00                       0.00
# 11988                      0.00                       0.00
# 17482                      0.00                       0.00
# 7347                       0.00                       0.00
#
#        current_final_global_limit      first zeroized      second zeroized  \
# 16008                        0.00  first not zeroized  second not zeroized
# 10635                        0.00  first not zeroized  second not zeroized
# 11988                        0.00  first not zeroized  second not zeroized
# 17482                        0.00  first not zeroized  second not zeroized
# 7347                         0.00  first not zeroized  second not zeroized
#
#       first_balance_limit_flag second_balance_limit_flag
# 16008       Lower than balance        Lower than balance
# 10635       Lower than balance        Lower than balance
# 11988       Lower than balance        Lower than balance
# 17482       Lower than balance        Lower than balance
# 7347        Lower than balance        Lower than balance

# %%
current_defaulters_bloom_two['store_number'].nunique()
# Out:
# 20167

# %%
current_defaulters_bloom_two.shape
# Out:
# (20167, 16)

# %%
current_defaulters_bloom_two['first_balance_limit_flag'].value_counts()
# Out:
# Lower than balance     17635
# Higher than balance     2532
# Name: first_balance_limit_flag, dtype: int64

# %%
first_batch = current_defaulters_bloom_two[(current_defaulters_bloom_two['Default Flag'] == 'Bloom Two First Default') & (current_defaulters_bloom_two['First Limit Reductions Flag'] == 'Default occurred after first limit reductions') & (current_defaulters_bloom_two['first_balance_limit_flag'] == 'Lower than balance') & (current_defaulters_bloom_two['first zeroized'] == 'first zeroized')]

first_batch = first_batch[['store_number', 'Loan Count Flag', 'Default Flag', 'First Limit Reductions Flag', 'loan_balance', 'previous_final_global_limit', 'first_final_global_limit', 'current_final_global_limit', 'first zeroized', 'first_balance_limit_flag']]

first_batch.head()
# Out:
#       store_number Loan Count Flag             Default Flag  \
# 5491       7187782   Repeat Client  Bloom Two First Default
# 811        7214596   Repeat Client  Bloom Two First Default
# 7295       7343046   Repeat Client  Bloom Two First Default
# 20066      7982347   Repeat Client  Bloom Two First Default
# 16669      7184468   Repeat Client  Bloom Two First Default
#
#                          First Limit Reductions Flag  loan_balance  \
# 5491   Default occurred after first limit reductions      10973.33
# 811    Default occurred after first limit reductions      14859.08
# 7295   Default occurred after first limit reductions      37699.62
# 20066  Default occurred after first limit reductions       1861.47
# 16669  Default occurred after first limit reductions     286231.88
#
#        previous_final_global_limit  first_final_global_limit  \
# 5491                       4400.00                      0.00
# 811                        5400.00                      0.00
# 7295                      22300.00                      0.00
# 20066                      1100.00                      0.00
# 16669                    169100.00                      0.00
#
#        current_final_global_limit  first zeroized first_balance_limit_flag
# 5491                         0.00  first zeroized       Lower than balance
# 811                          0.00  first zeroized       Lower than balance
# 7295                         0.00  first zeroized       Lower than balance
# 20066                        0.00  first zeroized       Lower than balance
# 16669                        0.00  first zeroized       Lower than balance

# %%
first_batch.shape
# Out:
# (56, 10)

# %%
first_batch.to_excel('First Batch Defaulters.xlsx')

# %%
second_batch = current_defaulters_bloom_two[(current_defaulters_bloom_two['Default Flag'] == 'Bloom Two First Default') & (current_defaulters_bloom_two['Second Limit Reductions Flag'] == 'Default occurred after second limit reductions') & (current_defaulters_bloom_two['second_balance_limit_flag'] == 'Lower than balance') & (current_defaulters_bloom_two['second zeroized'] == 'second zeroized')]

second_batch = second_batch[['store_number', 'Loan Count Flag', 'Default Flag', 'Second Limit Reductions Flag', 'loan_balance', 'previous_final_global_limit', 'second_final_global_limit', 'current_final_global_limit', 'second zeroized', 'second_balance_limit_flag']]

second_batch.head()
# Out:
#       store_number Loan Count Flag             Default Flag  \
# 19394      7237719   Repeat Client  Bloom Two First Default
# 18169      7759217   Repeat Client  Bloom Two First Default
# 8510        779448   Repeat Client  Bloom Two First Default
# 9440       7565981   Repeat Client  Bloom Two First Default
# 14734      7536789   Repeat Client  Bloom Two First Default
#
#                          Second Limit Reductions Flag  loan_balance  \
# 19394  Default occurred after second limit reductions      13621.39
# 18169  Default occurred after second limit reductions      16516.03
# 8510   Default occurred after second limit reductions       3579.60
# 9440   Default occurred after second limit reductions      14660.42
# 14734  Default occurred after second limit reductions       4957.25
#
#        previous_final_global_limit  second_final_global_limit  \
# 19394                     12400.00                       0.00
# 18169                      6800.00                       0.00
# 8510                       1700.00                       0.00
# 9440                       8600.00                       0.00
# 14734                      3600.00                       0.00
#
#        current_final_global_limit  second zeroized second_balance_limit_flag
# 19394                        0.00  second zeroized        Lower than balance
# 18169                        0.00  second zeroized        Lower than balance
# 8510                         0.00  second zeroized        Lower than balance
# 9440                         0.00  second zeroized        Lower than balance
# 14734                        0.00  second zeroized        Lower than balance

# %%
second_batch.to_excel('Second Batch Defaulters.xlsx')

# %%
second_batch.shape
# Out:
# (158, 10)

# %%
current_defaulters_bloom_two.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20167 entries, 16008 to 9026
# Data columns (total 16 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   store_number                  20167 non-null  object
#  1   Loan Count Flag               20167 non-null  object
#  2   Default Flag                  20167 non-null  object
#  3   First Limit Reductions Flag   20167 non-null  object
#  4   Second Limit Reductions Flag  20167 non-null  object
#  5   total_outstanding             20167 non-null  float64
#  6   safaricom_loan_balance        20167 non-null  float64
#  7   loan_balance                  20167 non-null  float64
#  8   previous_final_global_limit   20167 non-null  float64
#  9   first_final_global_limit      20167 non-null  float64
#  10  second_final_global_limit     20167 non-null  float64
#  11  current_final_global_limit    20167 non-null  float64
#  12  first zeroized                20167 non-null  object
#  13  second zeroized               20167 non-null  object
#  14  first_balance_limit_flag      20167 non-null  object
#  15  second_balance_limit_flag     20167 non-null  object
# dtypes: float64(7), object(9)
# memory usage: 2.6+ MB

# %%
# current_defaulters_700 = current_defaulters[current_defaulters['loan_status'] == 700]

# current_defaulters_700 = current_defaulters_700[['loan_mifos_id', 'store_number', 'loan_status', 'principal_outstanding', 'interest_outstanding', 'fee_charges_outstanding', 'penalty_charges_outstanding', 'total_outstanding']]

# current_defaulters_700['total_outstanding_calculated'] = current_defaulters_700['principal_outstanding'] + current_defaulters_700['interest_outstanding'] + current_defaulters_700['fee_charges_outstanding'] + current_defaulters_700['penalty_charges_outstanding']

# current_defaulters_700.head()
