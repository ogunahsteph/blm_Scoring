# %%
# Import modules
import sys

# %%
# Import custom modules
sys.path.append('../')

from src.models.upload_data import *

# %%
# Set notebook attributes
pd.set_option('display.max_colwidth', 500)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 300)
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
# Set magic attributes
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
# Configuration
args = argparse.ArgumentParser()
args.add_argument("--config", default="../params.yaml")
parsed_args = vars(args.parse_args(""))
config_path = parsed_args['config']

# %%
config = read_params(config_path)
project_dir = config["project_dir"]
merged_data_path = config["processed_data_config"]["merged_data_parquet"]
sr_rein_last_limits_clean_data_path = config["processed_data_config"]["sr_rein_last_limits_clean_data_parquet"]
sr_rein_last_limits_clean_data_path = config["processed_data_config"]["sr_rein_last_limits_clean_data_parquet"]
sr_rein_cohort_data_path = config["interim_data_config"]["sr_rein_cohort_data_parquet"]
ftd_clean_data_path = config["processed_data_config"]["ftd_clean_data_parquet"]

# %% [markdown]
# ### Merged Dataset

# %%
# %%time
# Merge data sets
df_merge = pd.read_parquet(project_dir + merged_data_path)
df_merge.sample(2)
# Out:
# CPU times: total: 297 ms
# Wall time: 214 ms
#        previous_is_iprs_validated store_number  \
# 110991                       None      7244904
# 28219                        None       889144
#
#        most_recent_trx_date_past_30_days last_trx_date  actual_trx_days  \
# 110991                               NaT           NaT                0
# 28219                         2022-11-15    2022-12-14               29
#
#         approx_30_days_trx_val  expected_trx_days  page_active_days  \
# 110991                   10.00                  0              0.00
# 28219                 12636.67                 30              0.97
#
#            inference_col  days_since_last_trx transacted_last_5_days  \
# 110991  No_rules_relaxed                  NaN                      0
# 28219        relax_rules               105.00                     No
#
#         weight_till_recency national_id is_iprs_validated mobile_number  \
# 110991                 0.00    34909853              True  254718769448
# 28219                  0.00    13626101              True  254722861142
#
#        idm_recommendation  idm_limit client_mobile_number  loan_count  \
# 110991            Approve       0.00                 None           0
# 28219             Approve    4000.00         254722861142          22
#
#         loan_status  term_frequency  principal_disbursed  principal_repaid  \
# 110991          NaN             NaN                  NaN               NaN
# 28219        600.00           21.00              5000.00           5000.00
#
#        disbursed_on_date expected_matured_on_date closed_on_date  \
# 110991               NaT                      NaT            NaT
# 28219         2022-08-25               2022-09-15     2022-09-15
#
#        due_date_fixed end_rollover_date_fixed expected_dpd90  days_past_due  \
# 110991            NaT                     NaT            NaT            NaN
# 28219      2022-09-15              2022-09-20     2022-12-19          -1.00
#
#         bloom_version   loan_repayment_status  src_crdt_score  \
# 110991            NaN                    None             NaN
# 28219            2.00  closed_early_repayment          460.00
#
#         max_principal_amount max_loan_disbursement_date  count_good_loans  \
# 110991                   NaN                        NaT               NaN
# 28219               20000.00                 2019-06-14             22.00
#
#         good_loans_repayment_ratio  num_days_since_last_disbursement  \
# 110991                         NaN                               NaN
# 28219                         1.00                            216.00
#
#         weight_dpd  max_days_past_due  loan_count_past_3_months  \
# 110991         NaN                NaN                       NaN
# 28219         1.00               2.00                      0.00
#
#         count_7_day_loans  avg_loan_tenure  \
# 110991                NaN              NaN
# 28219                0.00              NaN
#
#         count_7_day_loans_paid_upto_rollover  \
# 110991                                   NaN
# 28219                                   0.00
#
#         good_loans_repayment_ratio(7_day_loans)  \
# 110991                                      NaN
# 28219                                      0.00
#
#         minimum_7_day_principal_disbursed  \
# 110991                                NaN
# 28219                                0.00
#
#         total_sum_7_day_principal_disbursed  \
# 110991                                  NaN
# 28219                                  0.00
#
#         total_sum_1_day_principal_disbursed  avg_7_day_principal_disbursed  \
# 110991                                  NaN                            NaN
# 28219                                  0.00                           0.00
#
#         days_past_end_rollover any_bloom2_1day  total_outstanding_sum  \
# 110991                     NaN            None                    NaN
# 28219                    -6.00           False                   0.00
#
#         safaricom_loan_balance_sum  loan_balance  total_final_21_limit  \
# 110991                         NaN           NaN                     0
# 28219                      4474.00       4474.00                182500
#
#         total_final_1_limit  total_final_7_limit  previous_21_limit  \
# 110991                 0.00                 0.00                  0
# 28219              82100.00             76400.00                  0
#
#         previous_7_limit  previous_1_limit  model_630_21_limit  \
# 110991                 0                 0                 NaN
# 28219                  0                 0             5500.00
#
#         model_630_7_limit  model_630_1_limit  \
# 110991                NaN                NaN
# 28219             3000.00            3000.00
#
#         repayments_by_dd_vs_principal_mean  due_date_rm_ge_rm_add_back_old  \
# 110991                                 NaN                             NaN
# 28219                                 1.08                            1.00
#
#         due_date_rm_ge_rm_1d_old  repayments_by_erd_vs_principal_mean  \
# 110991                       NaN                                  NaN
# 28219                       1.00                                 1.00
#
#         rllvr_date_rm_ge_rm_add_back_old  never_borrowed_flag_old  \
# 110991                               NaN                        1
# 28219                               1.00                        0
#
#         repayments_by_dd_vs_total_expected_repayment_by_dd_mean  \
# 110991                                                      NaN
# 28219                                                      1.00
#
#         due_date_rm_ge_rm_add_back_new  \
# 110991                             NaN
# 28219                             1.00
#
#         repayments_by_erd_vs_total_expected_repayment_by_erd_mean  \
# 110991                                                        NaN
# 28219                                                        1.00
#
#         rllvr_date_rm_ge_rm_add_back_new  rllvr_date_rm_ge_rm_1d_new  \
# 110991                               NaN                         NaN
# 28219                               1.00                        0.00
#
#         never_borrowed_flag_new  due_date_rm_ge_rm_add_back  \
# 110991                        1                           0
# 28219                         0                           1
#
#         rllvr_date_rm_ge_rm_add_back  due_date_rm_ge_rm_1d  \
# 110991                             0                     0
# 28219                              1                     0
#
#         never_borrowed_flag  update_flag reinstatement_reason  rein_7_limit
# 110991                    1         0.00                 None          0.00
# 28219                     0         0.00                 None          0.00

# %%
# Final dataset schema
df_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118921 entries, 0 to 118920
# Data columns (total 82 columns):
#  #   Column                                                     Non-Null Count   Dtype
# ---  ------                                                     --------------   -----
#  0   previous_is_iprs_validated                                 0 non-null       object
#  1   store_number                                               118921 non-null  object
#  2   most_recent_trx_date_past_30_days                          102191 non-null  datetime64[ns]
#  3   last_trx_date                                              102191 non-null  datetime64[ns]
#  4   actual_trx_days                                            118921 non-null  int32
#  5   approx_30_days_trx_val                                     118921 non-null  float64
#  6   expected_trx_days                                          118921 non-null  int32
#  7   page_active_days                                           118921 non-null  float64
#  8   inference_col                                              118921 non-null  object
#  9   days_since_last_trx                                        102191 non-null  float64
#  10  transacted_last_5_days                                     118921 non-null  object
#  11  weight_till_recency                                        118921 non-null  float64
#  12  national_id                                                118401 non-null  object
#  13  is_iprs_validated                                          118921 non-null  object
#  14  mobile_number                                              118401 non-null  object
#  15  idm_recommendation                                         118921 non-null  object
#  16  idm_limit                                                  95455 non-null   float64
#  17  client_mobile_number                                       44331 non-null   object
#  18  loan_count                                                 118921 non-null  int32
#  19  loan_status                                                44331 non-null   float64
#  20  term_frequency                                             44331 non-null   float64
#  21  principal_disbursed                                        44331 non-null   float64
#  22  principal_repaid                                           44331 non-null   float64
#  23  disbursed_on_date                                          44331 non-null   datetime64[ns]
#  24  expected_matured_on_date                                   44331 non-null   datetime64[ns]
#  25  closed_on_date                                             17119 non-null   datetime64[ns]
#  26  due_date_fixed                                             44331 non-null   datetime64[ns]
#  27  end_rollover_date_fixed                                    36476 non-null   datetime64[ns]
#  28  expected_dpd90                                             36476 non-null   datetime64[ns]
#  29  days_past_due                                              40564 non-null   float64
#  30  bloom_version                                              44331 non-null   float64
#  31  loan_repayment_status                                      44331 non-null   object
#  32  src_crdt_score                                             30906 non-null   float64
#  33  max_principal_amount                                       44331 non-null   float64
#  34  max_loan_disbursement_date                                 44331 non-null   datetime64[ns]
#  35  count_good_loans                                           44353 non-null   float64
#  36  good_loans_repayment_ratio                                 44353 non-null   float64
#  37  num_days_since_last_disbursement                           44331 non-null   float64
#  38  weight_dpd                                                 44353 non-null   float64
#  39  max_days_past_due                                          43092 non-null   float64
#  40  loan_count_past_3_months                                   44353 non-null   float64
#  41  count_7_day_loans                                          44353 non-null   float64
#  42  avg_loan_tenure                                            6431 non-null    float64
#  43  count_7_day_loans_paid_upto_rollover                       44353 non-null   float64
#  44  good_loans_repayment_ratio(7_day_loans)                    44353 non-null   float64
#  45  minimum_7_day_principal_disbursed                          44353 non-null   float64
#  46  total_sum_7_day_principal_disbursed                        44353 non-null   float64
#  47  total_sum_1_day_principal_disbursed                        44353 non-null   float64
#  48  avg_7_day_principal_disbursed                              44353 non-null   float64
#  49  days_past_end_rollover                                     32717 non-null   float64
#  50  any_bloom2_1day                                            44331 non-null   object
#  51  total_outstanding_sum                                      44353 non-null   float64
#  52  safaricom_loan_balance_sum                                 44353 non-null   float64
#  53  loan_balance                                               44353 non-null   float64
#  54  total_final_21_limit                                       118921 non-null  int32
#  55  total_final_1_limit                                        117836 non-null  float64
#  56  total_final_7_limit                                        117836 non-null  float64
#  57  previous_21_limit                                          118921 non-null  int32
#  58  previous_7_limit                                           118921 non-null  int32
#  59  previous_1_limit                                           118921 non-null  int32
#  60  model_630_21_limit                                         48018 non-null   float64
#  61  model_630_7_limit                                          48018 non-null   float64
#  62  model_630_1_limit                                          48018 non-null   float64
#  63  repayments_by_dd_vs_principal_mean                         35360 non-null   float64
#  64  due_date_rm_ge_rm_add_back_old                             35360 non-null   float64
#  65  due_date_rm_ge_rm_1d_old                                   35360 non-null   float64
#  66  repayments_by_erd_vs_principal_mean                        35360 non-null   float64
#  67  rllvr_date_rm_ge_rm_add_back_old                           35360 non-null   float64
#  68  never_borrowed_flag_old                                    118921 non-null  int32
#  69  repayments_by_dd_vs_total_expected_repayment_by_dd_mean    35395 non-null   float64
#  70  due_date_rm_ge_rm_add_back_new                             35395 non-null   float64
#  71  repayments_by_erd_vs_total_expected_repayment_by_erd_mean  35395 non-null   float64
#  72  rllvr_date_rm_ge_rm_add_back_new                           35395 non-null   float64
#  73  rllvr_date_rm_ge_rm_1d_new                                 35395 non-null   float64
#  74  never_borrowed_flag_new                                    118921 non-null  int32
#  75  due_date_rm_ge_rm_add_back                                 118921 non-null  int32
#  76  rllvr_date_rm_ge_rm_add_back                               118921 non-null  int32
#  77  due_date_rm_ge_rm_1d                                       118921 non-null  int32
#  78  never_borrowed_flag                                        118921 non-null  int32
#  79  update_flag                                                118921 non-null  float64
#  80  reinstatement_reason                                       170 non-null     object
#  81  rein_7_limit                                               118921 non-null  float64
# dtypes: datetime64[ns](9), float64(48), int32(13), object(12)
# memory usage: 68.5+ MB

# %% [markdown]
# ### Reinstatement Dataset

# %%
# Reinstatement data set
rein_cohort_details = pd.read_parquet(project_dir + sr_rein_cohort_data_path)
rein_cohort_details.loan_mifos_id = rein_cohort_details.loan_mifos_id.astype('str')
rein_cohort_details.store_number = rein_cohort_details.store_number.astype('str')
rein_cohort_details.sample(2)
# Out:
#         id  client_id  loan_status_id  term_frequency              partner  \
# 118  41720      36584             300              21  Safaricom Bloom 2.0
# 5     4324      17340             300              21  Safaricom Bloom 2.0
#
#           product  disbursedon_date expected_maturedon_date  DPD  \
# 118  Bloom 21-day  13/03/2022 00:00        03/04/2022 00:00  355
# 5    Bloom 21-day  19/11/2021 00:00        10/12/2021 00:00  469
#
#      principal_disbursed_derived  total_repayment_derived  \
# 118                        84800                 24952.80
# 5                          44200                 14320.00
#
#      total_expected_repayment_derived  principal_repaid_derived  \
# 118                         125180.22                      0.00
# 5                            68704.81                      0.00
#
#      interest_charged_derived  interest_repaid_derived  \
# 118                   6444.81                     0.00
# 5                     3842.49                     0.00
#
#      fee_charges_charged_derived  fee_charges_repaid_derived  \
# 118                      4561.81                        0.00
# 5                        2142.27                        0.00
#
#      penalty_charges_charged_derived  penalty_charges_repaid_derived  \
# 118                         29373.60                        24952.80
# 5                           18520.05                        14320.00
#
#      total_outstanding_derived  loan_count  repayments_ratio_by_due_date  \
# 118                  100227.42           1                           NaN
# 5                     54384.81           1                           NaN
#
#      traction  rollover_period  dpd_from_erd loan_mifos_id store_number  \
# 118      0.29                5           350         41720       578417
# 5        0.32                5           464          4324       828269
#
#      is_iprs_validated   mobile_number
# 118               True 254723000000.00
# 5                 True 254723000000.00

# %%
# Final dataset schema
rein_cohort_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396 entries, 0 to 395
# Data columns (total 29 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                396 non-null    int64
#  1   client_id                         396 non-null    int64
#  2   loan_status_id                    396 non-null    int64
#  3   term_frequency                    396 non-null    int64
#  4   partner                           396 non-null    object
#  5   product                           396 non-null    object
#  6   disbursedon_date                  396 non-null    object
#  7   expected_maturedon_date           396 non-null    object
#  8   DPD                               396 non-null    int64
#  9   principal_disbursed_derived       396 non-null    int64
#  10  total_repayment_derived           396 non-null    float64
#  11  total_expected_repayment_derived  396 non-null    float64
#  12  principal_repaid_derived          396 non-null    float64
#  13  interest_charged_derived          396 non-null    float64
#  14  interest_repaid_derived           396 non-null    float64
#  15  fee_charges_charged_derived       396 non-null    float64
#  16  fee_charges_repaid_derived        396 non-null    float64
#  17  penalty_charges_charged_derived   396 non-null    float64
#  18  penalty_charges_repaid_derived    396 non-null    float64
#  19  total_outstanding_derived         396 non-null    float64
#  20  loan_count                        396 non-null    int64
#  21  repayments_ratio_by_due_date      339 non-null    float64
#  22  traction                          396 non-null    float64
#  23  rollover_period                   396 non-null    int64
#  24  dpd_from_erd                      396 non-null    int64
#  25  loan_mifos_id                     396 non-null    object
#  26  store_number                      396 non-null    object
#  27  is_iprs_validated                 396 non-null    bool
#  28  mobile_number                     396 non-null    float64
# dtypes: bool(1), float64(13), int64(9), object(6)
# memory usage: 87.1+ KB

# %% [markdown]
# ### FTD

# %%
# FTD data set
df_ftd_clean = pd.read_parquet(project_dir + ftd_clean_data_path)
df_ftd_clean.sample(2)
# Out:
#    store_number  update_flag  \
# 18      7783143            1
# 29      7309656            1
#
#                                               reinstatement_reason
# 18  first time defaulters during election risk mitigation measures
# 29  first time defaulters during election risk mitigation measures

# %%
# Final dataset schema
df_ftd_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   store_number          39 non-null     object
#  1   update_flag           39 non-null     int64
#  2   reinstatement_reason  39 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 1.0+ KB

# %% [markdown]
# ### Reinstatement and in Till Activity

# %%
# Sample
df_till = df_merge[(~df_merge.rein_7_limit.isna()) & (df_merge.rein_7_limit > 0)]
df_till.sample(2)
# Out:
#       previous_is_iprs_validated store_number  \
# 24782                       None       204741
# 18303                       None      7154750
#
#       most_recent_trx_date_past_30_days last_trx_date  actual_trx_days  \
# 24782                        2022-11-15    2022-12-14               29
# 18303                        2022-11-15    2022-12-14               29
#
#        approx_30_days_trx_val  expected_trx_days  page_active_days  \
# 24782                58832.72                 30              0.97
# 18303               144724.31                 30              0.97
#
#           inference_col  days_since_last_trx transacted_last_5_days  \
# 24782  No_rules_relaxed               105.00                     No
# 18303  No_rules_relaxed               105.00                     No
#
#        weight_till_recency national_id is_iprs_validated mobile_number  \
# 24782                 0.00    10893055              True  254722554132
# 18303                 0.00    25444046              True  254711446956
#
#       idm_recommendation  idm_limit client_mobile_number  loan_count  \
# 24782            Approve    4500.00         254722554132         118
# 18303             Reject       0.00         254711446956          14
#
#        loan_status  term_frequency  principal_disbursed  principal_repaid  \
# 24782       300.00           21.00            116500.00              0.00
# 18303       300.00           21.00             71800.00              0.00
#
#       disbursed_on_date expected_matured_on_date closed_on_date  \
# 24782        2022-07-24               2022-08-14            NaT
# 18303        2022-05-30               2022-06-20            NaT
#
#       due_date_fixed end_rollover_date_fixed expected_dpd90  days_past_due  \
# 24782     2022-08-14              2022-08-19     2022-11-17         227.00
# 18303     2022-06-20              2022-06-25     2022-09-23         282.00
#
#        bloom_version loan_repayment_status  src_crdt_score  \
# 24782           2.00        active_default          459.00
# 18303           2.00        active_default          438.00
#
#        max_principal_amount max_loan_disbursement_date  count_good_loans  \
# 24782             116500.00                 2022-07-24            110.00
# 18303              71800.00                 2022-05-30             13.00
#
#        good_loans_repayment_ratio  num_days_since_last_disbursement  \
# 24782                        0.93                            248.00
# 18303                        0.93                            303.00
#
#        weight_dpd  max_days_past_due  loan_count_past_3_months  \
# 24782        0.00             227.00                      0.00
# 18303        0.00             282.00                      0.00
#
#        count_7_day_loans  avg_loan_tenure  \
# 24782               0.00              NaN
# 18303               0.00              NaN
#
#        count_7_day_loans_paid_upto_rollover  \
# 24782                                  0.00
# 18303                                  0.00
#
#        good_loans_repayment_ratio(7_day_loans)  \
# 24782                                     0.00
# 18303                                     0.00
#
#        minimum_7_day_principal_disbursed  total_sum_7_day_principal_disbursed  \
# 24782                               0.00                                 0.00
# 18303                               0.00                                 0.00
#
#        total_sum_1_day_principal_disbursed  avg_7_day_principal_disbursed  \
# 24782                                 0.00                           0.00
# 18303                                 0.00                           0.00
#
#        days_past_end_rollover any_bloom2_1day  total_outstanding_sum  \
# 24782                  222.00           False              149644.21
# 18303                  277.00           False               88149.09
#
#        safaricom_loan_balance_sum  loan_balance  total_final_21_limit  \
# 24782                   231812.25     231812.25               1774200
# 18303                   139765.87     139765.87                665200
#
#        total_final_1_limit  total_final_7_limit  previous_21_limit  \
# 24782            678500.00            719300.00                  0
# 18303            464300.00            476300.00                  0
#
#        previous_7_limit  previous_1_limit  model_630_21_limit  \
# 24782                 0                 0           116500.00
# 18303                 0                 0            35800.00
#
#        model_630_7_limit  model_630_1_limit  \
# 24782           63600.00           63600.00
# 18303           19700.00           19700.00
#
#        repayments_by_dd_vs_principal_mean  due_date_rm_ge_rm_add_back_old  \
# 24782                                0.97                            0.00
# 18303                                0.95                            0.00
#
#        due_date_rm_ge_rm_1d_old  repayments_by_erd_vs_principal_mean  \
# 24782                      0.00                                 0.95
# 18303                      0.00                                 0.70
#
#        rllvr_date_rm_ge_rm_add_back_old  never_borrowed_flag_old  \
# 24782                              0.00                        0
# 18303                              0.00                        0
#
#        repayments_by_dd_vs_total_expected_repayment_by_dd_mean  \
# 24782                                                     0.95
# 18303                                                     0.93
#
#        due_date_rm_ge_rm_add_back_new  \
# 24782                            0.00
# 18303                            0.00
#
#        repayments_by_erd_vs_total_expected_repayment_by_erd_mean  \
# 24782                                                       0.97
# 18303                                                       0.93
#
#        rllvr_date_rm_ge_rm_add_back_new  rllvr_date_rm_ge_rm_1d_new  \
# 24782                              0.00                        0.00
# 18303                              0.00                        0.00
#
#        never_borrowed_flag_new  due_date_rm_ge_rm_add_back  \
# 24782                        0                           0
# 18303                        0                           0
#
#        rllvr_date_rm_ge_rm_add_back  due_date_rm_ge_rm_1d  \
# 24782                             0                     0
# 18303                             0                     0
#
#        never_borrowed_flag  update_flag reinstatement_reason  rein_7_limit
# 24782                    0         0.00                 None      63600.00
# 18303                    0         0.00                 None      39900.00

# %%
# Count
df_till.shape
# Out:
# (300, 82)

# %% [markdown]
# ### Till Activity and in FTD

# %%
# Sample
df_till[df_till.store_number.isin(df_ftd_clean.store_number)].head(2)
# Out:
#       previous_is_iprs_validated store_number  \
# 25790                       None       945539
#
#       most_recent_trx_date_past_30_days last_trx_date  actual_trx_days  \
# 25790                        2022-11-15    2022-12-14               29
#
#        approx_30_days_trx_val  expected_trx_days  page_active_days  \
# 25790               859270.60                 30              0.97
#
#           inference_col  days_since_last_trx transacted_last_5_days  \
# 25790  No_rules_relaxed               105.00                     No
#
#        weight_till_recency national_id is_iprs_validated mobile_number  \
# 25790                 0.00    22751266              True  254728410933
#
#       idm_recommendation  idm_limit client_mobile_number  loan_count  \
# 25790            Approve       0.00         254728410933          17
#
#        loan_status  term_frequency  principal_disbursed  principal_repaid  \
# 25790       300.00           21.00            200000.00         142925.85
#
#       disbursed_on_date expected_matured_on_date closed_on_date  \
# 25790        2022-07-31               2022-08-21            NaT
#
#       due_date_fixed end_rollover_date_fixed expected_dpd90  days_past_due  \
# 25790     2022-08-21              2022-08-26     2022-11-24         220.00
#
#        bloom_version loan_repayment_status  src_crdt_score  \
# 25790           2.00        active_default          486.00
#
#        max_principal_amount max_loan_disbursement_date  count_good_loans  \
# 25790             200000.00                 2022-07-31             15.00
#
#        good_loans_repayment_ratio  num_days_since_last_disbursement  \
# 25790                        0.88                            241.00
#
#        weight_dpd  max_days_past_due  loan_count_past_3_months  \
# 25790        0.00             220.00                      0.00
#
#        count_7_day_loans  avg_loan_tenure  \
# 25790               0.00              NaN
#
#        count_7_day_loans_paid_upto_rollover  \
# 25790                                  0.00
#
#        good_loans_repayment_ratio(7_day_loans)  \
# 25790                                     0.00
#
#        minimum_7_day_principal_disbursed  total_sum_7_day_principal_disbursed  \
# 25790                               0.00                                 0.00
#
#        total_sum_1_day_principal_disbursed  avg_7_day_principal_disbursed  \
# 25790                                 0.00                           0.00
#
#        days_past_end_rollover any_bloom2_1day  total_outstanding_sum  \
# 25790                  215.00           False               57074.15
#
#        safaricom_loan_balance_sum  loan_balance  total_final_21_limit  \
# 25790                    70068.37      70068.37               2400000
#
#        total_final_1_limit  total_final_7_limit  previous_21_limit  \
# 25790           2110400.00           2161500.00             200000
#
#        previous_7_limit  previous_1_limit  model_630_21_limit  \
# 25790            154700            154700           200000.00
#
#        model_630_7_limit  model_630_1_limit  \
# 25790          154700.00          154700.00
#
#        repayments_by_dd_vs_principal_mean  due_date_rm_ge_rm_add_back_old  \
# 25790                                1.01                            0.00
#
#        due_date_rm_ge_rm_1d_old  repayments_by_erd_vs_principal_mean  \
# 25790                      1.00                                 0.75
#
#        rllvr_date_rm_ge_rm_add_back_old  never_borrowed_flag_old  \
# 25790                              0.00                        0
#
#        repayments_by_dd_vs_total_expected_repayment_by_dd_mean  \
# 25790                                                     0.94
#
#        due_date_rm_ge_rm_add_back_new  \
# 25790                            0.00
#
#        repayments_by_erd_vs_total_expected_repayment_by_erd_mean  \
# 25790                                                       0.94
#
#        rllvr_date_rm_ge_rm_add_back_new  rllvr_date_rm_ge_rm_1d_new  \
# 25790                              0.00                        0.00
#
#        never_borrowed_flag_new  due_date_rm_ge_rm_add_back  \
# 25790                        0                           0
#
#        rllvr_date_rm_ge_rm_add_back  due_date_rm_ge_rm_1d  \
# 25790                             0                     0
#
#        never_borrowed_flag  update_flag reinstatement_reason  rein_7_limit
# 25790                    0         0.00                 None     123500.00

# %%
# Count
df_till[df_till.store_number.isin(df_ftd_clean.store_number)].shape
# Out:
# (1, 82)
